# %%
# Introduction of the packages
using Pkg
Pkg.add("CSV")
Pkg.add("DataFrames")
Pkg.add("JuMP")
Pkg.add("Gurobi")
#Pkg.add("NLopt")

using CSV, DataFrames, JuMP, Gurobi
# Out:
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.9/Project.toml`
#   No Changes to `~/.julia/environments/v1.9/Manifest.toml`
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.9/Project.toml`
#   No Changes to `~/.julia/environments/v1.9/Manifest.toml`
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.9/Project.toml`
#   No Changes to `~/.julia/environments/v1.9/Manifest.toml`
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.9/Project.toml`
#   No Changes to `~/.julia/environments/v1.9/Manifest.toml`

# %%
# Read the CSVs
SCALE_MWH = 1000
SCALE_DOLLAR = 1000

# CHANGE THIS FOR HIGH COST SCENARIO
scenario = "mean" # "max" or "mean"

fixed_cost = CSV.read("data/fixed_cost_"*scenario*".csv",DataFrame) ./ SCALE_DOLLAR
variable_cost = CSV.read("data/variable_cost_"*scenario*".csv",DataFrame) ./ SCALE_DOLLAR
co2_intensity = CSV.read("data/co2_intensity.csv",DataFrame)
curtailment_costs = [0, 2, 0, 0, 0, 0] ./ SCALE_DOLLAR
ramp_limits = CSV.read("data/ramp_limits.csv", DataFrame)

# AVAILABILITY
P_max_s = 95897829.43 / SCALE_MWH
P_max_w = 11158008 / SCALE_MWH;

Availability_matrix = CSV.read("data/Availability.csv", DataFrame);
println(size(Availability_matrix))

############### Constants of the model 

eta = 0.8; # Efficiency of the battery
CO2_price = 100; # price of the CO2 per ton
H = 2;

################ Time to consider

# T = 50
# T_start = 987
# println("Timespan: ", T)
# println("Starting at hour: ", T_start)
# time_ls_opt = 1:T
# time_ls_clipped = 2:T-1 # For rate of change calculations

T = 50
T_start = 4960
time_ls_opt = T_start-24:T_start+24


hrs = 4000
hre = 5000
sel_hrs = hrs:hre
println(sel_hrs)
techs = 5
n_eu = 4
# pad year by 1 day
add_h = 24


println("Timespan: ", T)
#time_ls = 1+add_h:T-add_h
time_ls = T_start-24+1:T_start+24-add_h
vre_ls = 1:2
fossil_ls = 3:4
batt_ind = 5;
# Out:
# (8760, 5)
# 4000:5000
# Timespan: 50

# %%
######## Need to create a loop on that ========

name_demand_flex_input = [
    "demand_flex25_vre0", 
    "demand_flex25_vre50", 
    "demand_flex25_vre100", 
    "demand_flex75_vre0", 
    "demand_flex75_vre50", 
    "demand_flex75_vre100"
    ]
println("Starting Loop")
for name in name_demand_flex_input
    println(name)
    file_to_read = "data/"*name*".csv"
    println("Reading scenario $file_to_read")

    demand = Matrix(CSV.read(file_to_read, DataFrame)) ./ SCALE_MWH;
    println("Loaded demand with size ", size(demand))

    #######################################

    println("Cost")
    C_FC = fixed_cost[1:techs,1]
    C_FOM = fixed_cost[1:techs,2]
    C_VOM = variable_cost[1:techs,1]
    E_CO2 = co2_intensity[1:techs,1]
    C_ramp = variable_cost[1:techs,2]
    C_start = variable_cost[1:techs,3]
    C_curt = curtailment_costs[1:techs]

    println("Demand")
    D_b = demand[:] # Baseline demand with no flex
    println(size(D_b))
    D_b = vcat(reverse(reverse(demand)[1:add_h]), D_b, D_b[1:24])
    println(size(D_b))
    total_demand = D_b
    X_D = D_b

    A_r = ramp_limits[1:techs, 1]
    println("Availability")
    A_s = Availability_matrix[:,1:techs]
    println("Try reverse")
    A_s = vcat(reverse(reverse(Availability_matrix)[1:add_h, 1:techs]), A_s, A_s[1:24, 1:techs])
    println(size(A_s))
    # over time, opt each year with worst day for availability and highest demand?

    n = size(C_FC, 1) # number of technologies
    println("Number of technologies: ", n)

    ###### MODEL ######

    model = Model(Gurobi.Optimizer) # TODO: options? other optimizers?
    set_optimizer_attribute(model, "NonConvex", 2)
    #set_optimizer_attribute(model, "IterationLimit", 10000000)
    set_optimizer_attribute(model, "TimeLimit", 120)
    println("Model: initialized!\n")

    ###### MAIN VARIABLES ######
    # Non-negativity constraints
    # The installed power capacity of the mix
    @variable(model, P[1:n] >= 0)

    # The hourly power generation of each technology
    @variable(model, X_gen[time_ls_opt, 1:n] >= 0); # hourly production/use for each technology

    # Curtailment (only renewables?)
    @variable(model, X_cur[time_ls_opt, 1:n] >= 0); # hourly production/use for each technology

    ###### CONSTRAINTS ######

    # Demand constraint - meet demand per hour
    println("Demand constraint")
    @constraint(model, Con_dh[t = time_ls_opt], sum(X_gen[t, i] for i in 1:n) >= X_D[t]); # TODO: add curtailment
    # Meet total demand
    # @constraint(model, Con_d, sum(X_gen[t, i] for i in 1:n for t in time_ls_opt) >= sum(total_demand));

    # Installed capacity renewables < max capacity
    println("Renewable maximum installed capacity constraint")
    @constraint(model, Con_sgen, P[1] <= P_max_s);
    @constraint(model, Con_wgen, P[2] <= P_max_w);

    # println("Renewable minimum installed capacity constraint")
    #@constraint(model, Con_solar_lb, P[1] >= 50);
    #@constraint(model, Con_wind_lb, P[2] >= 600);

    # Storage variable
    println("Storage variable")
    @variable(model, 0<= X_soc[time_ls_opt] <=1)
    @variable(model, X_ch[time_ls_opt]>=0)

    # Cannot produce more than the installed power
    # println("Installed power constraint")
    # @constraint(model, Con_p[i = 1:n, t = time_ls_opt], X_gen[t, i] <= P[i])

    # For each tech, at each hour, usage cannot exceed available capacity
    println("Availability & installed power constraint")
    @constraint(model, [i = 1:n, t = time_ls_opt], X_gen[t, i] <= P[i]*A_s[t, i])
    # Renewables produce maximum possible capacity
    @constraint(model, [i = vre_ls, t = time_ls_opt], X_gen[t, i] >= 0.7*P[i]*A_s[t, i]) 


    println("Availability & installed power constraint")
    @constraint(model, [i = 1:n, t = time_ls_opt], X_gen[t, i] <= P[i]*A_s[t, i])

    println("Curtailment definition")
    @constraint(model, [t = time_ls_opt], sum(X_cur[t, i] for i in 1:n) == sum(X_gen[t, i] for i in 1:n) - X_D[t]) 
    @constraint(model, [i = 1:n, t = time_ls_opt], X_cur[t, i] <= X_gen[t, i])

    # Cannot produce less than the minimum stable generation: X_gen must be zero or min to max
    # min_usage = [0, 0.1, 0, 0] #TODO - cant be more than ramp
    # @constraint(model, [i = 1:n, t = time_ls_opt], X_gen[t, i] >= P[i]*min_usage[i])

    # For each tech, at each hour, change in production cannot exceed ramp rate (TODO might need to convert this to time)
    # println("Ramp constraint")
    # Auxiliary variables to linearize the rate of change constraint
    # @constraint(model, Con_rdwn[i = 1:n, t = time_ls_clipped], (X_gen[t+1, i] - X_gen[t, i]) >= -A_r[i]*X_gen[t, i]) 
    # @constraint(model, Con_rup[i = 1:n, t = time_ls_clipped], (X_gen[t+1, i] - X_gen[t, i]) <= A_r[i]*X_gen[t, i]);

    M = 10000000
    
    # println("Cold Start")
    # @variable(model, Cold_start[time_ls_opt, i = 1:4], Bin)
    # @constraint(model, [i = 1:4, t in time_ls_clipped], (X_gen[t, i] - X_gen[t-1, i])*X_gen[t, i] <= M*Cold_start[t, i])
    # @constraint(model, [i = 1:4, t in time_ls_clipped], -(X_gen[t, i] - X_gen[t-1, i])*X_gen[t, i] <= M*Cold_start[t, i])

    # Storage model

    # Need to put this conditions above
    @variable(model, Z_X_gen_greater_X_D[time_ls_opt], Bin)

    @constraint(model, Z_X_gen_greater_X_D_1[t in time_ls_opt], sum(X_gen[t,i] for i in 1:4) - X_D[t] <= M*Z_X_gen_greater_X_D[t])
    @constraint(model, Z_X_gen_greater_X_D_2[t in time_ls_opt], -sum(X_gen[t,i] for i in 1:4) + X_D[t] <= M*(1-Z_X_gen_greater_X_D[t]))


    # X_1, X_2, X_3 = [eta*(sum(X_gen[t,i] for i in Power_generation_ls)- X_D[t]) , eta*P3], (1- X_soc[t])*P[5]* H]
    @variable(model, z1[t in time_ls_opt], Bin)
    @variable(model, z2[t in time_ls_opt], Bin)

    # z_1 equal 1 if eta*(x_g_t -x_d) is is greatter than eta*E_max*delta t
    println("Z_1 expression")
    @constraint(model, z_1_1[t in time_ls_opt], eta*P[5] - eta*(sum(X_gen[t,i] for i in 1:4)- X_D[t])   <=  M*z1[t])
    @constraint(model, z_1_2[t in time_ls_opt], -eta*P[5] + eta*(sum(X_gen[t,i] for i in 1:4)- X_D[t]) <= M*(1-z1[t]))


    #Minimum between X_1 and X_2
    @variable(model, min_X_1_X_2[time_ls_opt])

    println("Min X_1, X_2 expression")
    @constraint(model, X_1_X_2_lower_1[t in time_ls_opt], min_X_1_X_2[t] <= eta*(sum(X_gen[t,i] for i in 1:4)- X_D[t]))
    @constraint(model, X_1_X_2_lower_2[t in time_ls_opt], min_X_1_X_2[t] <= eta*P[5])
    @constraint(model, X_1_X_2_higher_1[t in time_ls_opt], min_X_1_X_2[t] >= eta*(sum(X_gen[t,i] for i in 1:4)- X_D[t]) - M*(1-z1[t]))
    @constraint(model, X_1_X_2_higher_2[t in time_ls_opt], min_X_1_X_2[t] >= eta*P[5] - M*z1[t])


    # z_2 equal 1 if min(X_1, X_2) is is greater than (1- x_soc[t])*h*E_max
    println(" Take the min of min(X_1, X_2) and X_3")
    @constraint(model, z_2_1[t in time_ls_opt], (1- X_soc[t])* P[5] * H - min_X_1_X_2[t] <=  M*z2[t])
    @constraint(model, z_2_2[t in time_ls_opt], - (1- X_soc[t]) * P[5] * H + min_X_1_X_2[t] <= M*(1-z2[t]))


    # Constraint for the variable X_ch
    println(" Take the overall min")
    @variable(model, min_X_1_X_2_X_3[time_ls_opt])

    @constraint(model, X_1_X_2_X_3_lower_1[t in time_ls_opt], min_X_1_X_2_X_3[t] <= min_X_1_X_2[t])
    @constraint(model, X_1_X_2_X_3_lower_2[t in time_ls_opt], min_X_1_X_2_X_3[t] <= (1- X_soc[t])*P[3]* H)
    @constraint(model, X_1_X_2_X_3_higher_1[t in time_ls_opt], min_X_1_X_2_X_3[t] >= min_X_1_X_2[t] - M*(1-z2[t]))
    @constraint(model, X_1_X_2_X_3_higher_2[t in time_ls_opt], min_X_1_X_2_X_3[t] >= (1- X_soc[t])*P[3]* H - M*z2[t]);

    #Expression of X_ch
    @constraint(model, X_ch_expression[t in time_ls_opt], X_ch[t]  == Z_X_gen_greater_X_D[t]*min_X_1_X_2_X_3[t]);
    @variable(model, y2[time_ls_opt], Bin)

    # z_2 equal 1 if min(X_1, X_2) is is greater than (1- x_soc[t])*h*E_max
    println(" Take the min of min(X_1, X_2) and X_3")
    @constraint(model, y_2_1[t in time_ls_opt], X_soc[t]* P[5] * H - P[5] <=  M*y2[t])
    @constraint(model, y_2_2[t in time_ls_opt], - X_soc[t] * P[5] * H + P[5] <= M*(1-y2[t]))

    # Constraint for the variable X_ch
    println(" Take the overall min")
    @variable(model, min_extra_prod_P5_soc[time_ls_opt])

    @constraint(model, min_extra_prod_P5_soc_lower_1[t in time_ls_opt], min_extra_prod_P5_soc[t] <= P[5])
    @constraint(model, min_extra_prod_P5_soc_lower_2[t in time_ls_opt], min_extra_prod_P5_soc[t] <= X_soc[t]*P[5]* H)
    @constraint(model, min_extra_prod_P5_soc_higher_1[t in time_ls_opt], min_extra_prod_P5_soc[t] >= P[5] - M*(1-y2[t]))
    @constraint(model, min_extra_prod_P5_soc_higher_2[t in time_ls_opt], min_extra_prod_P5_soc[t] >= X_soc[t]*P[5]* H - M*y2[t]);

    @variable(model, batt_dispatch[time_ls_opt], Bin)

    #Expression of X_dch
    @constraint(model, X_dch_expression[t in time_ls_opt], X_gen[t,5]  <= batt_dispatch[t]*min_extra_prod_P5_soc[t]);


    # First hour need to be equal to one
    # Start with a charged battery
    @constraint(model, SOC_t_1, X_soc[time_ls_opt[1]] == 0)

    #
    @constraint(model, SOC_t[t in time_ls_opt[2]:time_ls_opt[end]], (X_soc[t]-X_soc[t-1])*H*P[5] == (X_ch[t-1]- X_gen[t-1,5]));

    # MODEL OBJECTIVE FUNCTION
    #TODO RAMP AND STARTUP COSTS

    println("Initialize Objective")

    @objective(model, Min, 
        (
            sum((C_FC[i] + C_FOM[i])*P[i] for i in 1:n) + # FIXED COSTS
            sum(sum((C_VOM[i] + CO2_price* E_CO2[i])* X_gen[t, i] for i in 1:n) for t in time_ls_opt) + # VARIABLE COSTS
            sum(sum(C_curt[i] * X_cur[t, i] for i in 1:n) for t in time_ls) # CURTAILMENT COSTS
    ));

    #Optimize
    println("Optimize model")
    optimize!(model)

    # Save the results for the generation
    # Assuming your matrix is named `my_matrix`
    my_matrix = [value.(X_gen) value.(X_soc) X_D[time_ls_opt]]  # Replace this with your actual matrix
    # Column names

    column_names = ["Solar", "Wind", "CCGT", "Coal", "Battery", "State_of_Charge", "Demand"]

    # Create a DataFrame with vectors for each column
    df = DataFrame([Symbol(name) => my_matrix[:, i] for (i, name) in enumerate(column_names)])

    # Specify the file path for your CSV file
    csv_file_path = "Results/Mean_cost/profiles_" * name * ".csv"

    # Export the DataFrame to CSV
    CSV.write(csv_file_path, df)

    println("CSV file exported to: $csv_file_path")

    # Save the results for the power installed power
    # Assuming your matrix is named `my_matrix`
    Power = value.(P)   # Replace this with your actual matrix
    # Column names
    println("INSTALLED POWER RESULTS")
    println(Power)
    column_names_power = "Installed Power"

    # Create a DataFrame with vectors for each column
    df_Power = DataFrame(Symbol(column_names_power) => Power)

    # Specify the file path for your CSV file
    csv_file_path_power = "Results/Mean_cost/power_" * name * ".csv"

    # Export the DataFrame to CSV
    CSV.write(csv_file_path_power, df_Power)

    println("CSV file exported to: $csv_file_path_power")
end
# Out:
# Starting Loop
# demand_flex25_vre0
# Reading scenario data/demand_flex25_vre0.csv
# Loaded demand with size (8759, 1)
# Cost
# Demand
# (8759,)
# (8807,)
# Availability
# Try reverse
# (8808, 5)
# Number of technologies: 5
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-09-07
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 120
# Model: initialized!
#
# Demand constraint
# Renewable maximum installed capacity constraint
# Storage variable
# Availability & installed power constraint
# Availability & installed power constraint
# Curtailment definition
# Z_1 expression
# Min X_1, X_2 expression
#  Take the min of min(X_1, X_2) and X_3
#  Take the overall min
#  Take the min of min(X_1, X_2) and X_3
#  Take the overall min
# Initialize Objective
# Optimize model
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 120
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1522 rows, 985 columns and 4720 nonzeros
# Model fingerprint: 0x91b19a6e
# Model has 538 quadratic constraints
# Variable types: 740 continuous, 245 integer (245 binary)
# Coefficient statistics:
#   Matrix range     [9e-04, 1e+07]
#   QMatrix range    [1e+00, 2e+00]
#   QLMatrix range   [1e+00, 1e+07]
#   Objective range  [2e-03, 1e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+02, 1e+07]
#   QRHS range       [1e+07, 1e+07]
# Presolve added 4 rows and 64 columns
# Presolve time: 0.01s
# Presolved: 2489 rows, 1194 columns, 7207 nonzeros
# Presolved model has 239 bilinear constraint(s)
# Variable types: 951 continuous, 243 integer (243 binary)
#
# Root relaxation: objective 1.392032e+06, 711 iterations, 0.00 seconds (0.02 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1392032.09    0  133          - 1392032.09      -     -    0s
# H    0     0                    5.508918e+08 1392032.09   100%     -    0s
#      0     0 1919237.15    0  132 5.5089e+08 1919237.15   100%     -    0s
# H    0     0                    5.151384e+08 1919237.15   100%     -    0s
# H    0     0                    5.151384e+08 1919237.15   100%     -    0s
#      0     0 1919237.15    0  133 5.1514e+08 1919237.15   100%     -    0s
#      0     0 1919237.15    0  125 5.1514e+08 1919237.15   100%     -    0s
#      0     0 1919237.15    0  125 5.1514e+08 1919237.15   100%     -    0s
#      0     0 1919237.15    0  127 5.1514e+08 1919237.15   100%     -    0s
#      0     0 1989133.29    0  127 5.1514e+08 1989133.29   100%     -    0s
#      0     2 1989133.29    0  126 5.1514e+08 1989133.29   100%     -    0s
# H  530   566                    1.052460e+08 1989133.29  98.1%  13.5    0s
# H  889   835                    1.052460e+08 1989133.29  98.1%  17.8    0s
# * 1384   707             107    1.702022e+07 1989133.29  88.3%  16.6    0s
# * 1388   707             109    1.680471e+07 1989133.29  88.2%  16.7    0s
# * 1469   706              74    1.608830e+07 1989133.29  87.6%  16.4    0s
# H 1587   682                    4732077.9823 2684895.67  43.3%  18.1    3s
# * 2535   851              83    4017728.0240 2684895.67  33.2%  20.1    4s
# * 2578   830              55    3950684.7451 2684895.67  32.0%  20.1    4s
# * 2581   798              57    3943704.4384 2684895.67  31.9%  20.1    4s
# H 2582   769                    3943114.0683 2684895.67  31.9%  20.1    4s
# * 2637   710              58    3943087.3412 2684895.67  31.9%  20.1    4s
# H 2639   592                    3318065.8707 2684895.67  19.1%  20.1    4s
# * 2757   529             106    3318065.6488 2714297.85  18.2%  19.8    4s
#   3152   496 2945233.90   31   65 3318065.65 2762916.87  16.7%  20.4    5s
# * 3348   529              77    3317727.8366 2767532.38  16.6%  20.2    5s
# * 4371  1030             100    3296542.4042 2850818.28  13.5%  19.3    5s
# * 4982  1044              56    3295533.1662 2875823.00  12.7%  19.5    6s
# H 4985  1032                    3294611.9914 2875823.00  12.7%  19.5    6s
# * 5342  1064              54    3291737.2008 2899120.07  11.9%  19.9    6s
# * 5344  1051              55    3289950.4529 2899120.07  11.9%  19.8    6s
# * 5346  1049              56    3289681.2627 2899120.07  11.9%  19.8    6s
# * 5349  1049              58    3289481.2972 2899120.07  11.9%  19.8    6s
# * 5353  1049              61    3289477.2713 2899120.07  11.9%  19.8    6s
# * 5573  1097              89    3289477.1811 2903944.31  11.7%  19.8    6s
# * 5576  1097              87    3289477.1764 2903944.31  11.7%  19.8    6s
# * 5577  1097              86    3289477.1714 2903944.31  11.7%  19.8    6s
# * 5855  1194              51    3287292.0847 2907730.23  11.5%  20.0    6s
# * 5864  1190              59    3286325.5230 2907730.23  11.5%  20.0    6s
# * 5871  1190              65    3286287.7475 2907730.23  11.5%  20.0    6s
# * 5879  1190              71    3286286.0349 2907730.23  11.5%  20.0    6s
# * 5888  1190              78    3286285.9871 2907730.23  11.5%  20.0    6s
# * 6052  1260             101    3286285.9836 2914098.06  11.3%  20.1    6s
# H 7214  1543                    3267815.4112 2938561.34  10.1%  20.7    7s
# H 8539  1968                    3267743.8965 2960669.24  9.40%  21.1    8s
# H 8540  1968                    3267743.7842 2960669.24  9.40%  21.1    8s
# H 8625  1968                    3267743.5348 2960669.24  9.40%  21.2    8s
#  11244  2852 3232305.91   46   63 3267743.53 2982168.04  8.74%  21.7   10s
# *14439  3804             108    3265092.0642 2992530.01  8.35%  22.3   11s
# H15901  4139                    3264962.0024 2995054.92  8.27%  22.7   13s
# H15904  4044                    3257892.4325 2995054.92  8.07%  22.7   13s
# H15984  4044                    3257778.6476 2995054.92  8.06%  22.7   13s
# H17266  4391                    3256173.2819 2998277.89  7.92%  23.0   14s
#  18674  5027     cutoff   39      3256173.28 3000690.08  7.85%  23.3   15s
# *20249  5339             110    3256163.2368 3003318.90  7.77%  23.4   15s
#  30478  7952     cutoff   38      3256163.24 3012826.56  7.47%  24.3   20s
#  42037 10032 3176641.68   38   68 3256163.24 3020707.83  7.23%  25.3   25s
#  54180 11737 3183113.61   40   64 3256163.24 3026881.65  7.04%  25.7   30s
#  66089 12987 3036417.29   39   64 3256163.24 3032541.18  6.87%  25.9   35s
#  77953 14016 3084147.98   38   63 3256163.24 3037936.17  6.70%  26.1   40s
#  88854 14776 infeasible   40      3256163.24 3043088.17  6.54%  26.3   45s
#  100024 15500 3138311.41   36   62 3256163.24 3048363.22  6.38%  26.4   50s
#  111988 15996     cutoff   39      3256163.24 3054606.78  6.19%  26.5   55s
#  122254 16237 3178922.51   35   15 3256163.24 3059980.77  6.02%  26.5   60s
#  132543 15992 3238430.33   44   62 3256163.24 3065727.44  5.85%  26.5   65s
#  143597 15503     cutoff   39      3256163.24 3072140.65  5.65%  26.5   70s
#  151553 15079 3170131.07   35   62 3256163.24 3077026.65  5.50%  26.5   75s
#  162090 14365 3185253.36   37   62 3256163.24 3083601.92  5.30%  26.4   80s
#  173058 13245 3173372.94   38   63 3256163.24 3092442.07  5.03%  26.3   85s
#  184146 11775 3254658.36   38   57 3256163.24 3104335.46  4.66%  26.2   90s
#  194182 10879     cutoff   35      3256163.24 3119854.27  4.19%  26.0   95s
#  203694 10029     cutoff   42      3256163.24 3135596.24  3.70%  25.9  100s
#  214733  9412     cutoff   43      3256163.24 3152647.98  3.18%  25.8  105s
#  225938  8567     cutoff   39      3256163.24 3169674.84  2.66%  25.6  110s
#  237262  7743     cutoff   42      3256163.24 3185568.19  2.17%  25.4  115s
#  249094  6886 3211717.58   47   67 3256163.24 3201922.59  1.67%  25.0  120s
#
# Cutting planes:
#   Gomory: 17
#   Cover: 3
#   Implied bound: 18
#   Projected implied bound: 4
#   Clique: 3
#   MIR: 62
#   Flow cover: 39
#   RLT: 115
#   Relax-and-lift: 9
#
# Explored 249936 nodes (6238195 simplex iterations) in 120.01 seconds (109.87 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 3.25616e+06 3.25617e+06 3.25778e+06 ... 3.26782e+06
#
# Time limit reached
# Warning: max constraint violation (1.5977e-06) exceeds tolerance
# Best objective 3.256163236814e+06, best bound 3.202589415029e+06, gap 1.6453%
#
# User-callback calls 506548, time in user-callback 0.07 sec
# CSV file exported to: Results/Mean_cost/profiles_demand_flex25_vre0.csv
# INSTALLED POWER RESULTS
# [1031.1054100642639, 1625.1190574225207, 323.0000037529628, 0.0, 2564.0000086271893]
# CSV file exported to: Results/Mean_cost/power_demand_flex25_vre0.csv
# demand_flex25_vre50
# Reading scenario data/demand_flex25_vre50.csv
# Loaded demand with size (8759, 1)
# Cost
# Demand
# (8759,)
# (8807,)
# Availability
# Try reverse
# (8808, 5)
# Number of technologies: 5
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-09-07
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 120
# Model: initialized!
#
# Demand constraint
# Renewable maximum installed capacity constraint
# Storage variable
# Availability & installed power constraint
# Availability & installed power constraint
# Curtailment definition
# Z_1 expression
# Min X_1, X_2 expression
#  Take the min of min(X_1, X_2) and X_3
#  Take the overall min
#  Take the min of min(X_1, X_2) and X_3
#  Take the overall min
# Initialize Objective
# Optimize model
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 120
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1522 rows, 985 columns and 4720 nonzeros
# Model fingerprint: 0xd068f896
# Model has 538 quadratic constraints
# Variable types: 740 continuous, 245 integer (245 binary)
# Coefficient statistics:
#   Matrix range     [9e-04, 1e+07]
#   QMatrix range    [1e+00, 2e+00]
#   QLMatrix range   [1e+00, 1e+07]
#   Objective range  [2e-03, 1e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+02, 1e+07]
#   QRHS range       [1e+07, 1e+07]
# Presolve added 4 rows and 64 columns
# Presolve time: 0.01s
# Presolved: 2489 rows, 1194 columns, 7207 nonzeros
# Presolved model has 239 bilinear constraint(s)
# Variable types: 951 continuous, 243 integer (243 binary)
#
# Root relaxation: objective 1.404957e+06, 684 iterations, 0.00 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1404957.47    0  133          - 1404957.47      -     -    0s
# H    0     0                    5.037526e+08 1404957.47   100%     -    0s
#      0     0 1937225.37    0  132 5.0375e+08 1937225.37   100%     -    0s
#      0     0 2081709.87    0  131 5.0375e+08 2081709.87   100%     -    0s
#      0     2 2081709.87    0  130 5.0375e+08 2081709.87   100%     -    0s
# H  459   486                    7.676280e+07 2081709.87  97.3%  17.2    0s
# H  471   486                    3.819632e+07 2081709.87  94.5%  18.2    0s
# H  472   486                    3.819632e+07 2081709.87  94.5%  18.5    0s
# * 1509   653             125    4506664.8853 2081709.87  53.8%  16.1    0s
# H 1751   648                    3425100.4096 2902769.80  15.3%  18.2    3s
# * 2403   906              65    3341710.1341 2919889.81  12.6%  19.4    4s
# * 2640   924              89    3327751.2153 2919889.81  12.3%  18.3    4s
# * 2718   766              90    3266532.7626 2919889.81  10.6%  18.0    4s
# * 2719   738              90    3266532.6472 2919889.81  10.6%  18.0    4s
# * 2721   711              90    3262768.4829 2919889.81  10.5%  18.0    4s
# * 2722   685              90    3260924.3662 2919889.81  10.5%  17.9    4s
# H 2771   584                    3253941.2365 2925369.51  10.1%  17.8    4s
# * 3057   558              86    3253901.3061 2951347.99  9.30%  17.5    4s
#   3161   610 3132246.20   29   85 3253901.31 2951347.99  9.30%  17.4    5s
# H 4149   629                    3242532.4193 2983373.53  7.99%  18.8    5s
# H 5186   858                    3242373.3062 2993392.53  7.68%  19.5    7s
# H 9015  1572                    3236595.9186 3106082.22  4.03%  20.2   10s
# * 9445  1699             120    3236400.9609 3106082.22  4.03%  19.7   10s
# H13228  1585                    3235605.9700 3169469.32  2.04%  19.4   12s
# H13231  1581                    3235601.8615 3169469.32  2.04%  19.4   12s
# *13603  1919             101    3235494.4869 3169473.54  2.04%  19.0   12s
# *13606  1846             101    3234643.7002 3169473.54  2.01%  19.0   12s
# *13941  1832             100    3233968.8397 3172098.70  1.91%  18.8   12s
# *14883  1540              99    3233457.3709 3176937.87  1.75%  18.2   12s
# *16515  1817              94    3233053.3195 3186160.92  1.45%  17.6   13s
#  20144  1474     cutoff   37      3233053.32 3205345.65  0.86%  16.2   15s
# *22098  1404             106    3232731.8834 3209418.43  0.72%  15.3   15s
# *22604  1169              95    3232724.4742 3210743.59  0.68%  15.2   15s
# H31617  1635                    3232724.4582 3229174.56  0.11%  11.8   19s
# H31618  1617                    3232721.5573 3229174.56  0.11%  11.8   19s
# H31625  1617                    3232721.5400 3229174.56  0.11%  11.8   19s
#  34147  1937     cutoff   51      3232721.54 3229914.75  0.09%  11.0   20s
#  52447  4049     cutoff   52      3232721.54 3231800.25  0.03%   7.5   25s
#  73674  6397 3232458.37   51   61 3232721.54 3232254.46  0.01%   5.4   30s
#
# Cutting planes:
#   Gomory: 10
#   Implied bound: 7
#   Projected implied bound: 14
#   MIR: 57
#   Flow cover: 11
#   RLT: 93
#   Relax-and-lift: 31
#
# Explored 90951 nodes (407620 simplex iterations) in 33.91 seconds (23.33 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 3.23272e+06 3.23272e+06 3.23272e+06 ... 3.23549e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.232721540033e+06, best bound 3.232401296531e+06, gap 0.0099%
#
# User-callback calls 185235, time in user-callback 0.01 sec
# CSV file exported to: Results/Mean_cost/profiles_demand_flex25_vre50.csv
# INSTALLED POWER RESULTS
# [1073.5230215096965, 1600.058150217233, 316.9621344728511, 0.0, 2493.999070545956]
# CSV file exported to: Results/Mean_cost/power_demand_flex25_vre50.csv
# demand_flex25_vre100
# Reading scenario data/demand_flex25_vre100.csv
# Loaded demand with size (8759, 1)
# Cost
# Demand
# (8759,)
# (8807,)
# Availability
# Try reverse
# (8808, 5)
# Number of technologies: 5
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-09-07
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 120
# Model: initialized!
#
# Demand constraint
# Renewable maximum installed capacity constraint
# Storage variable
# Availability & installed power constraint
# Availability & installed power constraint
# Curtailment definition
# Z_1 expression
# Min X_1, X_2 expression
#  Take the min of min(X_1, X_2) and X_3
#  Take the overall min
#  Take the min of min(X_1, X_2) and X_3
#  Take the overall min
# Initialize Objective
# Optimize model
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 120
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1522 rows, 985 columns and 4720 nonzeros
# Model fingerprint: 0x36b137ac
# Model has 538 quadratic constraints
# Variable types: 740 continuous, 245 integer (245 binary)
# Coefficient statistics:
#   Matrix range     [9e-04, 1e+07]
#   QMatrix range    [1e+00, 2e+00]
#   QLMatrix range   [1e+00, 1e+07]
#   Objective range  [2e-03, 1e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+02, 1e+07]
#   QRHS range       [1e+07, 1e+07]
# Presolve added 4 rows and 64 columns
# Presolve time: 0.01s
# Presolved: 2489 rows, 1194 columns, 7207 nonzeros
# Presolved model has 239 bilinear constraint(s)
# Variable types: 951 continuous, 243 integer (243 binary)
#
# Root relaxation: objective 1.419421e+06, 678 iterations, 0.00 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1419420.59    0  134          - 1419420.59      -     -    0s
# H    0     0                    8.213456e+08 1419420.59   100%     -    0s
#      0     0 1866794.57    0  134 8.2135e+08 1866794.57   100%     -    0s
# H    0     0                    4.938468e+08 1866794.57   100%     -    0s
#      0     0 1866794.57    0  134 4.9385e+08 1866794.57   100%     -    0s
#      0     0 2085770.26    0  134 4.9385e+08 2085770.26   100%     -    0s
#      0     2 2085770.26    0  131 4.9385e+08 2085770.26   100%     -    0s
# H   93    96                    4.751997e+08 2085770.26   100%  18.6    0s
# H  139   141                    4.727732e+08 2085770.26   100%  13.3    0s
# H  455   502                    3.988852e+08 2085770.26  99.5%  11.7    0s
# H  463   502                    3.251960e+08 2085770.26  99.4%  11.5    0s
# H  778   587                    1.356907e+07 2085770.26  84.6%  13.8    0s
#   1602  1237 2893177.71   24   66 1.3569e+07 2709959.74  80.0%  18.7    5s
# * 2146  1423              57    6200360.5999 2709959.74  56.3%  21.5    5s
# * 2206  1339              58    4482115.6785 2709959.74  39.5%  21.4    5s
# * 2244  1273              62    3949173.6185 2709959.74  31.4%  21.3    5s
# * 2293  1139              67    3367215.2570 2709959.74  19.5%  21.2    5s
# * 2327  1087              80    3339717.5890 2709959.74  18.9%  21.3    5s
# * 2373  1002              87    3334661.2462 2709959.74  18.7%  21.3    5s
# * 2464   940             101    3334199.9553 2709959.74  18.7%  21.3    5s
# * 2953   760             106    3282281.2492 2778242.26  15.4%  24.0    6s
# H 3267   687                    3277674.5110 2811045.92  14.2%  25.4    6s
# * 3773   648              53    3273693.2704 2870523.39  12.3%  26.8    6s
# * 3784   648              59    3273350.6823 2870523.39  12.3%  26.8    6s
# * 3792   648              62    3273301.5659 2870523.39  12.3%  26.7    6s
# * 3884   702              63    3273281.7544 2870523.39  12.3%  27.0    7s
# * 3888   702              63    3273268.3565 2870523.39  12.3%  27.0    7s
# H 4965  1020                    3265095.2646 2917220.77  10.7%  29.7    8s
# H 4965   964                    3246415.8619 2917220.77  10.1%  29.7    8s
#   6134  1332 2991806.50   38   65 3246415.86 2938628.66  9.48%  31.6   10s
# H 6158  1332                    3246391.2871 2938628.66  9.48%  31.6   10s
# H 6159  1332                    3246391.2860 2938628.66  9.48%  31.6   10s
# H 6161  1332                    3246391.2841 2938628.66  9.48%  31.7   10s
# * 6854  1583              97    3242987.8398 2946049.27  9.16%  32.5   10s
# H 7508  1757                    3238789.9512 2954093.90  8.79%  33.6   11s
# H10064  2721                    3233129.5248 2963470.23  8.34%  34.5   13s
# H10067  2712                    3232518.6345 2963470.23  8.32%  34.5   13s
# H10070  2712                    3232431.9543 2963470.23  8.32%  34.5   13s
# *12640  3964             119    3231881.7578 2970498.32  8.09%  33.0   14s
# *12650  2962             121    3226244.7935 2970498.32  7.93%  33.0   14s
#  12686  2740 3066159.94   41   64 3226244.79 2970531.80  7.93%  33.0   15s
# H14002  2799                    3219562.2018 2976228.53  7.56%  34.5   17s
# H14064  2739                    3218600.7831 2976228.53  7.53%  34.6   17s
#  17647  3378     cutoff   48      3218600.78 2985516.79  7.24%  38.0   20s
#  24216  4079     cutoff   41      3218600.78 2998661.30  6.83%  41.6   25s
# H27314  4305                    3218600.7819 3004957.61  6.64%  42.8   28s
# H29057  4460                    3218423.3273 3007796.55  6.54%  43.2   29s
#  29369  4554 3211644.84   42   19 3218423.33 3008351.88  6.53%  43.3   30s
# H30404  4589                    3218402.8994 3010536.53  6.46%  43.6   31s
#  35608  4752 3054680.32   30   65 3218402.90 3020884.99  6.14%  44.8   35s
#  42247  4890     cutoff   41      3218402.90 3032647.63  5.77%  45.8   40s
#  48649  4715 3204056.36   46   17 3218402.90 3046618.15  5.34%  46.6   45s
#  55105  4111     cutoff   40      3218402.90 3063078.78  4.83%  47.4   50s
#  61407  3129     cutoff   39      3218402.90 3087951.45  4.05%  48.2   55s
#  68319  2123     cutoff   45      3218402.90 3150422.49  2.11%  48.6   60s
#  76118  1619 3191865.19   51   62 3218402.90 3189044.89  0.91%  46.2   65s
#  85137  1194     cutoff   66      3218402.90 3207785.68  0.33%  43.1   70s
# *89804  1284             103    3218402.6337 3212522.82  0.18%  41.0   71s
# H90290  1334                    3218396.8527 3213553.25  0.15%  40.8   72s
# H93247  1599                    3218383.6468 3214842.35  0.11%  39.6   73s
# *94930  1726             113    3218377.4709 3215563.83  0.09%  38.9   73s
#  98185  2076     cutoff   57      3218377.47 3216436.67  0.06%  37.7   75s
#  115769  4636 3218267.92   67   62 3218377.47 3217654.28  0.02%  32.1   80s
# H121179  5253                    3218374.4584 3217728.80  0.02%  30.7   81s
# *122361  5301             111    3218374.2055 3217759.09  0.02%  30.4   81s
#  135236  6384     cutoff   72      3218374.21 3217951.97  0.01%  27.5   85s
#
# Cutting planes:
#   Gomory: 14
#   Cover: 8
#   Implied bound: 3
#   Projected implied bound: 3
#   Clique: 1
#   MIR: 64
#   Flow cover: 57
#   RLT: 348
#   Relax-and-lift: 10
#   PSD: 2
#
# Explored 147528 nodes (3727214 simplex iterations) in 88.19 seconds (79.04 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 3.21837e+06 3.21837e+06 3.21838e+06 ... 3.2186e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Warning: max constraint violation (1.6124e-06) exceeds tolerance
# Best objective 3.218374205534e+06, best bound 3.218052689033e+06, gap 0.0100%
#
# User-callback calls 300818, time in user-callback 0.02 sec
# CSV file exported to: Results/Mean_cost/profiles_demand_flex25_vre100.csv
# INSTALLED POWER RESULTS
# [1114.30435644546, 1581.1625577060347, 309.99139743420096, 0.0, 2445.4429057861735]
# CSV file exported to: Results/Mean_cost/power_demand_flex25_vre100.csv
# demand_flex75_vre0
# Reading scenario data/demand_flex75_vre0.csv
# Loaded demand with size (8759, 1)
# Cost
# Demand
# (8759,)
# (8807,)
# Availability
# Try reverse
# (8808, 5)
# Number of technologies: 5
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-09-07
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 120
# Model: initialized!
#
# Demand constraint
# Renewable maximum installed capacity constraint
# Storage variable
# Availability & installed power constraint
# Availability & installed power constraint
# Curtailment definition
# Z_1 expression
# Min X_1, X_2 expression
#  Take the min of min(X_1, X_2) and X_3
#  Take the overall min
#  Take the min of min(X_1, X_2) and X_3
#  Take the overall min
# Initialize Objective
# Optimize model
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 120
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1522 rows, 985 columns and 4720 nonzeros
# Model fingerprint: 0x3c100b5c
# Model has 538 quadratic constraints
# Variable types: 740 continuous, 245 integer (245 binary)
# Coefficient statistics:
#   Matrix range     [9e-04, 1e+07]
#   QMatrix range    [1e+00, 2e+00]
#   QLMatrix range   [1e+00, 1e+07]
#   Objective range  [2e-03, 1e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+02, 1e+07]
#   QRHS range       [1e+07, 1e+07]
# Presolve added 4 rows and 64 columns
# Presolve time: 0.02s
# Presolved: 2489 rows, 1194 columns, 7207 nonzeros
# Presolved model has 239 bilinear constraint(s)
# Variable types: 951 continuous, 243 integer (243 binary)
#
# Root relaxation: objective 1.244510e+06, 683 iterations, 0.00 seconds (0.02 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1244510.40    0  140          - 1244510.40      -     -    0s
# H    0     0                    7.534808e+08 1400798.50   100%     -    0s
#      0     0 1475365.46    0  139 7.5348e+08 1475365.46   100%     -    0s
# H    0     0                    3.733439e+08 1475365.46   100%     -    0s
#      0     0 1546020.89    0  139 3.7334e+08 1546020.89   100%     -    0s
#      0     2 1546020.89    0  138 3.7334e+08 1546020.89   100%     -    0s
# H   54    64                    3.330481e+08 1635609.85   100%  61.3    0s
# H  455   492                    1.407336e+08 1717728.24  98.8%  14.4    0s
# H  649   676                    1.407336e+08 1717728.24  98.8%  14.2    0s
# * 1142  1071             131    8.415689e+07 1721751.89  98.0%  16.9    0s
# * 1154   589             124    4789514.7407 1721751.89  64.1%  17.1    0s
# * 1249   495             125    4779620.5154 1855038.79  61.2%  17.0    0s
# * 1254   495             127    4777982.2465 1855038.79  61.2%  17.1    0s
# * 1325   534             129    4777906.1382 1855038.79  61.2%  19.0    0s
# * 1382   556             134    4777902.1711 1855038.79  61.2%  20.3    0s
# H 1451   526                    4610827.5216 2481380.39  46.2%  20.5    4s
# H 1454   501                    3492525.9764 2614915.08  25.1%  20.4    4s
#   1466   512 2770909.86   16   70 3492525.98 2650709.09  24.1%  21.7    5s
# H 1744   601                    3389038.7338 2650709.09  21.8%  23.6    5s
# * 1816   624              53    3310001.2089 2650709.09  19.9%  24.4    5s
# * 1859   619              53    3299250.4970 2650709.09  19.7%  24.4    5s
# * 1890   587              48    3292256.9325 2650709.09  19.5%  24.5    5s
# * 1894   566              50    3288928.5330 2650709.09  19.4%  24.5    5s
# * 1933   562              70    3276387.4966 2650709.09  19.1%  24.5    5s
# * 1985   550              68    3276387.4957 2650709.09  19.1%  24.3    5s
# * 1989   531              68    3276387.4935 2650709.09  19.1%  24.2    5s
# H 2002   516                    3260682.1867 2650709.09  18.7%  24.1    5s
# H 2004   499                    3237402.8856 2650709.09  18.1%  24.1    5s
# * 2217   529              49    3227690.2250 2729049.84  15.4%  24.5    5s
# * 2222   513              53    3226069.9080 2729049.84  15.4%  24.4    5s
# * 2357   529              69    3226051.6211 2729049.84  15.4%  24.3    5s
# * 2538   659             101    3226051.5809 2739079.03  15.1%  23.6    6s
# * 2586   585             105    3188017.5912 2739079.03  14.1%  23.5    6s
# * 2594   584             109    3187176.6857 2739079.03  14.1%  23.4    6s
# * 2596   584             110    3186377.0793 2739079.03  14.0%  23.4    6s
# * 2653   635             114    3185046.7197 2739079.03  14.0%  23.3    6s
# * 2663   635             123    3185002.5903 2739079.03  14.0%  23.2    6s
# * 2757   681             138    3185000.3261 2739079.03  14.0%  22.9    6s
# H 2794   626                    3184390.5579 2749408.04  13.7%  23.2    6s
# * 2811   669             105    3184390.5522 2749408.04  13.7%  23.3    6s
# * 2815   665             106    3184358.4545 2749408.04  13.7%  23.3    6s
# * 2991   683              97    3184331.7396 2749408.04  13.7%  23.1    6s
# H 4026   913                    3183109.5466 2817038.75  11.5%  27.9    7s
# H 4028   910                    3182946.2220 2817038.75  11.5%  27.9    7s
# * 5389  1448             104    3164227.2266 2861674.85  9.56%  30.3    9s
# H 5914  1705                    3160268.3411 2869599.25  9.20%  31.5   10s
# * 6675  1990             100    3148826.6276 2875715.82  8.67%  32.1   11s
#  11251  3661 3087002.21   36   69 3148826.63 2908559.85  7.63%  36.1   15s
# H15711  4893                    3147561.0555 2922727.88  7.14%  37.9   19s
# H15720  4871                    3145458.4923 2922727.88  7.08%  37.9   19s
#  16986  5188 infeasible   32      3145458.49 2925309.93  7.00%  38.4   20s
# H16992  5188                    3145458.4912 2925355.14  7.00%  38.4   20s
#  22940  6794     cutoff   41      3145458.49 2933829.79  6.73%  40.7   25s
#  30189  7954 3001856.87   30   19 3145458.49 2941829.18  6.47%  43.0   30s
# H32505  8298                    3145455.7052 2943720.12  6.41%  43.5   32s
#  36235  8977 3001134.15   28   61 3145455.71 2946721.31  6.32%  43.9   35s
#  42544  9826 2956145.57   36   68 3145455.71 2950678.19  6.19%  45.0   40s
#  49347 10635 3106994.97   29   62 3145455.71 2954917.42  6.06%  45.9   45s
#  56873 11481 3085550.59   32   65 3145455.71 2959216.86  5.92%  46.7   50s
#  63479 12011 infeasible   35      3145455.71 2962979.59  5.80%  47.3   55s
#  70155 12446 3036283.52   31   63 3145455.71 2966250.49  5.70%  48.0   60s
#  76854 12819 3133314.19   33   67 3145455.71 2969671.12  5.59%  48.4   65s
#  83504 13013 3127017.26   30   67 3145455.71 2973129.60  5.48%  48.9   70s
#  89468 13226 3108240.93   37   66 3145455.71 2976067.21  5.39%  49.3   75s
#  96161 13433     cutoff   32      3145455.71 2979893.22  5.26%  49.7   80s
#  101534 13475     cutoff   32      3145455.71 2983035.96  5.16%  50.0   85s
#  108303 13411 infeasible   30      3145455.71 2987703.34  5.02%  50.4   90s
#  115109 13281 3142259.69   31   59 3145455.71 2992341.40  4.87%  50.8   95s
#  120933 13109 3128754.06   35   59 3145455.71 2996915.22  4.72%  51.0  100s
#  127507 12760     cutoff   37      3145455.71 3003475.11  4.51%  51.3  105s
#  133885 12179 3115825.42   38   63 3145455.71 3011416.60  4.26%  51.5  110s
#  140615 11446 3097988.05   34   66 3145455.71 3023641.60  3.87%  51.7  115s
#  147453 10873 3133712.56   31   53 3145455.71 3037807.20  3.42%  51.7  120s
#
# Cutting planes:
#   Gomory: 3
#   Cover: 4
#   Implied bound: 2
#   Projected implied bound: 6
#   Clique: 4
#   MIR: 70
#   Flow cover: 21
#   RLT: 371
#   Relax-and-lift: 28
#
# Explored 148119 nodes (7657961 simplex iterations) in 120.01 seconds (120.54 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 3.14546e+06 3.14546e+06 3.14546e+06 ... 3.18433e+06
#
# Time limit reached
# Warning: max constraint violation (1.5344e-06) exceeds tolerance
# Best objective 3.145455705215e+06, best bound 3.039348071550e+06, gap 3.3734%
#
# User-callback calls 302025, time in user-callback 0.03 sec
# CSV file exported to: Results/Mean_cost/profiles_demand_flex75_vre0.csv
# INSTALLED POWER RESULTS
# [716.460957609175, 1749.1802088448078, 300.3699304659347, 0.0, 2406.3569674596515]
# CSV file exported to: Results/Mean_cost/power_demand_flex75_vre0.csv
# demand_flex75_vre50
# Reading scenario data/demand_flex75_vre50.csv
# Loaded demand with size (8759, 1)
# Cost
# Demand
# (8759,)
# (8807,)
# Availability
# Try reverse
# (8808, 5)
# Number of technologies: 5
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-09-07
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 120
# Model: initialized!
#
# Demand constraint
# Renewable maximum installed capacity constraint
# Storage variable
# Availability & installed power constraint
# Availability & installed power constraint
# Curtailment definition
# Z_1 expression
# Min X_1, X_2 expression
#  Take the min of min(X_1, X_2) and X_3
#  Take the overall min
#  Take the min of min(X_1, X_2) and X_3
#  Take the overall min
# Initialize Objective
# Optimize model
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 120
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1522 rows, 985 columns and 4720 nonzeros
# Model fingerprint: 0x57c4e2cc
# Model has 538 quadratic constraints
# Variable types: 740 continuous, 245 integer (245 binary)
# Coefficient statistics:
#   Matrix range     [9e-04, 1e+07]
#   QMatrix range    [1e+00, 2e+00]
#   QLMatrix range   [1e+00, 1e+07]
#   Objective range  [2e-03, 1e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+02, 1e+07]
#   QRHS range       [1e+07, 1e+07]
# Presolve added 4 rows and 64 columns
# Presolve time: 0.01s
# Presolved: 2489 rows, 1194 columns, 7207 nonzeros
# Presolved model has 239 bilinear constraint(s)
# Variable types: 951 continuous, 243 integer (243 binary)
#
# Root relaxation: objective 1.265456e+06, 661 iterations, 0.00 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1265456.29    0  139          - 1265456.29      -     -    0s
# H    0     0                    7.195382e+08 1265456.29   100%     -    0s
#      0     0 1695153.49    0  139 7.1954e+08 1695153.49   100%     -    0s
# H    0     0                    3.480162e+08 1695153.49   100%     -    0s
#      0     0 1695153.49    0  139 3.4802e+08 1695153.49   100%     -    0s
#      0     0 1695153.49    0  138 3.4802e+08 1695153.49   100%     -    0s
#      0     0 1695153.49    0  130 3.4802e+08 1695153.49   100%     -    0s
#      0     0 1695153.49    0  127 3.4802e+08 1695153.49   100%     -    0s
#      0     0 1695156.18    0  127 3.4802e+08 1695156.18   100%     -    0s
#      0     0 1841386.57    0  127 3.4802e+08 1841386.57  99.5%     -    0s
#      0     2 1841386.57    0  123 3.4802e+08 1841386.57  99.5%     -    0s
# H  378   423                    3.480162e+08 1841386.57  99.5%  12.6    0s
# *  412   423              45    4163324.6281 1841386.57  55.8%  13.4    0s
# *  417   423              47    4162255.5991 1841386.57  55.8%  13.5    0s
# H 1461   927                    3459715.0484 2454886.62  29.0%  20.1    2s
# H 1469   886                    3326155.3632 2609002.08  21.6%  20.0    3s
# * 2095   987              56    3317927.6356 2661889.41  19.8%  26.1    4s
#   2235  1043 infeasible   47      3317927.64 2661889.41  19.8%  25.7    5s
# * 2256   994             104    3317374.3542 2661889.41  19.8%  25.7    5s
# * 2258   954             103    3317345.2494 2661889.41  19.8%  25.7    5s
# * 2259   915             102    3317314.5974 2661889.41  19.8%  25.7    5s
# * 2260   878             101    3317282.3322 2661889.41  19.8%  25.7    5s
# * 2312   848              89    3316733.4228 2674853.58  19.4%  25.9    5s
# * 2343   784              52    3289979.2428 2674853.58  18.7%  25.9    5s
# * 2346   752              54    3250274.2843 2674853.58  17.7%  25.9    5s
# * 2348   723              55    3234538.2639 2674853.58  17.3%  25.8    5s
# * 2350   694              56    3227552.1690 2674853.58  17.1%  25.8    5s
# * 2352   666              57    3224352.5653 2674853.58  17.0%  25.8    5s
# * 2399   632              62    3224234.8998 2674853.58  17.0%  25.7    5s
# * 2402   607              64    3224178.0910 2674853.58  17.0%  25.7    5s
# * 2404   583              65    3224175.2510 2674853.58  17.0%  25.7    5s
# * 2508   545              83    3224174.4392 2674853.58  17.0%  25.4    5s
# * 2509   524              82    3224174.4040 2674853.58  17.0%  25.4    5s
# * 2510   505              81    3224174.3670 2674853.58  17.0%  25.4    5s
# H 2627   542                    3224173.8243 2674853.58  17.0%  25.3    5s
# * 2749   584              56    3214442.2174 2677815.95  16.7%  25.4    5s
# * 2758   584              63    3214136.5108 2677815.95  16.7%  25.3    5s
# * 2763   584              65    3214063.3540 2677815.95  16.7%  25.3    5s
# * 2770   584              69    3214057.0217 2677815.95  16.7%  25.2    5s
# * 2846   602              68    3214052.8164 2677815.95  16.7%  24.9    5s
# * 2847   602              67    3214045.8187 2677815.95  16.7%  24.9    5s
# * 2901   619              95    3198094.6761 2702147.94  15.5%  24.8    5s
# * 2905   618              98    3196676.2270 2702147.94  15.5%  24.8    5s
# * 2907   618              99    3196605.1895 2702147.94  15.5%  24.8    5s
# * 3058   704             128    3196603.8867 2702147.94  15.5%  24.4    5s
# * 3100   689              50    3194946.8092 2708541.51  15.2%  24.5    5s
# * 3102   683              51    3193760.0537 2708541.51  15.2%  24.5    5s
# * 3201   789              55    3193636.5064 2708541.51  15.2%  24.4    5s
# * 3202   789              55    3193587.5819 2708541.51  15.2%  24.4    5s
# * 3203   789              54    3193519.2551 2708541.51  15.2%  24.4    5s
# * 3204   789              53    3193423.8048 2708541.51  15.2%  24.4    5s
# * 3737  1020              59    3193026.1294 2729427.25  14.5%  24.1    6s
# * 3739  1019              60    3192293.0543 2729427.25  14.5%  24.1    6s
# * 3742  1018              62    3191967.8974 2729427.25  14.5%  24.0    6s
# * 3744  1018              63    3191952.0024 2729427.25  14.5%  24.0    6s
# * 3746  1018              64    3191948.7421 2729427.25  14.5%  24.0    6s
# * 4029  1170              80    3157688.3499 2736408.10  13.3%  23.4    6s
# * 4632  1534             107    3140140.3815 2736997.70  12.8%  22.5    6s
# * 4638  1532             110    3136051.8413 2736997.70  12.7%  22.5    6s
# * 4639  1513             110    3130459.5157 2736997.70  12.6%  22.4    6s
# * 5833  1885             105    3119259.1038 2757923.01  11.6%  21.1    7s
# * 6148  1639             105    3112041.5006 2762459.67  11.2%  20.9    7s
# * 6668  1933              83    3109763.0991 2772913.92  10.8%  20.8    8s
#   9722  3316 3048866.99   46   72 3109763.10 2801258.64  9.92%  21.5   10s
# H20451  7652                    3107942.6659 2850194.56  8.29%  23.0   15s
# H20466  7616                    3104054.3748 2850194.56  8.18%  23.0   16s
# H20467  7551                    3099176.6329 2850194.56  8.03%  23.0   16s
# H20468  7460                    3093334.6541 2850194.56  7.86%  23.0   16s
#  25988  9754 2864955.65   26   71 3093334.65 2860346.19  7.53%  23.5   20s
#  35770 12774 3035958.94   49   17 3093334.65 2871635.10  7.17%  24.1   25s
#  47190 16007 2926312.98   40   67 3093334.65 2881090.28  6.86%  24.4   30s
#  57451 18908 3011988.87   45   16 3093334.65 2886989.32  6.67%  24.6   35s
#  68407 21624     cutoff   41      3093334.65 2891827.97  6.51%  24.9   40s
#  79665 24126     cutoff   43      3093334.65 2895594.08  6.39%  25.1   45s
#  91125 26615 2916916.14   42   64 3093334.65 2898338.23  6.30%  25.1   50s
#  102753 29104 3068308.21   49   15 3093334.65 2901015.86  6.22%  25.2   55s
#  113383 31353 3086765.51   52   63 3093334.65 2902907.10  6.16%  25.3   60s
#  123461 33519 3055090.94   50   13 3093334.65 2904560.26  6.10%  25.5   65s
#  134869 35875 2924279.65   39   63 3093334.65 2906217.30  6.05%  25.5   70s
#  145300 37693     cutoff   53      3093334.65 2907599.98  6.00%  25.6   75s
#  156703 39610 3082273.06   49   62 3093334.65 2909123.70  5.96%  25.7   80s
#  165328 40822 3075593.12   48   18 3093334.65 2910225.91  5.92%  25.8   85s
# H165333 40767                    3092933.9205 2910225.91  5.91%  25.8   85s
# H165334 40752                    3092833.9235 2910225.91  5.90%  25.8   85s
# H165487 40720                    3092602.3590 2910225.91  5.90%  25.8   85s
#  175104 42477 3028785.52   41   64 3092602.36 2911423.75  5.86%  25.9   90s
#  185330 44229 3014635.10   47   66 3092602.36 2912450.65  5.83%  26.0   95s
#  195694 45821 2948422.23   42   62 3092602.36 2913542.72  5.79%  26.0  100s
#  207716 47677 2983846.45   42   66 3092602.36 2914874.65  5.75%  26.1  105s
#  218035 49034 2986650.00   39   63 3092602.36 2915847.18  5.72%  26.2  110s
#  229215 50610     cutoff   54      3092602.36 2916950.78  5.68%  26.2  115s
#  238850 51935     cutoff   43      3092602.36 2917774.97  5.65%  26.3  120s
#
# Cutting planes:
#   Gomory: 4
#   Cover: 18
#   Implied bound: 6
#   Projected implied bound: 9
#   MIR: 67
#   Flow cover: 45
#   RLT: 393
#   Relax-and-lift: 27
#   BQP: 4
#
# Explored 239932 nodes (6305990 simplex iterations) in 120.01 seconds (114.06 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 3.0926e+06 3.09283e+06 3.09293e+06 ... 3.11926e+06
#
# Time limit reached
# Best objective 3.092602359043e+06, best bound 2.917860529537e+06, gap 5.6503%
#
# User-callback calls 489140, time in user-callback 0.04 sec
# CSV file exported to: Results/Mean_cost/profiles_demand_flex75_vre50.csv
# INSTALLED POWER RESULTS
# [822.3048796798255, 1664.7808699799023, 306.37905556487544, 0.0, 2256.7595232455888]
# CSV file exported to: Results/Mean_cost/power_demand_flex75_vre50.csv
# demand_flex75_vre100
# Reading scenario data/demand_flex75_vre100.csv
# Loaded demand with size (8759, 1)
# Cost
# Demand
# (8759,)
# (8807,)
# Availability
# Try reverse
# (8808, 5)
# Number of technologies: 5
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-09-07
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 120
# Model: initialized!
#
# Demand constraint
# Renewable maximum installed capacity constraint
# Storage variable
# Availability & installed power constraint
# Availability & installed power constraint
# Curtailment definition
# Z_1 expression
# Min X_1, X_2 expression
#  Take the min of min(X_1, X_2) and X_3
#  Take the overall min
#  Take the min of min(X_1, X_2) and X_3
#  Take the overall min
# Initialize Objective
# Optimize model
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 120
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1522 rows, 985 columns and 4720 nonzeros
# Model fingerprint: 0x5d9a38b3
# Model has 538 quadratic constraints
# Variable types: 740 continuous, 245 integer (245 binary)
# Coefficient statistics:
#   Matrix range     [9e-04, 1e+07]
#   QMatrix range    [1e+00, 2e+00]
#   QLMatrix range   [1e+00, 1e+07]
#   Objective range  [2e-03, 1e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+02, 1e+07]
#   QRHS range       [1e+07, 1e+07]
# Presolve added 4 rows and 64 columns
# Presolve time: 0.01s
# Presolved: 2489 rows, 1194 columns, 7207 nonzeros
# Presolved model has 239 bilinear constraint(s)
# Variable types: 951 continuous, 243 integer (243 binary)
#
# Root relaxation: objective 1.310953e+06, 663 iterations, 0.00 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1310952.93    0  139          - 1310952.93      -     -    0s
# H    0     0                    6.630218e+08 1310952.93   100%     -    0s
#      0     0 1728618.57    0  140 6.6302e+08 1728618.57   100%     -    0s
# H    0     0                    3.300915e+08 1728618.57  99.5%     -    0s
#      0     0 1811285.41    0  140 3.3009e+08 1811285.41  99.5%     -    0s
#      0     0 1811285.41    0  141 3.3009e+08 1811285.41  99.5%     -    0s
#      0     0 1940477.01    0  129 3.3009e+08 1940477.01  99.4%     -    0s
#      0     0 1940477.01    0  130 3.3009e+08 1940477.01  99.4%     -    0s
#      0     0 1940477.01    0  122 3.3009e+08 1940477.01  99.4%     -    0s
#      0     0 1940477.01    0  120 3.3009e+08 1940477.01  99.4%     -    0s
#      0     0 1940477.01    0  121 3.3009e+08 1940477.01  99.4%     -    0s
#      0     0 1940477.01    0  121 3.3009e+08 1940477.01  99.4%     -    0s
# H    0     0                    2.943392e+08 1940477.01  99.3%     -    0s
#      0     0 1940477.01    0  121 2.9434e+08 1940477.01  99.3%     -    0s
#      0     2 1940477.01    0  119 2.9434e+08 1940477.01  99.3%     -    0s
# H  278   301                    2.941963e+08 1940477.01  99.3%  12.9    0s
# H  299   301                    2.295411e+08 1940477.01  99.2%  12.4    0s
# H  603   488                    1.065467e+07 1940477.01  81.8%  12.8    0s
# *  717   487              91    1.065467e+07 1940477.01  81.8%  14.1    0s
# *  718   487              91    1.065467e+07 1940477.01  81.8%  14.1    0s
# H 1478   869                    8731788.3479 2529577.50  71.0%  17.6    4s
# H 1478   825                    3295024.5147 2529577.50  23.2%  17.6    4s
#   1605   873 2873727.38   32   64 3295024.51 2715406.64  17.6%  21.2    5s
# * 2328   905              78    3247022.3361 2727405.50  16.0%  24.6    6s
# * 2331   865              80    3243379.2079 2727405.50  15.9%  24.6    6s
# * 2370   830              80    3240960.3420 2736045.87  15.6%  24.9    6s
# * 2371   795              79    3236880.7517 2736045.87  15.5%  24.9    6s
# * 2594   765              90    3138600.5671 2743667.56  12.6%  25.3    6s
# * 3568   988              72    3138600.5507 2774172.55  11.6%  27.0    7s
# * 3717  1129              72    3138600.5349 2774172.55  11.6%  26.5    7s
# * 4342  1507              85    3128367.1562 2779408.52  11.2%  24.4    7s
# * 4352  1489              90    3125831.0522 2779408.52  11.1%  24.3    7s
# * 4557  1460             116    3094805.4794 2779408.52  10.2%  24.3    8s
# * 4558  1454             117    3091106.3455 2779408.52  10.1%  24.3    8s
# * 5224  1357             104    3071202.2252 2804090.79  8.70%  25.1    8s
# * 5234  1340             111    3062531.0453 2804090.79  8.44%  25.1    8s
# * 5694  1467             108    3055946.4842 2810139.58  8.04%  25.6    8s
# * 5701  1463             108    3055483.7920 2810139.58  8.03%  25.6    8s
# H 5765  1509                    3051186.3313 2810139.58  7.90%  25.8    8s
#   6870  1896 infeasible   49      3051186.33 2820273.35  7.57%  27.4   10s
# H 6911  1858                    3050220.9365 2820273.35  7.54%  27.4   10s
# H 9983  3019                    3049658.7391 2840349.16  6.86%  30.6   12s
# *11074  3470             127    3048826.5212 2843595.90  6.73%  31.3   13s
# *12322  3795             136    3043060.9693 2845531.77  6.49%  31.6   14s
# *12325  3793             137    3042968.4885 2845531.77  6.49%  31.6   14s
# *12327  3788             138    3042705.2973 2845531.77  6.48%  31.6   14s
#  13828  4265     cutoff   46      3042705.30 2848228.04  6.39%  32.5   16s
# H13829  4191                    3042584.3378 2848228.04  6.39%  32.5   16s
# H13854  4158                    3041325.0722 2848228.04  6.35%  32.5   16s
# H18128  5529                    3041325.0312 2853108.67  6.19%  36.2   19s
#  18749  5720     cutoff   46      3041325.03 2853985.68  6.16%  37.1   20s
# H19394  5721                    3041248.1400 2854133.55  6.15%  37.8   20s
# H19405  5721                    3041247.7524 2854671.87  6.13%  37.8   20s
# H19430  5721                    3041245.0669 2854903.55  6.13%  38.5   20s
#  25353  7382     cutoff   42      3041245.07 2860081.88  5.96%  40.3   25s
#  33197  9026     cutoff   48      3041245.07 2865603.83  5.78%  41.5   30s
#  40785 10309 3025081.62   46   20 3041245.07 2869578.08  5.64%  42.8   35s
#  47539 11227 3021568.35   49   64 3041245.07 2873301.94  5.52%  43.6   40s
#  55135 12225 infeasible   43      3041245.07 2876685.79  5.41%  44.3   45s
#  62531 13080 infeasible   43      3041245.07 2880177.51  5.30%  45.1   50s
#  69313 13694 2888412.25   34   66 3041245.07 2883026.66  5.20%  45.6   55s
#  76846 14227 2923363.64   42   22 3041245.07 2886102.76  5.10%  46.3   60s
#  83495 14640 infeasible   41      3041245.07 2889142.12  5.00%  46.8   65s
#  90253 14996 2897847.38   35   64 3041245.07 2892336.52  4.90%  47.2   70s
#  96552 15172 2896554.93   39   65 3041245.07 2895125.28  4.80%  47.5   75s
#  104142 15315 2970990.35   44   26 3041245.07 2899351.13  4.67%  47.9   80s
#  110814 15256 2966541.83   42   65 3041245.07 2903720.27  4.52%  48.2   85s
#  116836 15124 infeasible   45      3041245.07 2907057.59  4.41%  49.1   90s
#  118026 15179 infeasible   40      3041245.07 2907057.59  4.41%  57.5   95s
#  119229 15093 2971110.97   42   60 3041245.07 2907057.59  4.41%  64.6  100s
#  121904 14922     cutoff   43      3041245.07 2907057.59  4.41%  67.0  105s
#  129096 14567 infeasible   40      3041245.07 2918772.76  4.03%  66.4  110s
#  136263 14153 infeasible   50      3041245.07 2927127.32  3.75%  65.8  115s
#  143707 13654 3040636.57   47   62 3041245.07 2936448.23  3.45%  65.1  120s
#
# Cutting planes:
#   Gomory: 9
#   Cover: 4
#   Implied bound: 7
#   MIR: 50
#   Flow cover: 81
#   RLT: 195
#   Relax-and-lift: 9
#
# Explored 143772 nodes (9361825 simplex iterations) in 120.00 seconds (135.06 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 3.04125e+06 3.04125e+06 3.04125e+06 ... 3.04883e+06
#
# Time limit reached
# Best objective 3.041245066932e+06, best bound 2.936448225453e+06, gap 3.4459%
#
# User-callback calls 294578, time in user-callback 0.03 sec
# CSV file exported to: Results/Mean_cost/profiles_demand_flex75_vre100.csv
# INSTALLED POWER RESULTS
# [930.670468355554, 1624.6370036491535, 268.46685630702115, 0.0, 2117.8112167007057]
# CSV file exported to: Results/Mean_cost/power_demand_flex75_vre100.csv
