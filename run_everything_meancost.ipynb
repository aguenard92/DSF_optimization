# %%
# Introduction of the packages
using Pkg
Pkg.add("CSV")
Pkg.add("DataFrames")
Pkg.add("JuMP")
Pkg.add("Gurobi")
#Pkg.add("NLopt")

using CSV, DataFrames, JuMP, Gurobi
# Out:
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.9/Project.toml`
#   No Changes to `~/.julia/environments/v1.9/Manifest.toml`
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.9/Project.toml`
#   No Changes to `~/.julia/environments/v1.9/Manifest.toml`
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.9/Project.toml`
#   No Changes to `~/.julia/environments/v1.9/Manifest.toml`
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.9/Project.toml`
#   No Changes to `~/.julia/environments/v1.9/Manifest.toml`

# %%
# Read the CSVs
SCALE_MWH = 1000
SCALE_DOLLAR = 1000

# CHANGE THIS FOR HIGH COST SCENARIO
scenario = "mean" # "max" or "mean"

fixed_cost = CSV.read("data/fixed_cost_"*scenario*".csv",DataFrame) ./ SCALE_DOLLAR
variable_cost = CSV.read("data/variable_cost_"*scenario*".csv",DataFrame) ./ SCALE_DOLLAR
co2_intensity = CSV.read("data/co2_intensity.csv",DataFrame)
curtailment_costs = [0, 2, 0, 0, 0, 0] ./ SCALE_DOLLAR
ramp_limits = CSV.read("data/ramp_limits.csv", DataFrame)

# AVAILABILITY
P_max_s = 95897829.43 / SCALE_MWH
P_max_w = 11158008 / SCALE_MWH;

Availability_matrix = CSV.read("data/Availability.csv", DataFrame);
println(size(Availability_matrix))

############### Constants of the model 

eta = 0.8; # Efficiency of the battery
CO2_price = 100; # price of the CO2 per ton
H = 2;

################ Time to consider

# T = 50
# T_start = 987
# println("Timespan: ", T)
# println("Starting at hour: ", T_start)
# time_ls_opt = 1:T
# time_ls_clipped = 2:T-1 # For rate of change calculations

T = 50
T_start = 4960
time_ls_opt = T_start-24:T_start+24


hrs = 4000
hre = 5000
sel_hrs = hrs:hre
println(sel_hrs)
techs = 5
n_eu = 4
# pad year by 1 day
add_h = 24


println("Timespan: ", T)
#time_ls = 1+add_h:T-add_h
time_ls = T_start-24+1:T_start+24-add_h
vre_ls = 1:2
fossil_ls = 3:4
batt_ind = 5;
# Out:
# (8760, 5)
# 4000:5000
# Timespan: 50

# %%
######## Need to create a loop on that ========

name_demand_flex_input = [
    "demand_flex0_vre0", 
    "demand_flex50_vre0", 
    "demand_flex50_vre50", 
    "demand_flex50_vre100", 
    "demand_flex100_vre0", 
    "demand_flex100_vre50",
    "demand_flex100_vre100"
    ]
println("Starting Loop")
for name in name_demand_flex_input
    println(name)
    file_to_read = "data/"*name*".csv"
    println("Reading scenario $file_to_read")

    demand = Matrix(CSV.read(file_to_read, DataFrame)) ./ SCALE_MWH;
    println("Loaded demand with size ", size(demand))

    #######################################

    println("Cost")
    C_FC = fixed_cost[1:techs,1]
    C_FOM = fixed_cost[1:techs,2]
    C_VOM = variable_cost[1:techs,1]
    E_CO2 = co2_intensity[1:techs,1]
    C_ramp = variable_cost[1:techs,2]
    C_start = variable_cost[1:techs,3]
    C_curt = curtailment_costs[1:techs]

    println("Demand")
    D_b = demand[:] # Baseline demand with no flex
    println(size(D_b))
    D_b = vcat(reverse(reverse(demand)[1:add_h]), D_b, D_b[1:24])
    println(size(D_b))
    total_demand = D_b
    X_D = D_b

    A_r = ramp_limits[1:techs, 1]
    println("Availability")
    A_s = Availability_matrix[:,1:techs]
    println("Try reverse")
    A_s = vcat(reverse(reverse(Availability_matrix)[1:add_h, 1:techs]), A_s, A_s[1:24, 1:techs])
    println(size(A_s))
    # over time, opt each year with worst day for availability and highest demand?

    n = size(C_FC, 1) # number of technologies
    println("Number of technologies: ", n)

    ###### MODEL ######

    model = Model(Gurobi.Optimizer) # TODO: options? other optimizers?
    set_optimizer_attribute(model, "NonConvex", 2)
    #set_optimizer_attribute(model, "IterationLimit", 10000000)
    set_optimizer_attribute(model, "TimeLimit", 120)
    println("Model: initialized!\n")

    ###### MAIN VARIABLES ######
    # Non-negativity constraints
    # The installed power capacity of the mix
    @variable(model, P[1:n] >= 0)

    # The hourly power generation of each technology
    @variable(model, X_gen[time_ls_opt, 1:n] >= 0); # hourly production/use for each technology

    # Curtailment (only renewables?)
    @variable(model, X_cur[time_ls_opt, 1:n] >= 0); # hourly production/use for each technology

    ###### CONSTRAINTS ######

    # Demand constraint - meet demand per hour
    println("Demand constraint")
    @constraint(model, Con_dh[t = time_ls_opt], sum(X_gen[t, i] for i in 1:n) >= X_D[t]); # TODO: add curtailment
    # Meet total demand
    # @constraint(model, Con_d, sum(X_gen[t, i] for i in 1:n for t in time_ls_opt) >= sum(total_demand));

    # Installed capacity renewables < max capacity
    println("Renewable maximum installed capacity constraint")
    @constraint(model, Con_sgen, P[1] <= P_max_s);
    @constraint(model, Con_wgen, P[2] <= P_max_w);

    # println("Renewable minimum installed capacity constraint")
    #@constraint(model, Con_solar_lb, P[1] >= 50);
    #@constraint(model, Con_wind_lb, P[2] >= 600);

    # Storage variable
    println("Storage variable")
    @variable(model, 0<= X_soc[time_ls_opt] <=1)
    @variable(model, X_ch[time_ls_opt]>=0)

    # Cannot produce more than the installed power
    # println("Installed power constraint")
    # @constraint(model, Con_p[i = 1:n, t = time_ls_opt], X_gen[t, i] <= P[i])

    # For each tech, at each hour, usage cannot exceed available capacity
    println("Availability & installed power constraint")
    @constraint(model, [i = 1:n, t = time_ls_opt], X_gen[t, i] <= P[i]*A_s[t, i])
    # Renewables produce maximum possible capacity
    @constraint(model, [i = vre_ls, t = time_ls_opt], X_gen[t, i] >= 0.7*P[i]*A_s[t, i]) 


    println("Availability & installed power constraint")
    @constraint(model, [i = 1:n, t = time_ls_opt], X_gen[t, i] <= P[i]*A_s[t, i])

    println("Curtailment definition")
    @constraint(model, [t = time_ls_opt], sum(X_cur[t, i] for i in 1:n) == sum(X_gen[t, i] for i in 1:n) - X_D[t]) 
    @constraint(model, [i = 1:n, t = time_ls_opt], X_cur[t, i] <= X_gen[t, i])

    # Cannot produce less than the minimum stable generation: X_gen must be zero or min to max
    # min_usage = [0, 0.1, 0, 0] #TODO - cant be more than ramp
    # @constraint(model, [i = 1:n, t = time_ls_opt], X_gen[t, i] >= P[i]*min_usage[i])

    # For each tech, at each hour, change in production cannot exceed ramp rate (TODO might need to convert this to time)
    # println("Ramp constraint")
    # Auxiliary variables to linearize the rate of change constraint
    # @constraint(model, Con_rdwn[i = 1:n, t = time_ls_clipped], (X_gen[t+1, i] - X_gen[t, i]) >= -A_r[i]*X_gen[t, i]) 
    # @constraint(model, Con_rup[i = 1:n, t = time_ls_clipped], (X_gen[t+1, i] - X_gen[t, i]) <= A_r[i]*X_gen[t, i]);

    M = 10000000
    
    # println("Cold Start")
    # @variable(model, Cold_start[time_ls_opt, i = 1:4], Bin)
    # @constraint(model, [i = 1:4, t in time_ls_clipped], (X_gen[t, i] - X_gen[t-1, i])*X_gen[t, i] <= M*Cold_start[t, i])
    # @constraint(model, [i = 1:4, t in time_ls_clipped], -(X_gen[t, i] - X_gen[t-1, i])*X_gen[t, i] <= M*Cold_start[t, i])

    # Storage model

    # Need to put this conditions above
    @variable(model, Z_X_gen_greater_X_D[time_ls_opt], Bin)

    @constraint(model, Z_X_gen_greater_X_D_1[t in time_ls_opt], sum(X_gen[t,i] for i in 1:4) - X_D[t] <= M*Z_X_gen_greater_X_D[t])
    @constraint(model, Z_X_gen_greater_X_D_2[t in time_ls_opt], -sum(X_gen[t,i] for i in 1:4) + X_D[t] <= M*(1-Z_X_gen_greater_X_D[t]))


    # X_1, X_2, X_3 = [eta*(sum(X_gen[t,i] for i in Power_generation_ls)- X_D[t]) , eta*P3], (1- X_soc[t])*P[5]* H]
    @variable(model, z1[t in time_ls_opt], Bin)
    @variable(model, z2[t in time_ls_opt], Bin)

    # z_1 equal 1 if eta*(x_g_t -x_d) is is greatter than eta*E_max*delta t
    println("Z_1 expression")
    @constraint(model, z_1_1[t in time_ls_opt], eta*P[5] - eta*(sum(X_gen[t,i] for i in 1:4)- X_D[t])   <=  M*z1[t])
    @constraint(model, z_1_2[t in time_ls_opt], -eta*P[5] + eta*(sum(X_gen[t,i] for i in 1:4)- X_D[t]) <= M*(1-z1[t]))


    #Minimum between X_1 and X_2
    @variable(model, min_X_1_X_2[time_ls_opt])

    println("Min X_1, X_2 expression")
    @constraint(model, X_1_X_2_lower_1[t in time_ls_opt], min_X_1_X_2[t] <= eta*(sum(X_gen[t,i] for i in 1:4)- X_D[t]))
    @constraint(model, X_1_X_2_lower_2[t in time_ls_opt], min_X_1_X_2[t] <= eta*P[5])
    @constraint(model, X_1_X_2_higher_1[t in time_ls_opt], min_X_1_X_2[t] >= eta*(sum(X_gen[t,i] for i in 1:4)- X_D[t]) - M*(1-z1[t]))
    @constraint(model, X_1_X_2_higher_2[t in time_ls_opt], min_X_1_X_2[t] >= eta*P[5] - M*z1[t])


    # z_2 equal 1 if min(X_1, X_2) is is greater than (1- x_soc[t])*h*E_max
    println(" Take the min of min(X_1, X_2) and X_3")
    @constraint(model, z_2_1[t in time_ls_opt], (1- X_soc[t])* P[5] * H - min_X_1_X_2[t] <=  M*z2[t])
    @constraint(model, z_2_2[t in time_ls_opt], - (1- X_soc[t]) * P[5] * H + min_X_1_X_2[t] <= M*(1-z2[t]))


    # Constraint for the variable X_ch
    println(" Take the overall min")
    @variable(model, min_X_1_X_2_X_3[time_ls_opt])

    @constraint(model, X_1_X_2_X_3_lower_1[t in time_ls_opt], min_X_1_X_2_X_3[t] <= min_X_1_X_2[t])
    @constraint(model, X_1_X_2_X_3_lower_2[t in time_ls_opt], min_X_1_X_2_X_3[t] <= (1- X_soc[t])*P[3]* H)
    @constraint(model, X_1_X_2_X_3_higher_1[t in time_ls_opt], min_X_1_X_2_X_3[t] >= min_X_1_X_2[t] - M*(1-z2[t]))
    @constraint(model, X_1_X_2_X_3_higher_2[t in time_ls_opt], min_X_1_X_2_X_3[t] >= (1- X_soc[t])*P[3]* H - M*z2[t]);

    #Expression of X_ch
    @constraint(model, X_ch_expression[t in time_ls_opt], X_ch[t]  == Z_X_gen_greater_X_D[t]*min_X_1_X_2_X_3[t]);
    @variable(model, y2[time_ls_opt], Bin)

    # z_2 equal 1 if min(X_1, X_2) is is greater than (1- x_soc[t])*h*E_max
    println(" Take the min of min(X_1, X_2) and X_3")
    @constraint(model, y_2_1[t in time_ls_opt], X_soc[t]* P[5] * H - P[5] <=  M*y2[t])
    @constraint(model, y_2_2[t in time_ls_opt], - X_soc[t] * P[5] * H + P[5] <= M*(1-y2[t]))

    # Constraint for the variable X_ch
    println(" Take the overall min")
    @variable(model, min_extra_prod_P5_soc[time_ls_opt])

    @constraint(model, min_extra_prod_P5_soc_lower_1[t in time_ls_opt], min_extra_prod_P5_soc[t] <= P[5])
    @constraint(model, min_extra_prod_P5_soc_lower_2[t in time_ls_opt], min_extra_prod_P5_soc[t] <= X_soc[t]*P[5]* H)
    @constraint(model, min_extra_prod_P5_soc_higher_1[t in time_ls_opt], min_extra_prod_P5_soc[t] >= P[5] - M*(1-y2[t]))
    @constraint(model, min_extra_prod_P5_soc_higher_2[t in time_ls_opt], min_extra_prod_P5_soc[t] >= X_soc[t]*P[5]* H - M*y2[t]);

    @variable(model, batt_dispatch[time_ls_opt], Bin)

    #Expression of X_dch
    @constraint(model, X_dch_expression[t in time_ls_opt], X_gen[t,5]  <= batt_dispatch[t]*min_extra_prod_P5_soc[t]);


    # First hour need to be equal to one
    # Start with a charged battery
    @constraint(model, SOC_t_1, X_soc[time_ls_opt[1]] == 0)

    #
    @constraint(model, SOC_t[t in time_ls_opt[2]:time_ls_opt[end]], (X_soc[t]-X_soc[t-1])*H*P[5] == (X_ch[t-1]- X_gen[t-1,5]));

    # MODEL OBJECTIVE FUNCTION
    #TODO RAMP AND STARTUP COSTS

    println("Initialize Objective")

    @objective(model, Min, 
        (
            sum((C_FC[i] + C_FOM[i])*P[i] for i in 1:n) + # FIXED COSTS
            sum(sum((C_VOM[i] + CO2_price* E_CO2[i])* X_gen[t, i] for i in 1:n) for t in time_ls_opt) + # VARIABLE COSTS
            sum(sum(C_curt[i] * X_cur[t, i] for i in 1:n) for t in time_ls) # CURTAILMENT COSTS
    ));

    #Optimize
    println("Optimize model")
    optimize!(model)

    # Save the results for the generation
    # Assuming your matrix is named `my_matrix`
    my_matrix = [value.(X_gen) value.(X_soc) X_D[time_ls_opt]]  # Replace this with your actual matrix
    # Column names

    column_names = ["Solar", "Wind", "CCGT", "Coal", "Battery", "State_of_Charge", "Demand"]

    # Create a DataFrame with vectors for each column
    df = DataFrame([Symbol(name) => my_matrix[:, i] for (i, name) in enumerate(column_names)])

    # Specify the file path for your CSV file
    csv_file_path = "Results/Mean_cost/profiles_" * name * ".csv"

    # Export the DataFrame to CSV
    CSV.write(csv_file_path, df)

    println("CSV file exported to: $csv_file_path")

    # Save the results for the power installed power
    # Assuming your matrix is named `my_matrix`
    Power = value.(P)   # Replace this with your actual matrix
    # Column names
    println("INSTALLED POWER RESULTS")
    println(Power)
    column_names_power = "Installed Power"

    # Create a DataFrame with vectors for each column
    df_Power = DataFrame(Symbol(column_names_power) => Power)

    # Specify the file path for your CSV file
    csv_file_path_power = "Results/Mean_cost/power_" * name * ".csv"

    # Export the DataFrame to CSV
    CSV.write(csv_file_path_power, df_Power)

    println("CSV file exported to: $csv_file_path_power")
end
# Out:
# Starting Loop
# demand_flex0_vre0
# Reading scenario data/demand_flex0_vre0.csv
# Loaded demand with size (8759, 1)
# Cost
# Demand
# (8759,)
# (8807,)
# Availability
# Try reverse
# (8808, 5)
# Number of technologies: 5
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-09-07
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 120
# Model: initialized!
#
# Demand constraint
# Renewable maximum installed capacity constraint
# Storage variable
# Availability & installed power constraint
# Availability & installed power constraint
# Curtailment definition
# Z_1 expression
# Min X_1, X_2 expression
#  Take the min of min(X_1, X_2) and X_3
#  Take the overall min
#  Take the min of min(X_1, X_2) and X_3
#  Take the overall min
# Initialize Objective
# Optimize model
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 120
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1522 rows, 985 columns and 4720 nonzeros
# Model fingerprint: 0x34341dda
# Model has 538 quadratic constraints
# Variable types: 740 continuous, 245 integer (245 binary)
# Coefficient statistics:
#   Matrix range     [9e-04, 1e+07]
#   QMatrix range    [1e+00, 2e+00]
#   QLMatrix range   [1e+00, 1e+07]
#   Objective range  [2e-03, 1e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [4e+02, 1e+07]
#   QRHS range       [1e+07, 1e+07]
# Presolve added 4 rows and 64 columns
# Presolve time: 0.01s
# Presolved: 2489 rows, 1194 columns, 7207 nonzeros
# Presolved model has 239 bilinear constraint(s)
# Variable types: 951 continuous, 243 integer (243 binary)
#
# Root relaxation: objective 1.487968e+06, 669 iterations, 0.00 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1487967.51    0  130          - 1487967.51      -     -    0s
#      0     0 1622509.76    0  131          - 1622509.76      -     -    0s
#      0     0 1689238.29    0  131          - 1689238.29      -     -    0s
#      0     0 1750566.11    0  128          - 1750566.11      -     -    0s
#      0     2 1750566.11    0  128          - 1750566.11      -     -    0s
# * 1496  1436             143    4.539752e+08 1750566.11   100%  19.2    0s
# * 1499  1436             146    4.524220e+08 1750566.11   100%  19.3    0s
# * 1582  1604             132    2.630046e+08 1750566.11  99.3%  19.6    0s
# * 1592  1599             137    2.057839e+08 1750566.11  99.1%  19.5    0s
# * 1755  1740             140    2.057791e+08 1750566.11  99.1%  18.2    0s
# * 1930  1762             146    2.057791e+08 1750566.11  99.1%  17.6    0s
# H 2316  1950                    2.057791e+08 2792530.26  98.6%  16.4    2s
# H 2322  1856                    5.013708e+07 2886049.64  94.2%  16.4    3s
# H 2322  1763                    4.097168e+07 2886049.64  93.0%  16.4    3s
# H 2322  1675                    4.097168e+07 2886049.64  93.0%  16.4    3s
# * 3150  1831              96    4645113.2716 2886049.64  37.9%  19.1    3s
# * 3151  1750              97    4643587.5598 2886049.64  37.8%  19.1    3s
# * 3248  1586              82    4413172.9038 2886049.64  34.6%  19.0    3s
# * 3295  1494              83    4352919.1537 2886049.64  33.7%  19.4    3s
# * 3296  1426              84    4350295.5915 2886049.64  33.7%  19.4    3s
# * 3298  1360              85    4350233.5481 2886049.64  33.7%  19.3    3s
# * 3301  1297              86    4349102.3593 2886049.64  33.6%  19.3    3s
# * 3302  1238              87    4349047.9709 2886049.64  33.6%  19.3    3s
# * 3440  1160              92    4330788.5316 2886049.64  33.4%  19.5    4s
# * 3441  1107              93    4328219.6851 2886049.64  33.3%  19.5    4s
# * 3444  1056              94    4326746.1776 2886049.64  33.3%  19.5    4s
# * 3498   988              97    4326710.9338 2886049.64  33.3%  19.4    4s
# * 3561   921             108    4326702.2055 2886049.64  33.3%  19.4    4s
# * 3562   877             108    4326697.7059 2886049.64  33.3%  19.4    4s
# * 3563   836             107    4326692.9695 2886049.64  33.3%  19.4    4s
# * 3604   755             106    4326687.9838 2886049.64  33.3%  19.6    4s
# * 3605   718             105    4326682.7358 2886049.64  33.3%  19.6    4s
# * 3706   658              82    4256650.7453 2886049.64  32.2%  20.0    4s
# * 3745   621              84    4205533.0191 2886049.64  31.4%  20.2    4s
# * 3748   588              83    4182345.9678 2886049.64  31.0%  20.2    4s
# * 3751   557              85    4177523.9387 2886049.64  30.9%  20.2    4s
# * 3754   528              87    4176375.6381 2886049.64  30.9%  20.2    4s
# * 3803   461             101    4176375.2543 2886049.64  30.9%  20.1    4s
# * 3804   442             101    4176375.2125 2886049.64  30.9%  20.1    4s
# * 3806   442              99    4176375.1332 2886049.64  30.9%  20.1    4s
# * 4153   578              65    4028909.1979 2886049.64  28.4%  19.8    4s
# * 4155   572              66    3900102.3012 2886049.64  26.0%  19.8    4s
# * 4157   572              67    3795016.4104 2886049.64  24.0%  19.8    4s
# * 4202   468             123    3400924.2224 2886049.64  15.1%  19.7    4s
# * 4594   482              93    3397182.6038 2966225.27  12.7%  19.5    4s
# * 4682   469             119    3397175.9720 2966225.27  12.7%  19.5    4s
# * 4683   469             119    3397175.6233 2966225.27  12.7%  19.5    4s
# * 4684   469             118    3397175.2559 2966225.27  12.7%  19.5    4s
# * 4685   469             117    3397174.8692 2966225.27  12.7%  19.5    4s
# * 4686   469             116    3397174.4621 2966225.27  12.7%  19.5    4s
# * 4853   504              87    3395618.8573 2966225.27  12.6%  19.4    4s
# * 4854   502              87    3393197.0652 2966225.27  12.6%  19.4    4s
# * 4856   498              87    3388222.4298 2966225.27  12.5%  19.4    4s
# * 4858   492              88    3385290.8102 2966225.27  12.4%  19.4    4s
#   5108   625 2975224.90   22   70 3385290.81 2968034.90  12.3%  19.4    5s
# * 7703  1666             129    3384268.3401 3047763.07  9.94%  19.4    6s
# * 7704  1662             129    3383377.5990 3047763.07  9.92%  19.4    6s
# * 8872  1979             100    3353039.0736 3053019.68  8.95%  19.0    7s
# * 9532  2154             119    3352926.5616 3055500.16  8.87%  18.9    7s
# * 9882  2331             121    3350962.5065 3056013.19  8.80%  18.8    7s
# H10126  2444                    3340181.9030 3057930.48  8.45%  18.7    8s
# H10129  2444                    3340181.6455 3057930.48  8.45%  18.7    8s
# H11692  2782                    3339909.2921 3062953.16  8.29%  18.5    8s
#  14028  3745 3159110.15   55   19 3339909.29 3070264.72  8.07%  19.0   10s
# *14991  3937             127    3337113.2112 3073243.91  7.91%  19.0   10s
# *14992  3935             127    3337060.5061 3073243.91  7.91%  19.0   10s
# *14995  3935             127    3337044.4469 3073243.91  7.91%  19.0   10s
# H17571  4555                    3333633.2408 3078888.16  7.64%  19.1   12s
# H17574  4544                    3332656.7921 3078888.16  7.61%  19.1   12s
# H17575  4541                    3331694.8246 3078888.16  7.59%  19.1   12s
# H17729  4519                    3329322.3522 3078888.16  7.52%  19.2   12s
# H19012  4859                    3328584.1872 3081013.18  7.44%  19.5   13s
#  21251  5519 3108062.70   39   72 3328584.19 3086010.38  7.29%  19.9   15s
#  33125  7485 3226690.59   52   64 3328584.19 3108421.65  6.61%  21.1   20s
#  42058  8331 3236770.81   39   62 3328584.19 3123235.89  6.17%  21.8   25s
#  52407  8835 3157263.39   52   65 3328584.19 3140762.18  5.64%  22.1   30s
#  64241  8244 3165031.68   45   62 3328584.19 3164027.09  4.94%  22.5   35s
#  75168  7498     cutoff   49      3328584.19 3189443.66  4.18%  22.8   40s
#  85488  6586 3302742.08   45   27 3328584.19 3217122.38  3.35%  22.7   45s
#  97391  5127 3314377.92   58   65 3328584.19 3247217.32  2.44%  22.6   50s
#  109976  3560 3280923.82   55   65 3328584.19 3277323.79  1.54%  22.2   55s
#  123687  1822 3321354.84   54   23 3328584.19 3303368.44  0.76%  21.3   60s
# *127273  1515             129    3328495.3713 3309691.33  0.56%  21.0   61s
# H129268  1011                    3328382.9744 3315054.87  0.40%  20.9   62s
# H130833   885                    3328382.9488 3319005.41  0.28%  20.7   63s
# H130842   873                    3328315.0187 3319005.41  0.28%  20.7   63s
# *132678  1118             114    3328314.6762 3320540.55  0.23%  20.5   64s
#  135000  1256     cutoff   71      3328314.68 3325217.10  0.09%  20.2   65s
# *136490  1283             105    3328309.4523 3326334.30  0.06%  20.0   65s
# *145207  2239             112    3328303.5716 3327576.86  0.02%  18.9   67s
#  152204  2719 3328225.76   80   63 3328303.57 3327906.78  0.01%  18.0   70s
#
# Cutting planes:
#   Gomory: 24
#   Cover: 3
#   Implied bound: 1
#   Projected implied bound: 1
#   MIR: 36
#   Flow cover: 30
#   RLT: 335
#   Relax-and-lift: 1
#
# Explored 153836 nodes (2746014 simplex iterations) in 70.24 seconds (61.55 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 3.3283e+06 3.32831e+06 3.32831e+06 ... 3.33169e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Warning: max constraint violation (1.8438e-06) exceeds tolerance
# Best objective 3.328303571559e+06, best bound 3.327972926050e+06, gap 0.0099%
#
# User-callback calls 314289, time in user-callback 0.03 sec
# CSV file exported to: Results/Mean_cost/profiles_demand_flex0_vre0.csv
# INSTALLED POWER RESULTS
# [1248.00071918553, 1520.7790503659721, 347.9089453014544, 0.0, 2698.908624427861]
# CSV file exported to: Results/Mean_cost/power_demand_flex0_vre0.csv
# demand_flex50_vre0
# Reading scenario data/demand_flex50_vre0.csv
# Loaded demand with size (8759, 1)
# Cost
# Demand
# (8759,)
# (8807,)
# Availability
# Try reverse
# (8808, 5)
# Number of technologies: 5
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-09-07
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 120
# Model: initialized!
#
# Demand constraint
# Renewable maximum installed capacity constraint
# Storage variable
# Availability & installed power constraint
# Availability & installed power constraint
# Curtailment definition
# Z_1 expression
# Min X_1, X_2 expression
#  Take the min of min(X_1, X_2) and X_3
#  Take the overall min
#  Take the min of min(X_1, X_2) and X_3
#  Take the overall min
# Initialize Objective
# Optimize model
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 120
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1522 rows, 985 columns and 4720 nonzeros
# Model fingerprint: 0xe59fc9c0
# Model has 538 quadratic constraints
# Variable types: 740 continuous, 245 integer (245 binary)
# Coefficient statistics:
#   Matrix range     [9e-04, 1e+07]
#   QMatrix range    [1e+00, 2e+00]
#   QLMatrix range   [1e+00, 1e+07]
#   Objective range  [2e-03, 1e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+02, 1e+07]
#   QRHS range       [1e+07, 1e+07]
# Presolve added 4 rows and 64 columns
# Presolve time: 0.01s
# Presolved: 2489 rows, 1194 columns, 7207 nonzeros
# Presolved model has 239 bilinear constraint(s)
# Variable types: 951 continuous, 243 integer (243 binary)
#
# Root relaxation: objective 1.306948e+06, 682 iterations, 0.00 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1306948.49    0  134          - 1306948.49      -     -    0s
#      0     0 1459983.31    0  137          - 1459983.31      -     -    0s
#      0     0 1605204.84    0  135          - 1605204.84      -     -    0s
# H    0     0                    9.441538e+08 1605204.84   100%     -    0s
# H    0     0                    4.438650e+08 1605204.84   100%     -    0s
# H    0     2                    4.438543e+08 1605204.84   100%     -    0s
#      0     2 1605204.84    0  131 4.4385e+08 1605204.84   100%     -    0s
# H   32    40                    4.436993e+08 1605241.33   100%  83.3    0s
# H  846   655                    3.127882e+07 1843314.42  94.1%  15.1    0s
# * 1338  1051             129    2.960002e+07 1843314.42  93.8%  16.4    0s
# H 1520   996                    7176365.4464 2631313.61  63.3%  16.9    2s
# * 2256  1379              60    6991347.5241 2631313.61  62.4%  20.4    4s
# * 2259  1327              60    6424343.9268 2631313.61  59.0%  20.4    4s
# * 2399  1274              97    5564991.5103 2631313.61  52.7%  20.8    4s
# * 2484  1218              96    5443758.5555 2631313.61  51.7%  20.6    4s
# * 2561  1205              98    5362710.1101 2631313.61  50.9%  20.3    4s
# H 2615   998                    5115405.9379 2631313.61  48.6%  20.0    4s
# * 2680   830              94    4520425.9247 2631313.61  41.8%  19.8    4s
# * 2753   797              99    4403887.0052 2631313.61  40.3%  19.5    4s
# * 2755   763              99    4403885.4140 2631313.61  40.3%  19.5    4s
# * 2757   730             100    4403881.3837 2631313.61  40.3%  19.5    4s
# * 2826   708             100    4402491.2305 2631313.61  40.2%  19.1    4s
# * 2904   712             106    4401521.1655 2631313.61  40.2%  18.7    4s
# * 2973   737             106    4401520.6515 2631313.61  40.2%  18.4    4s
# * 3192   903             119    4401475.0059 2631313.61  40.2%  17.4    4s
# * 3327   669             108    3236359.7204 2631313.61  18.7%  17.0    4s
# * 3333   643             107    3236359.4366 2631313.61  18.7%  17.0    4s
#   3455   690 2761483.88   23   72 3236359.44 2700025.03  16.6%  16.8    5s
# * 3492   612             144    3222241.8169 2700025.03  16.2%  16.9    5s
#  11262  4074     cutoff   40      3222241.82 2937634.47  8.83%  21.2   10s
# *11522  3732             122    3213376.4621 2938300.03  8.56%  21.1   10s
# H14524  4653                    3202924.3652 2947453.43  7.98%  21.5   12s
#  19187  6409 2983640.50   42   66 3202924.37 2959998.41  7.58%  21.4   15s
# H28316  8853                    3202694.6462 2974353.13  7.13%  21.4   19s
#  28326  9100 3098959.31   39   14 3202694.65 2974391.59  7.13%  21.4   20s
# H30000  9331                    3202617.9996 2976020.35  7.08%  21.4   21s
# H30212  9331                    3202617.9781 2976226.97  7.07%  21.4   21s
#  38931 11515 3021004.53   41   65 3202617.98 2982911.89  6.86%  21.7   25s
#  49941 13519 3177698.06   48   79 3202617.98 2990314.43  6.63%  22.0   30s
#  61756 15516 3002360.72   39   65 3202617.98 2996617.29  6.43%  22.2   35s
#  73540 17242 3058028.55   45   18 3202617.98 3001953.89  6.27%  22.4   40s
#  85757 18716     cutoff   48      3202617.98 3007061.51  6.11%  22.6   45s
#  96983 19910 infeasible   34      3202617.98 3011754.44  5.96%  22.7   50s
#  107488 20830     cutoff   41      3202617.98 3015754.34  5.83%  22.8   55s
#  118149 21358 3185750.52   53   14 3202617.98 3020013.79  5.70%  22.8   60s
#  130317 21826     cutoff   50      3202617.98 3024977.87  5.55%  22.9   65s
#  140940 22151 3050432.68   36   65 3202617.98 3028994.30  5.42%  22.9   70s
#  152555 22240     cutoff   37      3202617.98 3034187.54  5.26%  23.0   75s
#  164369 22328 3177269.19   44   72 3202617.98 3038875.02  5.11%  22.9   80s
# H169080 22236                    3202360.0160 3040781.69  5.05%  22.9   82s
#  172721 22203     cutoff   47      3202360.02 3042170.61  5.00%  22.9   85s
#  183822 21780     cutoff   44      3202360.02 3047057.74  4.85%  22.9   90s
#  196571 21197 3188725.77   43   66 3202360.02 3053023.15  4.66%  22.8   95s
#  208074 20464 3093692.66   47   63 3202360.02 3058775.21  4.48%  22.7  100s
#  220725 19248 infeasible   45      3202360.02 3065698.57  4.27%  22.6  105s
#  232633 18007     cutoff   46      3202360.02 3072552.81  4.05%  22.5  110s
#  245902 16335     cutoff   48      3202360.02 3082525.54  3.74%  22.3  115s
#  254873 15276 3129838.40   41   15 3202360.02 3090545.19  3.49%  22.2  120s
#
# Cutting planes:
#   Gomory: 11
#   Cover: 5
#   Projected implied bound: 5
#   MIR: 53
#   Flow cover: 23
#   RLT: 276
#   Relax-and-lift: 3
#
# Explored 254987 nodes (5668746 simplex iterations) in 120.00 seconds (127.18 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 3.20236e+06 3.20262e+06 3.20262e+06 ... 4.40148e+06
#
# Time limit reached
# Warning: max constraint violation (1.6270e-06) exceeds tolerance
# Best objective 3.202360015988e+06, best bound 3.090777976463e+06, gap 3.4844%
#
# User-callback calls 517893, time in user-callback 0.04 sec
# CSV file exported to: Results/Mean_cost/profiles_demand_flex50_vre0.csv
# INSTALLED POWER RESULTS
# [847.081388262489, 1702.1388216580508, 315.87514812246127, 0.0, 2468.124883406101]
# CSV file exported to: Results/Mean_cost/power_demand_flex50_vre0.csv
# demand_flex50_vre50
# Reading scenario data/demand_flex50_vre50.csv
# Loaded demand with size (8759, 1)
# Cost
# Demand
# (8759,)
# (8807,)
# Availability
# Try reverse
# (8808, 5)
# Number of technologies: 5
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-09-07
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 120
# Model: initialized!
#
# Demand constraint
# Renewable maximum installed capacity constraint
# Storage variable
# Availability & installed power constraint
# Availability & installed power constraint
# Curtailment definition
# Z_1 expression
# Min X_1, X_2 expression
#  Take the min of min(X_1, X_2) and X_3
#  Take the overall min
#  Take the min of min(X_1, X_2) and X_3
#  Take the overall min
# Initialize Objective
# Optimize model
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 120
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1522 rows, 985 columns and 4720 nonzeros
# Model fingerprint: 0xef288827
# Model has 538 quadratic constraints
# Variable types: 740 continuous, 245 integer (245 binary)
# Coefficient statistics:
#   Matrix range     [9e-04, 1e+07]
#   QMatrix range    [1e+00, 2e+00]
#   QLMatrix range   [1e+00, 1e+07]
#   Objective range  [2e-03, 1e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+02, 1e+07]
#   QRHS range       [1e+07, 1e+07]
# Presolve added 4 rows and 64 columns
# Presolve time: 0.01s
# Presolved: 2489 rows, 1194 columns, 7207 nonzeros
# Presolved model has 239 bilinear constraint(s)
# Variable types: 951 continuous, 243 integer (243 binary)
#
# Root relaxation: objective 1.316542e+06, 679 iterations, 0.00 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1316541.86    0  131          - 1316541.86      -     -    0s
# H    0     0                    3.808959e+08 1316541.86   100%     -    0s
#      0     0 1831150.97    0  135 3.8090e+08 1831150.97   100%     -    0s
#      0     0 1945083.89    0  135 3.8090e+08 1945083.89  99.5%     -    0s
#      0     0 1945083.89    0  134 3.8090e+08 1945083.89  99.5%     -    0s
#      0     0 1945083.89    0  124 3.8090e+08 1945083.89  99.5%     -    0s
#      0     0 1945083.89    0  125 3.8090e+08 1945083.89  99.5%     -    0s
#      0     0 1945083.89    0  128 3.8090e+08 1945083.89  99.5%     -    0s
#      0     0 1945083.89    0  123 3.8090e+08 1945083.89  99.5%     -    0s
#      0     2 1945083.89    0  123 3.8090e+08 1945083.89  99.5%     -    0s
# H   60    64                    3.602085e+08 1945083.89  99.5%  32.1    0s
# H   91    95                    3.602059e+08 1945083.89  99.5%  24.6    0s
# *  272   314              38    4413580.0670 1945083.89  55.9%  14.5    0s
# *  323   314              40    4412690.8910 1945083.89  55.9%  16.2    0s
# *  326   314              42    4412458.9733 1945083.89  55.9%  16.3    0s
# *  378   339              44    4412448.3985 1945083.89  55.9%  18.3    0s
# *  379   339              45    4412447.8698 1945083.89  55.9%  18.3    0s
# *  420   399              49    4412447.8677 1945083.89  55.9%  20.2    0s
#   1555   868 3586563.69   22   88 4412447.87 2716739.72  38.4%  30.1    5s
# H 1965  1027                    3787587.5703 2719815.57  28.2%  30.5    5s
# H 2004   976                    3456612.7356 2719815.57  21.3%  30.9    5s
# H 2014   935                    3269512.8307 2719815.57  16.8%  30.8    5s
# * 2210   935              75    3266220.1992 2723293.47  16.6%  29.4    5s
# * 2211   901              75    3266220.1431 2723293.47  16.6%  29.4    5s
# H 2296   776                    3263319.4882 2723293.47  16.5%  29.0    5s
# * 2300   743              94    3244882.1164 2723293.47  16.1%  29.0    5s
# * 2301   713              94    3243759.0518 2723293.47  16.0%  29.0    5s
# * 2302   686              93    3239876.1767 2723293.47  15.9%  29.0    5s
# * 2331   653              93    3239512.5508 2723293.47  15.9%  29.1    5s
# * 2729   581              95    3224316.6287 2745356.04  14.9%  28.9    6s
# * 3774  1114             104    3217722.6695 2797746.39  13.1%  26.7    7s
# * 4071   877              97    3205517.4049 2803715.46  12.5%  27.0    7s
# H 5149  1217                    3202881.6284 2836989.08  11.4%  29.2    9s
# H 5150  1217                    3202873.9399 2836989.08  11.4%  29.2    9s
# H 5152  1217                    3202863.1035 2836989.08  11.4%  29.2    9s
# H 5153  1217                    3202862.3425 2836989.08  11.4%  29.2    9s
#   5957  1662 3037778.83   37   63 3202862.34 2850391.77  11.0%  30.6   10s
# H 6029  1648                    3194807.6765 2851891.68  10.7%  30.7   10s
# H 7031  2204                    3185042.8441 2857698.39  10.3%  30.1   10s
# H 7034  2204                    3185042.8422 2857698.39  10.3%  30.1   10s
# * 7120  2204             102    3185042.8384 2857698.39  10.3%  29.8   10s
#  12748  4110 infeasible   40      3185042.84 2895138.41  9.10%  36.0   15s
# H12928  3816                    3184286.2885 2896096.30  9.05%  36.5   15s
# H14908  4460                    3181210.0471 2902942.99  8.75%  38.7   17s
#  17275  5351 2977583.79   42   21 3181210.05 2907770.79  8.60%  42.6   20s
#  22786  7342 2957650.70   37   68 3181210.05 2919086.48  8.24%  53.6   25s
# H28291  8726                    3179342.2349 2927266.72  7.93%  58.7   30s
# H30255  9590                    3179318.7714 2929749.80  7.85%  59.1   32s
#  33858 10641     cutoff   41      3179318.77 2936028.90  7.65%  57.9   35s
#  41646 12548 infeasible   40      3179318.77 2943126.18  7.43%  55.2   40s
#  48958 14332 3015018.40   38   69 3179318.77 2949139.49  7.24%  53.6   45s
#  56594 16022     cutoff   42      3179318.77 2954058.21  7.09%  52.5   50s
#  65002 17660 infeasible   46      3179318.77 2957935.10  6.96%  51.9   55s
#  71961 18830 3132374.39   37   59 3179318.77 2960536.12  6.88%  52.5   60s
#  79001 20032 3128768.26   43   12 3179318.77 2963068.31  6.80%  53.6   65s
# H84316 20780                    3178971.7344 2964855.59  6.74%  53.6   69s
#  84659 20916 3170792.65   43   60 3178971.73 2964945.74  6.73%  53.5   70s
# H85636 20922                    3178965.5175 2965276.73  6.72%  53.5   71s
#  91591 21977 3148260.01   38   16 3178965.52 2967265.71  6.66%  53.2   75s
#  100024 23138     cutoff   37      3178965.52 2969685.44  6.58%  52.8   80s
#  106998 23965     cutoff   40      3178965.52 2971750.64  6.52%  52.7   85s
#  116030 25056 2975048.42   37   61 3178965.52 2974099.79  6.44%  52.4   90s
#  123187 25900     cutoff   37      3178965.52 2975849.22  6.39%  52.2   95s
#  131292 26935 3149893.79   39   67 3178965.52 2977731.65  6.33%  52.1  100s
#  139297 27783 3111870.90   38   65 3178965.52 2979757.16  6.27%  51.9  105s
#  146312 28466 infeasible   41      3178965.52 2981526.99  6.21%  51.9  110s
#  153756 29134 3134212.93   44   66 3178965.52 2983229.17  6.16%  51.9  115s
#  160259 29657 3141992.38   46   62 3178965.52 2984862.12  6.11%  51.8  120s
#
# Cutting planes:
#   Gomory: 8
#   Cover: 4
#   Implied bound: 20
#   Projected implied bound: 6
#   Clique: 15
#   MIR: 57
#   Flow cover: 44
#   Inf proof: 1
#   RLT: 128
#   Relax-and-lift: 30
#   BQP: 1
#
# Explored 161176 nodes (8354582 simplex iterations) in 120.01 seconds (128.05 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 3.17897e+06 3.17897e+06 3.17932e+06 ... 3.19481e+06
#
# Time limit reached
# Warning: max constraint violation (1.7868e-06) exceeds tolerance
# Best objective 3.178965517462e+06, best bound 2.985114742247e+06, gap 6.0979%
#
# User-callback calls 331108, time in user-callback 0.03 sec
# CSV file exported to: Results/Mean_cost/profiles_demand_flex50_vre50.csv
# INSTALLED POWER RESULTS
# [880.1188709552839, 1684.109251359926, 303.29903179474326, 0.0, 2424.031655487633]
# CSV file exported to: Results/Mean_cost/power_demand_flex50_vre50.csv
# demand_flex50_vre100
# Reading scenario data/demand_flex50_vre100.csv
# Loaded demand with size (8759, 1)
# Cost
# Demand
# (8759,)
# (8807,)
# Availability
# Try reverse
# (8808, 5)
# Number of technologies: 5
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-09-07
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 120
# Model: initialized!
#
# Demand constraint
# Renewable maximum installed capacity constraint
# Storage variable
# Availability & installed power constraint
# Availability & installed power constraint
# Curtailment definition
# Z_1 expression
# Min X_1, X_2 expression
#  Take the min of min(X_1, X_2) and X_3
#  Take the overall min
#  Take the min of min(X_1, X_2) and X_3
#  Take the overall min
# Initialize Objective
# Optimize model
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 120
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1522 rows, 985 columns and 4720 nonzeros
# Model fingerprint: 0xefbb4461
# Model has 538 quadratic constraints
# Variable types: 740 continuous, 245 integer (245 binary)
# Coefficient statistics:
#   Matrix range     [9e-04, 1e+07]
#   QMatrix range    [1e+00, 2e+00]
#   QLMatrix range   [1e+00, 1e+07]
#   Objective range  [2e-03, 1e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+02, 1e+07]
#   QRHS range       [1e+07, 1e+07]
# Presolve added 4 rows and 64 columns
# Presolve time: 0.01s
# Presolved: 2489 rows, 1194 columns, 7207 nonzeros
# Presolved model has 239 bilinear constraint(s)
# Variable types: 951 continuous, 243 integer (243 binary)
#
# Root relaxation: objective 1.352109e+06, 700 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1352109.39    0  139          - 1352109.39      -     -    0s
# H    0     0                    5.197659e+08 1352109.39   100%     -    0s
#      0     0 1755400.27    0  139 5.1977e+08 1755400.27   100%     -    0s
# H    0     0                    4.013855e+08 1755400.27   100%     -    0s
#      0     0 1878776.72    0  137 4.0139e+08 1878776.72   100%     -    0s
#      0     2 1878776.72    0  137 4.0139e+08 1878776.72   100%     -    0s
# H   60    64                    3.422307e+08 1878776.72  99.5%  41.6    0s
# H  467   479                    2.604179e+07 1878776.72  92.8%  16.1    0s
# H 1496  1103                    2.157866e+07 2553395.65  88.2%  19.7    3s
# H 1496  1048                    5391021.2765 2553395.65  52.6%  19.7    3s
# H 1496   995                    5391021.2736 2553395.65  52.6%  19.7    3s
# H 1529   955                    5391021.2725 2553395.65  52.6%  21.9    4s
# H 1606   955                    5391021.2708 2553395.65  52.6%  21.8    4s
# H 1660   937                    5391021.2687 2553395.65  52.6%  21.8    4s
# H 1685   886                    5391021.2680 2553395.65  52.6%  21.6    4s
# H 1762   889                    5391021.2673 2553395.65  52.6%  21.4    4s
# H 1832   873                    3508515.6146 2553395.65  27.2%  21.7    4s
# * 2145   921              56    3409831.7809 2622875.68  23.1%  22.1    4s
# * 2147   886              57    3304522.4412 2622875.68  20.6%  22.1    4s
# * 2150   852              59    3276285.9463 2622875.68  19.9%  22.1    4s
# * 2152   819              60    3266753.9662 2622875.68  19.7%  22.0    4s
# * 2154   788              61    3262686.5619 2622875.68  19.6%  22.0    4s
# * 2205   741              64    3261769.7764 2622875.68  19.6%  22.1    4s
# * 2208   713              66    3261567.5236 2622875.68  19.6%  22.0    4s
# * 2212   686              69    3261537.5649 2622875.68  19.6%  22.0    4s
# * 2261   678              76    3261535.5605 2622875.68  19.6%  21.8    4s
# * 2266   653              76    3261535.1066 2622875.68  19.6%  21.8    4s
#   2638   605 infeasible   48      3261535.11 2649997.15  18.8%  23.0    5s
# H 3255   882                    3252140.7841 2732866.80  16.0%  25.4    5s
# H 3264   868                    3229262.2691 2732866.80  15.4%  25.3    5s
# * 3482   996              96    3227530.0065 2732866.80  15.3%  24.9    5s
# H 3586   993                    3223156.3048 2741665.25  14.9%  24.9    5s
# H 4652  1455                    3210493.2799 2784200.54  13.3%  27.5    7s
# * 4695  1557              75    3209333.0080 2788286.40  13.1%  27.3    7s
# * 5001  1626              75    3205377.0195 2788286.40  13.0%  27.4    8s
# * 5244  1635             106    3170990.3385 2793151.51  11.9%  27.2    8s
# * 6480  1872              50    3152043.5050 2803677.77  11.1%  28.2    9s
# * 6491  1870              58    3151739.4691 2803677.77  11.0%  28.2    9s
# * 6494  1870              60    3151686.0396 2803677.77  11.0%  28.2    9s
# * 6710  1983              70    3151685.6360 2807720.14  10.9%  28.1    9s
# * 6716  1983              75    3151685.6300 2807720.14  10.9%  28.1    9s
# * 6734  1983              85    3151685.6296 2807720.14  10.9%  28.0    9s
# * 6822  2072              56    3146182.2140 2808219.76  10.7%  27.9    9s
# * 6828  2072              61    3146174.2570 2808219.76  10.7%  27.9    9s
#   7542  2270 3133066.98   49   62 3146174.26 2812967.74  10.6%  28.3   10s
# H13065  4823                    3142651.1056 2841812.82  9.57%  32.7   13s
# H13068  4823                    3142651.0287 2841812.82  9.57%  32.7   13s
# H13485  4732                    3131938.3689 2841812.82  9.26%  32.3   13s
# H13488  4730                    3131800.8513 2841812.82  9.26%  32.3   13s
#  14910  5870     cutoff   40      3131800.85 2846473.87  9.11%  31.6   15s
# H15300  5870                    3131784.3193 2847387.33  9.08%  31.8   15s
# H16746  5338                    3127533.5936 2852141.99  8.81%  31.8   16s
# H16823  5277                    3123543.8810 2852141.99  8.69%  31.9   16s
# H16915  5250                    3122652.8817 2852141.99  8.66%  32.0   16s
# H16966  5095                    3114163.4350 2852141.99  8.41%  32.0   16s
#  21821  7087 2964299.93   40   19 3114163.43 2862243.56  8.09%  34.6   20s
#  30605  9605     cutoff   40      3114163.43 2872903.74  7.75%  38.3   25s
# H30606  9600                    3113650.0009 2872903.74  7.73%  38.3   25s
# H32322 10239                    3113546.0516 2874719.58  7.67%  38.7   27s
#  36933 11671     cutoff   50      3113546.05 2878766.83  7.54%  39.9   30s
#  45193 13907 3071157.92   46   10 3113546.05 2884628.28  7.35%  41.6   35s
#  53570 16192 2907627.62   35   72 3113546.05 2889837.20  7.19%  42.5   40s
#  61214 17988     cutoff   47      3113546.05 2893537.58  7.07%  43.0   45s
#  68765 19530 infeasible   52      3113546.05 2896433.10  6.97%  43.6   50s
#  75780 21095     cutoff   39      3113546.05 2898647.91  6.90%  44.2   55s
#  83739 22680 2996340.62   41   61 3113546.05 2901016.57  6.83%  44.9   60s
#  92422 24306     cutoff   47      3113546.05 2903333.68  6.75%  45.4   65s
#  100210 25559     cutoff   49      3113546.05 2905262.07  6.69%  46.0   70s
#  108945 26977 infeasible   41      3113546.05 2907294.31  6.62%  46.4   75s
#  117042 28151 3104800.68   43   13 3113546.05 2908992.51  6.57%  46.8   80s
# H121625 28682                    3113505.0275 2909937.09  6.54%  47.0   83s
# H122661 28826                    3113502.2356 2910179.75  6.53%  47.1   84s
#  123061 28937     cutoff   44      3113502.24 2910266.22  6.53%  47.1   85s
#  131338 30105     cutoff   46      3113502.24 2911966.98  6.47%  47.6   90s
#  139669 30990 2915040.76   34   67 3113502.24 2913664.89  6.42%  48.1   95s
#  148019 31847 2922736.13   40   65 3113502.24 2915369.25  6.36%  48.4  100s
#  156340 32691     cutoff   47      3113502.24 2917001.17  6.31%  48.8  105s
# H159155 32812                    3113502.1819 2917560.39  6.29%  49.0  107s
#  162154 33072 3004892.00   35   64 3113502.18 2918114.32  6.28%  49.1  110s
#  170802 33605     cutoff   47      3113502.18 2919956.30  6.22%  49.5  115s
#  178551 34137 infeasible   44      3113502.18 2921244.80  6.17%  49.8  120s
#
# Cutting planes:
#   Gomory: 3
#   Implied bound: 1
#   MIR: 48
#   Flow cover: 30
#   Inf proof: 1
#   RLT: 219
#
# Explored 179151 nodes (8922540 simplex iterations) in 120.00 seconds (134.96 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 3.1135e+06 3.1135e+06 3.11351e+06 ... 3.13178e+06
#
# Time limit reached
# Best objective 3.113502181939e+06, best bound 2.921356975267e+06, gap 6.1714%
#
# User-callback calls 367975, time in user-callback 0.04 sec
# CSV file exported to: Results/Mean_cost/profiles_demand_flex50_vre100.csv
# INSTALLED POWER RESULTS
# [989.4448930408762, 1630.2361498805867, 278.780909323538, 0.0, 2212.9998957736834]
# CSV file exported to: Results/Mean_cost/power_demand_flex50_vre100.csv
# demand_flex100_vre0
# Reading scenario data/demand_flex100_vre0.csv
# Loaded demand with size (8760, 1)
# Cost
# Demand
# (8760,)
# (8808,)
# Availability
# Try reverse
# (8808, 5)
# Number of technologies: 5
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-09-07
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 120
# Model: initialized!
#
# Demand constraint
# Renewable maximum installed capacity constraint
# Storage variable
# Availability & installed power constraint
# Availability & installed power constraint
# Curtailment definition
# Z_1 expression
# Min X_1, X_2 expression
#  Take the min of min(X_1, X_2) and X_3
#  Take the overall min
#  Take the min of min(X_1, X_2) and X_3
#  Take the overall min
# Initialize Objective
# Optimize model
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 120
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1522 rows, 985 columns and 4720 nonzeros
# Model fingerprint: 0x6300a7ab
# Model has 538 quadratic constraints
# Variable types: 740 continuous, 245 integer (245 binary)
# Coefficient statistics:
#   Matrix range     [9e-04, 1e+07]
#   QMatrix range    [1e+00, 2e+00]
#   QLMatrix range   [1e+00, 1e+07]
#   Objective range  [2e-03, 1e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+02, 1e+07]
#   QRHS range       [1e+07, 1e+07]
# Presolve added 4 rows and 64 columns
# Presolve time: 0.01s
# Presolved: 2489 rows, 1194 columns, 7207 nonzeros
# Presolved model has 239 bilinear constraint(s)
# Variable types: 951 continuous, 243 integer (243 binary)
#
# Root relaxation: objective 1.201954e+06, 674 iterations, 0.00 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1201954.40    0  146          - 1201954.40      -     -    0s
#      0     0 1341320.50    0  141          - 1341320.50      -     -    0s
# H    0     0                    6.728493e+08 1341320.50   100%     -    0s
#      0     0 1411971.87    0  141 6.7285e+08 1411971.87   100%     -    0s
#      0     0 1480284.37    0  141 6.7285e+08 1480284.37   100%     -    0s
# H    0     0                    6.703374e+08 1480284.37   100%     -    0s
#      0     0 1480284.37    0  140 6.7034e+08 1480284.37   100%     -    0s
# H    0     0                    3.177550e+08 1480284.37   100%     -    0s
#      0     0 1480284.37    0  138 3.1775e+08 1480284.37   100%     -    0s
#      0     0 1480284.37    0  139 3.1775e+08 1480284.37   100%     -    0s
#      0     0 1480284.37    0  139 3.1775e+08 1480284.37   100%     -    0s
#      0     0 1480284.37    0  130 3.1775e+08 1480284.37   100%     -    0s
#      0     2 1480284.37    0  130 3.1775e+08 1480284.37   100%     -    0s
# H   36    40                    3.104869e+08 1569514.01  99.5%  57.5    0s
# H   76    80                    2.980000e+08 1569538.97  99.5%  31.8    0s
# H  170   175                    2.938528e+08 1569538.97  99.5%  17.2    0s
# H  823   814                    1.660674e+08 1569538.97  99.1%  14.8    0s
# * 1092  1011             149    1.583914e+08 1569538.97  99.0%  16.0    0s
# * 1169  1068             130    5.504197e+07 1569538.97  97.1%  16.2    0s
# * 1248  1078             131    5.478960e+07 1707501.61  96.9%  16.4    0s
# H 1504  1202                    1.930657e+07 2611224.41  86.5%  17.6    2s
# H 1536  1170                    3665186.0018 2611224.41  28.8%  20.7    3s
# H 1918  1226                    3256568.7472 2611224.41  19.8%  22.8    3s
# * 2066  1199              67    3186006.4754 2611224.41  18.0%  23.8    3s
# * 2102  1141              70    3176480.2387 2628972.11  17.2%  23.9    4s
# * 2103  1092              70    3176462.9320 2628972.11  17.2%  23.9    4s
# * 2104  1045              69    3176439.2537 2628972.11  17.2%  23.9    4s
# * 2105  1000              68    3176406.8490 2628972.11  17.2%  23.9    4s
# * 2641  1007             110    3131157.4210 2706892.93  13.5%  22.6    4s
# * 2643   964             111    3129782.2606 2706892.93  13.5%  22.5    4s
#   3065  1077 2796617.16   24   74 3129782.26 2717242.72  13.2%  22.6    5s
# * 3149   912             104    3128342.2731 2717242.72  13.1%  22.5    5s
# * 3156   872             104    3127907.7808 2717242.72  13.1%  22.5    5s
# * 3161   821             101    3122138.4736 2717242.72  13.0%  22.5    5s
# * 4675  1660             112    3120854.2942 2764213.86  11.4%  24.0    6s
# * 4956  1681             109    3110536.0482 2764213.86  11.1%  23.4    6s
# * 5068  1752             111    3107654.1911 2778144.85  10.6%  23.5    6s
# * 9311  3700             117    3104212.8315 2812801.00  9.39%  24.9    9s
# * 9317  3689             120    3102812.3001 2812801.00  9.35%  24.8    9s
# * 9318  3688             120    3102752.3019 2812801.00  9.34%  24.8    9s
#   9763  3929     cutoff   53      3102752.30 2815428.82  9.26%  25.0   10s
# *16433  6552              61    3102065.2103 2838229.19  8.51%  27.6   14s
# *16439  6547              66    3102003.4770 2838229.19  8.50%  27.6   14s
# *16443  6547              69    3102000.8529 2838229.19  8.50%  27.6   14s
# *17020  6875              76    3102000.8160 2839290.51  8.47%  27.8   14s
# *17023  6875              78    3102000.8059 2839290.51  8.47%  27.8   14s
#  17301  7166 infeasible   28      3102000.81 2840263.80  8.44%  27.8   15s
# H18709  7102                    3072803.2948 2842933.68  7.48%  28.1   17s
#  23911  9325 3007493.84   47   19 3072803.29 2850662.72  7.23%  29.0   20s
# H32633 12106                    3071949.6312 2859591.17  6.91%  30.3   25s
#  39869 14896 infeasible   49      3071949.63 2865445.66  6.72%  31.4   30s
#  48289 17402 3044221.58   43   65 3071949.63 2870524.21  6.56%  32.4   35s
#  58309 20341     cutoff   39      3071949.63 2875146.23  6.41%  33.3   40s
#  66680 22675     cutoff   54      3071949.63 2878119.60  6.31%  34.2   45s
#  74473 24700 2913600.67   38   66 3071949.63 2880438.25  6.23%  36.0   50s
#  82005 26530     cutoff   43      3071949.63 2882807.14  6.16%  37.2   55s
#  90006 28485 3043236.05   42   66 3071949.63 2885260.67  6.08%  37.5   60s
#  97857 30172     cutoff   47      3071949.63 2887315.45  6.01%  37.9   65s
#  104783 31611 infeasible   50      3071949.63 2889195.12  5.95%  39.0   70s
#  112068 32681 infeasible   42      3071949.63 2890336.45  5.91%  40.2   76s
#  117742 33962     cutoff   43      3071949.63 2892046.32  5.86%  40.7   80s
#  125396 35163     cutoff   47      3071949.63 2893483.12  5.81%  41.1   85s
#  134059 36594     cutoff   48      3071949.63 2894988.24  5.76%  41.4   90s
#  141618 37717 3036543.91   52   20 3071949.63 2896129.01  5.72%  42.5   95s
#  148259 38742 2916516.04   33   67 3071949.63 2897305.80  5.69%  43.5  100s
#  156383 39930 2904881.49   47   21 3071949.63 2898735.97  5.64%  43.7  105s
#  165252 41217 2918644.29   50   66 3071949.63 2900199.29  5.59%  43.8  110s
#  171936 42231 infeasible   35      3071949.63 2901173.51  5.56%  44.0  115s
# H177817 42788                    3071943.9418 2902003.74  5.53%  44.2  119s
#  178128 42869 2912407.64   39   66 3071943.94 2902030.65  5.53%  44.2  120s
#
# Cutting planes:
#   Gomory: 24
#   Cover: 2
#   Implied bound: 5
#   Projected implied bound: 2
#   MIR: 58
#   Flow cover: 37
#   Inf proof: 6
#   RLT: 249
#
# Explored 179084 nodes (7928242 simplex iterations) in 120.01 seconds (130.24 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 3.07194e+06 3.07195e+06 3.0728e+06 ... 3.10281e+06
#
# Time limit reached
# Warning: max constraint violation (2.3551e-06) exceeds tolerance
# Best objective 3.071943941756e+06, best bound 2.902184642594e+06, gap 5.5261%
#
# User-callback calls 368083, time in user-callback 0.03 sec
# CSV file exported to: Results/Mean_cost/profiles_demand_flex100_vre0.csv
# INSTALLED POWER RESULTS
# [638.8706885511139, 1778.9936470123191, 271.5311940470564, 0.0, 2276.6658575626566]
# CSV file exported to: Results/Mean_cost/power_demand_flex100_vre0.csv
# demand_flex100_vre50
# Reading scenario data/demand_flex100_vre50.csv
# Loaded demand with size (8760, 1)
# Cost
# Demand
# (8760,)
# (8808,)
# Availability
# Try reverse
# (8808, 5)
# Number of technologies: 5
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-09-07
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 120
# Model: initialized!
#
# Demand constraint
# Renewable maximum installed capacity constraint
# Storage variable
# Availability & installed power constraint
# Availability & installed power constraint
# Curtailment definition
# Z_1 expression
# Min X_1, X_2 expression
#  Take the min of min(X_1, X_2) and X_3
#  Take the overall min
#  Take the min of min(X_1, X_2) and X_3
#  Take the overall min
# Initialize Objective
# Optimize model
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 120
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1522 rows, 985 columns and 4720 nonzeros
# Model fingerprint: 0x66397d39
# Model has 538 quadratic constraints
# Variable types: 740 continuous, 245 integer (245 binary)
# Coefficient statistics:
#   Matrix range     [9e-04, 1e+07]
#   QMatrix range    [1e+00, 2e+00]
#   QLMatrix range   [1e+00, 1e+07]
#   Objective range  [2e-03, 1e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+02, 1e+07]
#   QRHS range       [1e+07, 1e+07]
# Presolve added 4 rows and 64 columns
# Presolve time: 0.01s
# Presolved: 2489 rows, 1194 columns, 7207 nonzeros
# Presolved model has 239 bilinear constraint(s)
# Variable types: 951 continuous, 243 integer (243 binary)
#
# Root relaxation: objective 1.195413e+06, 675 iterations, 0.00 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1195413.30    0  154          - 1195413.30      -     -    0s
# H    0     0                    6.553610e+08 1195413.30   100%     -    0s
#      0     0 1341413.90    0  152 6.5536e+08 1341413.90   100%     -    0s
# H    0     0                    6.535710e+08 1341413.90   100%     -    0s
#      0     0 1747166.48    0  150 6.5357e+08 1747166.48   100%     -    0s
# H    0     0                    3.076994e+08 1747166.48  99.4%     -    0s
#      0     2 1747166.48    0  150 3.0770e+08 1747166.48  99.4%     -    0s
# H   31    40                    3.075787e+08 1747166.48  99.4%  91.2    0s
# H   36    40                    2.986760e+08 1747166.48  99.4%  81.3    0s
# H   38    40                    2.979730e+08 1747166.48  99.4%  84.0    0s
# H  267   319                    2.719894e+08 1747166.48  99.4%  17.6    0s
# H  457   466                    7.122276e+07 1747166.48  97.5%  15.8    0s
# H  470   484                    5.271793e+07 1747166.48  96.7%  15.6    0s
# *  684   543              69    4646839.6409 1747166.48  62.4%  15.0    0s
# H 1543   713                    4438379.5725 2422793.30  45.4%  20.7    3s
# H 1549   681                    3542078.5329 2654028.42  25.1%  20.6    4s
# H 1549   647                    3330832.5552 2654028.42  20.3%  20.6    4s
#   1559   653 2654028.42   18   67 3330832.56 2654028.42  20.3%  22.3    5s
# * 2163   812              97    3252377.8766 2654028.42  18.4%  24.0    5s
# * 2272   843              66    3188875.1163 2654028.42  16.8%  23.3    5s
# * 2275   813              67    3174426.3489 2654028.42  16.4%  23.3    5s
# * 2576   744             103    3134628.3484 2654028.42  15.3%  21.7    5s
# H 2586   610                    3125713.6553 2654028.42  15.1%  21.7    5s
# * 2676   568              83    3125711.4375 2654028.42  15.1%  21.6    5s
# * 3374   710             110    3097684.8505 2654028.42  14.3%  20.7    6s
# * 4176   974              83    3089452.9277 2747596.25  11.1%  21.3    6s
# * 4178   974              84    3089428.6928 2747596.25  11.1%  21.3    6s
# * 4211   965             111    3086068.3717 2747596.25  11.0%  21.1    6s
# * 5254  1553             119    3054069.1352 2794124.28  8.51%  19.9    7s
# H 6239  1578                    3053882.9887 2812801.38  7.89%  20.6    8s
# * 6433  1632             110    3052918.6834 2812801.38  7.87%  20.8    8s
# H 7720  2140                    3052674.4444 2828995.05  7.33%  21.2    9s
#   7765  2195 2929753.42   38   71 3052674.44 2828995.05  7.33%  21.2   10s
# *11996  4005             118    3049377.2023 2847358.09  6.62%  22.4   12s
# H13752  4065                    3046022.3249 2851718.11  6.38%  22.9   14s
# H13895  4021                    3043507.3030 2851718.11  6.30%  22.9   14s
#  15209  4626 3016093.76   52   64 3043507.30 2854918.30  6.20%  23.2   15s
#  26906  7966 2991312.51   43   35 3043507.30 2866582.09  5.81%  23.7   20s
# H27701  7967                    3043234.3362 2866983.07  5.79%  23.7   21s
#  35452  9929 3011683.09   46   62 3043234.34 2872008.26  5.63%  23.9   25s
#  47711 12502 3033896.67   37   63 3043234.34 2878763.14  5.40%  24.0   30s
#  59268 14448     cutoff   43      3043234.34 2883850.72  5.24%  24.0   35s
#  71471 16331     cutoff   44      3043234.34 2888835.47  5.07%  24.0   40s
#  84282 17921 2952950.75   39   67 3043234.34 2894245.17  4.90%  23.9   45s
# H90388 18480                    3043073.9260 2896597.96  4.81%  23.9   48s
#  93826 18915     cutoff   43      3043073.93 2898005.88  4.77%  23.9   50s
#  106692 20022 2932313.46   41   64 3043073.93 2903589.68  4.58%  23.8   55s
#  118831 20715 2935925.65   40   70 3043073.93 2909626.52  4.39%  23.7   60s
#  130137 21127     cutoff   41      3043073.93 2915492.49  4.19%  23.6   65s
#  142520 21265 2976727.44   42   17 3043073.93 2921711.65  3.99%  23.4   70s
#  154043 21181 2993729.08   37   66 3043073.93 2927422.38  3.80%  23.1   75s
#  167192 20839 3040174.13   46   17 3043073.93 2934903.47  3.55%  22.8   80s
# H171724 20544                    3042750.7383 2937710.54  3.45%  22.7   82s
# H171734 20471                    3041894.1437 2937710.54  3.42%  22.7   82s
#  176773 20191     cutoff   40      3041894.14 2940911.92  3.32%  22.6   85s
#  188747 19569 2949831.85   33   63 3041894.14 2946577.84  3.13%  22.5   90s
#  201870 18883 3011008.69   49   67 3041894.14 2953350.15  2.91%  22.3   95s
#  213650 17866     cutoff   48      3041894.14 2960693.37  2.67%  22.3  100s
#  225628 16909     cutoff   39      3041894.14 2969262.57  2.39%  22.3  105s
#  238419 15887     cutoff   48      3041894.14 2975942.60  2.17%  22.2  110s
#  251801 14301 2988405.51   37   59 3041894.14 2983984.34  1.90%  22.1  115s
#  263567 12430     cutoff   40      3041894.14 2992521.30  1.62%  22.0  120s
#
# Cutting planes:
#   Gomory: 6
#   Cover: 3
#   Implied bound: 4
#   Projected implied bound: 4
#   Clique: 7
#   MIR: 90
#   Flow cover: 21
#   Inf proof: 2
#   RLT: 228
#   Relax-and-lift: 35
#   BQP: 1
#
# Explored 264349 nodes (5809678 simplex iterations) in 120.01 seconds (109.47 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 3.04189e+06 3.04275e+06 3.04307e+06 ... 3.05388e+06
#
# Time limit reached
# Best objective 3.041894143738e+06, best bound 2.993244363659e+06, gap 1.5993%
#
# User-callback calls 536251, time in user-callback 0.05 sec
# CSV file exported to: Results/Mean_cost/profiles_demand_flex100_vre50.csv
# INSTALLED POWER RESULTS
# [694.7338587055668, 1746.9582085170377, 268.0748940844517, 0.0, 2159.1166662757596]
# CSV file exported to: Results/Mean_cost/power_demand_flex100_vre50.csv
# demand_flex100_vre100
# Reading scenario data/demand_flex100_vre100.csv
# Loaded demand with size (8760, 1)
# Cost
# Demand
# (8760,)
# (8808,)
# Availability
# Try reverse
# (8808, 5)
# Number of technologies: 5
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-09-07
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 120
# Model: initialized!
#
# Demand constraint
# Renewable maximum installed capacity constraint
# Storage variable
# Availability & installed power constraint
# Availability & installed power constraint
# Curtailment definition
# Z_1 expression
# Min X_1, X_2 expression
#  Take the min of min(X_1, X_2) and X_3
#  Take the overall min
#  Take the min of min(X_1, X_2) and X_3
#  Take the overall min
# Initialize Objective
# Optimize model
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 120
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1522 rows, 985 columns and 4720 nonzeros
# Model fingerprint: 0xb1e0890f
# Model has 538 quadratic constraints
# Variable types: 740 continuous, 245 integer (245 binary)
# Coefficient statistics:
#   Matrix range     [9e-04, 1e+07]
#   QMatrix range    [1e+00, 2e+00]
#   QLMatrix range   [1e+00, 1e+07]
#   Objective range  [2e-03, 1e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+02, 1e+07]
#   QRHS range       [1e+07, 1e+07]
# Presolve added 4 rows and 64 columns
# Presolve time: 0.01s
# Presolved: 2489 rows, 1194 columns, 7207 nonzeros
# Presolved model has 239 bilinear constraint(s)
# Variable types: 951 continuous, 243 integer (243 binary)
#
# Root relaxation: objective 1.241703e+06, 680 iterations, 0.00 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1241702.99    0  156          - 1241702.99      -     -    0s
#      0     0 1377194.80    0  155          - 1377194.80      -     -    0s
#      0     0 1512145.60    0  154          - 1512145.60      -     -    0s
#      0     2 1512145.60    0  151          - 1512145.60      -     -    0s
# *  255   259              33    3941896.9536 1512145.60  61.6%  12.8    0s
# *  284   248              34    3936080.5630 1512145.60  61.6%  17.5    0s
# *  330   283              35    3935548.8292 1512145.60  61.6%  20.7    0s
# H 1535  1020                    3025718.8591 2575261.84  14.9%  23.5    3s
#   2327  1242 2975974.78   37   16 3025718.86 2622169.35  13.3%  25.1    5s
# * 2333  1185              42    3017996.5514 2622169.35  13.1%  25.1    5s
# * 2388  1142              50    3015818.8764 2622169.35  13.1%  25.0    5s
# * 2830  1223              72    3015180.8066 2633173.95  12.7%  24.5    5s
# * 3121  1129              51    2989710.4539 2653597.55  11.2%  24.3    5s
# * 3332  1143              58    2989232.8426 2668371.57  10.7%  24.7    5s
# * 5243  1954              49    2979658.4605 2692924.09  9.62%  25.0    7s
# * 5245  1953              50    2979368.8204 2692924.09  9.61%  25.0    7s
# * 5252  1953              56    2978939.3339 2692924.09  9.60%  25.0    7s
# * 5255  1953              58    2978880.6494 2692924.09  9.60%  24.9    7s
# * 5258  1953              60    2978877.9239 2692924.09  9.60%  24.9    7s
# * 5271  1953              69    2978877.9014 2692924.09  9.60%  24.9    7s
# * 5278  1953              74    2978877.9005 2692924.09  9.60%  24.8    7s
# * 5281  1953              76    2978877.8985 2692924.09  9.60%  24.8    7s
#   9244  4133 2798529.07   32   66 2978877.90 2719089.26  8.72%  25.9   10s
#  16763  7745 2812409.13   31   67 2978877.90 2741881.44  7.96%  27.7   15s
# H18879  8432                    2977686.9001 2745609.01  7.79%  27.9   16s
#  23164 10737 2961900.42   40   70 2977686.90 2754560.42  7.49%  28.3   20s
# *26557 11935             103    2977686.8935 2759730.47  7.32%  28.5   21s
# *26562 11935             105    2977686.8022 2759730.47  7.32%  28.5   21s
# *26564 11935             104    2977686.7960 2759730.47  7.32%  28.5   21s
# *26565 11935             103    2977686.7893 2759730.47  7.32%  28.5   21s
# *26566 11935             102    2977686.7822 2759730.47  7.32%  28.5   21s
# *29097 13048              95    2976904.1603 2762506.22  7.20%  28.6   22s
# *29098 13002              95    2975383.8839 2762506.22  7.15%  28.6   22s
# *31761 14159              99    2974591.1012 2764638.90  7.06%  28.7   24s
#  32418 14390     cutoff   37      2974591.10 2765419.17  7.03%  28.8   25s
# *41238 17740             118    2973052.0964 2772724.68  6.74%  29.2   29s
# *41240 17727             119    2972630.9905 2772724.68  6.72%  29.2   29s
# *41250 17634             124    2970296.8134 2772724.68  6.65%  29.2   29s
#  42375 18305 infeasible   37      2970296.81 2773607.44  6.62%  29.2   30s
# H43160 17894                    2954284.3388 2774046.76  6.10%  29.2   30s
# H44718 18119                    2952831.4349 2774918.52  6.03%  29.3   31s
#  49385 20184 2810981.38   26   65 2952831.43 2777597.18  5.93%  29.7   35s
#  58123 23402 2806156.73   30   69 2952831.43 2781865.54  5.79%  30.5   40s
#  68028 26706 2905948.87   32   82 2952831.43 2786211.78  5.64%  31.4   45s
#  77451 29912     cutoff   41      2952831.43 2789524.60  5.53%  31.9   50s
#  86873 32798 2829402.28   33   21 2952831.43 2791888.24  5.45%  32.5   55s
#  96280 35550 2810007.35   29   64 2952831.43 2794009.28  5.38%  33.0   61s
# H96488 35225                    2950046.6485 2794009.28  5.29%  33.0   61s
# H98198 35660                    2949467.0125 2794393.88  5.26%  33.1   62s
# H100096 36316                    2949466.8648 2794807.44  5.24%  33.2   64s
#  101411 36717 2817593.73   27   63 2949466.86 2795017.19  5.24%  33.2   65s
#  110632 39353 2949184.93   42   60 2949466.86 2796548.73  5.18%  33.6   70s
#  119793 41838     cutoff   42      2949466.86 2798043.55  5.13%  33.8   75s
#  129041 44500 2814889.05   27   65 2949466.86 2799288.17  5.09%  34.1   80s
#  138188 46815 2904639.41   37   22 2949466.86 2800346.91  5.06%  34.5   85s
#  147457 49037 2885161.67   34   64 2949466.86 2801461.37  5.02%  34.8   90s
#  157082 51563 2897672.15   32   66 2949466.86 2802538.70  4.98%  35.0   95s
#  164847 53638     cutoff   39      2949466.86 2803257.68  4.96%  35.3  100s
#  173346 55816 2910489.61   37   15 2949466.86 2804003.37  4.93%  35.5  105s
# H178865 57084                    2949466.8644 2804471.97  4.92%  35.6  107s
#  182218 58043     cutoff   41      2949466.86 2804812.23  4.90%  35.7  110s
#  189681 59741 2883338.38   31   65 2949466.86 2805434.14  4.88%  35.9  115s
#  199112 61749 2899482.79   33   62 2949466.86 2806211.37  4.86%  36.1  120s
#
# Cutting planes:
#   Gomory: 1
#   Cover: 7
#   Implied bound: 6
#   Projected implied bound: 6
#   Clique: 5
#   MIR: 50
#   Flow cover: 32
#   RLT: 314
#   Relax-and-lift: 47
#   BQP: 1
#
# Explored 199350 nodes (7195286 simplex iterations) in 120.00 seconds (132.26 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 2.94947e+06 2.94947e+06 2.95005e+06 ... 2.97538e+06
#
# Time limit reached
# Warning: max constraint violation (1.4892e-06) exceeds tolerance
# Best objective 2.949466864392e+06, best bound 2.806237548766e+06, gap 4.8561%
#
# User-callback calls 408374, time in user-callback 0.03 sec
# CSV file exported to: Results/Mean_cost/profiles_demand_flex100_vre100.csv
# INSTALLED POWER RESULTS
# [778.8943686704631, 1699.2175206397208, 229.9999637192981, 0.0, 1931.9999970138392]
# CSV file exported to: Results/Mean_cost/power_demand_flex100_vre100.csv
