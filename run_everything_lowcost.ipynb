# %%
# Introduction of the packages
using Pkg
Pkg.add("CSV")
Pkg.add("DataFrames")
Pkg.add("JuMP")
Pkg.add("Gurobi")
#Pkg.add("NLopt")

using CSV, DataFrames, JuMP, Gurobi
# Out:
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.9/Project.toml`
#   No Changes to `~/.julia/environments/v1.9/Manifest.toml`
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.9/Project.toml`
#   No Changes to `~/.julia/environments/v1.9/Manifest.toml`
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.9/Project.toml`
#   No Changes to `~/.julia/environments/v1.9/Manifest.toml`
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.9/Project.toml`
#   No Changes to `~/.julia/environments/v1.9/Manifest.toml`

# %%
# Read the CSVs
SCALE_MWH = 1000
SCALE_DOLLAR = 1000

# CHANGE THIS FOR HIGH COST SCENARIO
scenario = "min" # "max" or "mean"

fixed_cost = CSV.read("data/fixed_cost_"*scenario*".csv",DataFrame) ./ SCALE_DOLLAR
variable_cost = CSV.read("data/variable_cost_"*scenario*".csv",DataFrame) ./ SCALE_DOLLAR
co2_intensity = CSV.read("data/co2_intensity.csv",DataFrame)
curtailment_costs = [0, 2, 0, 0, 0, 0] ./ SCALE_DOLLAR
ramp_limits = CSV.read("data/ramp_limits.csv", DataFrame)

# AVAILABILITY
P_max_s = 95897829.43 / SCALE_MWH
P_max_w = 11158008 / SCALE_MWH;

Availability_matrix = CSV.read("data/Availability.csv", DataFrame);
println(size(Availability_matrix))

############### Constants of the model 

eta = 0.8; # Efficiency of the battery
CO2_price = 100; # price of the CO2 per ton
H = 2;

################ Time to consider

# T = 50
# T_start = 987
# println("Timespan: ", T)
# println("Starting at hour: ", T_start)
# time_ls_opt = 1:T
# time_ls_clipped = 2:T-1 # For rate of change calculations

T = 50
T_start = 4960
time_ls_opt = T_start-24:T_start+24


hrs = 4000
hre = 5000
sel_hrs = hrs:hre
println(sel_hrs)
techs = 5
n_eu = 4
# pad year by 1 day
add_h = 24


println("Timespan: ", T)
#time_ls = 1+add_h:T-add_h
time_ls = T_start-24+1:T_start+24-add_h
vre_ls = 1:2
fossil_ls = 3:4
batt_ind = 5;
# Out:
# (8760, 5)
# 4000:5000
# Timespan: 50

# %%
######## Need to create a loop on that ========

name_demand_flex_input = [
    "demand_flex0_vre0", 
    "demand_flex50_vre0", 
    "demand_flex50_vre50", 
    "demand_flex50_vre100", 
    "demand_flex100_vre0", 
    "demand_flex100_vre50",
    "demand_flex100_vre100"
    ]
println("Starting Loop")
for name in name_demand_flex_input
    println(name)
    file_to_read = "data/"*name*".csv"
    println("Reading scenario $file_to_read")

    demand = Matrix(CSV.read(file_to_read, DataFrame)) ./ SCALE_MWH;
    println("Loaded demand with size ", size(demand))

    #######################################

    println("Cost")
    C_FC = fixed_cost[1:techs,1]
    C_FOM = fixed_cost[1:techs,2]
    C_VOM = variable_cost[1:techs,1]
    E_CO2 = co2_intensity[1:techs,1]
    C_ramp = variable_cost[1:techs,2]
    C_start = variable_cost[1:techs,3]
    C_curt = curtailment_costs[1:techs]

    println("Demand")
    D_b = demand[:] # Baseline demand with no flex
    println(size(D_b))
    D_b = vcat(reverse(reverse(demand)[1:add_h]), D_b, D_b[1:24])
    println(size(D_b))
    total_demand = D_b
    X_D = D_b

    A_r = ramp_limits[1:techs, 1]
    println("Availability")
    A_s = Availability_matrix[:,1:techs]
    println("Try reverse")
    A_s = vcat(reverse(reverse(Availability_matrix)[1:add_h, 1:techs]), A_s, A_s[1:24, 1:techs])
    println(size(A_s))
    # over time, opt each year with worst day for availability and highest demand?

    n = size(C_FC, 1) # number of technologies
    println("Number of technologies: ", n)

    ###### MODEL ######

    model = Model(Gurobi.Optimizer) # TODO: options? other optimizers?
    set_optimizer_attribute(model, "NonConvex", 2)
    #set_optimizer_attribute(model, "IterationLimit", 10000000)
    set_optimizer_attribute(model, "TimeLimit", 120)
    println("Model: initialized!\n")

    ###### MAIN VARIABLES ######
    # Non-negativity constraints
    # The installed power capacity of the mix
    @variable(model, P[1:n] >= 0)

    # The hourly power generation of each technology
    @variable(model, X_gen[time_ls_opt, 1:n] >= 0); # hourly production/use for each technology

    # Curtailment (only renewables?)
    @variable(model, X_cur[time_ls_opt, 1:n] >= 0); # hourly production/use for each technology

    ###### CONSTRAINTS ######

    # Demand constraint - meet demand per hour
    println("Demand constraint")
    @constraint(model, Con_dh[t = time_ls_opt], sum(X_gen[t, i] for i in 1:n) >= X_D[t]); # TODO: add curtailment
    # Meet total demand
    # @constraint(model, Con_d, sum(X_gen[t, i] for i in 1:n for t in time_ls_opt) >= sum(total_demand));

    # Installed capacity renewables < max capacity
    println("Renewable maximum installed capacity constraint")
    @constraint(model, Con_sgen, P[1] <= P_max_s);
    @constraint(model, Con_wgen, P[2] <= P_max_w);

    # println("Renewable minimum installed capacity constraint")
    #@constraint(model, Con_solar_lb, P[1] >= 50);
    #@constraint(model, Con_wind_lb, P[2] >= 600);

    # Storage variable
    println("Storage variable")
    @variable(model, 0<= X_soc[time_ls_opt] <=1)
    @variable(model, X_ch[time_ls_opt]>=0)

    # Cannot produce more than the installed power
    # println("Installed power constraint")
    # @constraint(model, Con_p[i = 1:n, t = time_ls_opt], X_gen[t, i] <= P[i])

    # For each tech, at each hour, usage cannot exceed available capacity
    println("Availability & installed power constraint")
    @constraint(model, [i = 1:n, t = time_ls_opt], X_gen[t, i] <= P[i]*A_s[t, i])
    # Renewables produce maximum possible capacity
    @constraint(model, [i = vre_ls, t = time_ls_opt], X_gen[t, i] >= 0.7*P[i]*A_s[t, i]) 


    println("Availability & installed power constraint")
    @constraint(model, [i = 1:n, t = time_ls_opt], X_gen[t, i] <= P[i]*A_s[t, i])

    println("Curtailment definition")
    @constraint(model, [t = time_ls_opt], sum(X_cur[t, i] for i in 1:n) == sum(X_gen[t, i] for i in 1:n) - X_D[t]) 
    @constraint(model, [i = 1:n, t = time_ls_opt], X_cur[t, i] <= X_gen[t, i])

    # Cannot produce less than the minimum stable generation: X_gen must be zero or min to max
    # min_usage = [0, 0.1, 0, 0] #TODO - cant be more than ramp
    # @constraint(model, [i = 1:n, t = time_ls_opt], X_gen[t, i] >= P[i]*min_usage[i])

    # For each tech, at each hour, change in production cannot exceed ramp rate (TODO might need to convert this to time)
    # println("Ramp constraint")
    # Auxiliary variables to linearize the rate of change constraint
    # @constraint(model, Con_rdwn[i = 1:n, t = time_ls_clipped], (X_gen[t+1, i] - X_gen[t, i]) >= -A_r[i]*X_gen[t, i]) 
    # @constraint(model, Con_rup[i = 1:n, t = time_ls_clipped], (X_gen[t+1, i] - X_gen[t, i]) <= A_r[i]*X_gen[t, i]);

    M = 10000000
    
    # println("Cold Start")
    # @variable(model, Cold_start[time_ls_opt, i = 1:4], Bin)
    # @constraint(model, [i = 1:4, t in time_ls_clipped], (X_gen[t, i] - X_gen[t-1, i])*X_gen[t, i] <= M*Cold_start[t, i])
    # @constraint(model, [i = 1:4, t in time_ls_clipped], -(X_gen[t, i] - X_gen[t-1, i])*X_gen[t, i] <= M*Cold_start[t, i])

    # Storage model

    # Need to put this conditions above
    @variable(model, Z_X_gen_greater_X_D[time_ls_opt], Bin)

    @constraint(model, Z_X_gen_greater_X_D_1[t in time_ls_opt], sum(X_gen[t,i] for i in 1:4) - X_D[t] <= M*Z_X_gen_greater_X_D[t])
    @constraint(model, Z_X_gen_greater_X_D_2[t in time_ls_opt], -sum(X_gen[t,i] for i in 1:4) + X_D[t] <= M*(1-Z_X_gen_greater_X_D[t]))


    # X_1, X_2, X_3 = [eta*(sum(X_gen[t,i] for i in Power_generation_ls)- X_D[t]) , eta*P3], (1- X_soc[t])*P[5]* H]
    @variable(model, z1[t in time_ls_opt], Bin)
    @variable(model, z2[t in time_ls_opt], Bin)

    # z_1 equal 1 if eta*(x_g_t -x_d) is is greatter than eta*E_max*delta t
    println("Z_1 expression")
    @constraint(model, z_1_1[t in time_ls_opt], eta*P[5] - eta*(sum(X_gen[t,i] for i in 1:4)- X_D[t])   <=  M*z1[t])
    @constraint(model, z_1_2[t in time_ls_opt], -eta*P[5] + eta*(sum(X_gen[t,i] for i in 1:4)- X_D[t]) <= M*(1-z1[t]))


    #Minimum between X_1 and X_2
    @variable(model, min_X_1_X_2[time_ls_opt])

    println("Min X_1, X_2 expression")
    @constraint(model, X_1_X_2_lower_1[t in time_ls_opt], min_X_1_X_2[t] <= eta*(sum(X_gen[t,i] for i in 1:4)- X_D[t]))
    @constraint(model, X_1_X_2_lower_2[t in time_ls_opt], min_X_1_X_2[t] <= eta*P[5])
    @constraint(model, X_1_X_2_higher_1[t in time_ls_opt], min_X_1_X_2[t] >= eta*(sum(X_gen[t,i] for i in 1:4)- X_D[t]) - M*(1-z1[t]))
    @constraint(model, X_1_X_2_higher_2[t in time_ls_opt], min_X_1_X_2[t] >= eta*P[5] - M*z1[t])


    # z_2 equal 1 if min(X_1, X_2) is is greater than (1- x_soc[t])*h*E_max
    println(" Take the min of min(X_1, X_2) and X_3")
    @constraint(model, z_2_1[t in time_ls_opt], (1- X_soc[t])* P[5] * H - min_X_1_X_2[t] <=  M*z2[t])
    @constraint(model, z_2_2[t in time_ls_opt], - (1- X_soc[t]) * P[5] * H + min_X_1_X_2[t] <= M*(1-z2[t]))


    # Constraint for the variable X_ch
    println(" Take the overall min")
    @variable(model, min_X_1_X_2_X_3[time_ls_opt])

    @constraint(model, X_1_X_2_X_3_lower_1[t in time_ls_opt], min_X_1_X_2_X_3[t] <= min_X_1_X_2[t])
    @constraint(model, X_1_X_2_X_3_lower_2[t in time_ls_opt], min_X_1_X_2_X_3[t] <= (1- X_soc[t])*P[3]* H)
    @constraint(model, X_1_X_2_X_3_higher_1[t in time_ls_opt], min_X_1_X_2_X_3[t] >= min_X_1_X_2[t] - M*(1-z2[t]))
    @constraint(model, X_1_X_2_X_3_higher_2[t in time_ls_opt], min_X_1_X_2_X_3[t] >= (1- X_soc[t])*P[3]* H - M*z2[t]);

    #Expression of X_ch
    @constraint(model, X_ch_expression[t in time_ls_opt], X_ch[t]  == Z_X_gen_greater_X_D[t]*min_X_1_X_2_X_3[t]);
    @variable(model, y2[time_ls_opt], Bin)

    # z_2 equal 1 if min(X_1, X_2) is is greater than (1- x_soc[t])*h*E_max
    println(" Take the min of min(X_1, X_2) and X_3")
    @constraint(model, y_2_1[t in time_ls_opt], X_soc[t]* P[5] * H - P[5] <=  M*y2[t])
    @constraint(model, y_2_2[t in time_ls_opt], - X_soc[t] * P[5] * H + P[5] <= M*(1-y2[t]))

    # Constraint for the variable X_ch
    println(" Take the overall min")
    @variable(model, min_extra_prod_P5_soc[time_ls_opt])

    @constraint(model, min_extra_prod_P5_soc_lower_1[t in time_ls_opt], min_extra_prod_P5_soc[t] <= P[5])
    @constraint(model, min_extra_prod_P5_soc_lower_2[t in time_ls_opt], min_extra_prod_P5_soc[t] <= X_soc[t]*P[5]* H)
    @constraint(model, min_extra_prod_P5_soc_higher_1[t in time_ls_opt], min_extra_prod_P5_soc[t] >= P[5] - M*(1-y2[t]))
    @constraint(model, min_extra_prod_P5_soc_higher_2[t in time_ls_opt], min_extra_prod_P5_soc[t] >= X_soc[t]*P[5]* H - M*y2[t]);

    @variable(model, batt_dispatch[time_ls_opt], Bin)

    #Expression of X_dch
    @constraint(model, X_dch_expression[t in time_ls_opt], X_gen[t,5]  <= batt_dispatch[t]*min_extra_prod_P5_soc[t]);


    # First hour need to be equal to one
    # Start with a charged battery
    @constraint(model, SOC_t_1, X_soc[time_ls_opt[1]] == 0)

    #
    @constraint(model, SOC_t[t in time_ls_opt[2]:time_ls_opt[end]], (X_soc[t]-X_soc[t-1])*H*P[5] == (X_ch[t-1]- X_gen[t-1,5]));

    # MODEL OBJECTIVE FUNCTION
    #TODO RAMP AND STARTUP COSTS

    println("Initialize Objective")

    @objective(model, Min, 
        (
            sum((C_FC[i] + C_FOM[i])*P[i] for i in 1:n) + # FIXED COSTS
            sum(sum((C_VOM[i] + CO2_price* E_CO2[i])* X_gen[t, i] for i in 1:n) for t in time_ls_opt) + # VARIABLE COSTS
            sum(sum(C_curt[i] * X_cur[t, i] for i in 1:n) for t in time_ls) # CURTAILMENT COSTS
    ));

    #Optimize
    println("Optimize model")
    optimize!(model)

    # Save the results for the generation
    # Assuming your matrix is named `my_matrix`
    my_matrix = [value.(X_gen) value.(X_soc) X_D[time_ls_opt]]  # Replace this with your actual matrix
    # Column names

    column_names = ["Solar", "Wind", "CCGT", "Coal", "Battery", "State_of_Charge", "Demand"]

    # Create a DataFrame with vectors for each column
    df = DataFrame([Symbol(name) => my_matrix[:, i] for (i, name) in enumerate(column_names)])

    # Specify the file path for your CSV file
    csv_file_path = "Results/Low_cost/profiles_" * name * ".csv"

    # Export the DataFrame to CSV
    CSV.write(csv_file_path, df)

    println("CSV file exported to: $csv_file_path")

    # Save the results for the power installed power
    # Assuming your matrix is named `my_matrix`
    Power = value.(P)   # Replace this with your actual matrix
    # Column names
    println("INSTALLED POWER RESULTS")
    println(Power)
    column_names_power = "Installed Power"

    # Create a DataFrame with vectors for each column
    df_Power = DataFrame(Symbol(column_names_power) => Power)

    # Specify the file path for your CSV file
    csv_file_path_power = "Results/Low_cost/power_" * name * ".csv"

    # Export the DataFrame to CSV
    CSV.write(csv_file_path_power, df_Power)

    println("CSV file exported to: $csv_file_path_power")
end
# Out:
# Starting Loop
# demand_flex0_vre0
# Reading scenario data/demand_flex0_vre0.csv
# Loaded demand with size (8759, 1)
# Cost
# Demand
# (8759,)
# (8807,)
# Availability
# Try reverse
# (8808, 5)
# Number of technologies: 5
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-09-07
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 120
# Model: initialized!
#
# Demand constraint
# Renewable maximum installed capacity constraint
# Storage variable
# Availability & installed power constraint
# Availability & installed power constraint
# Curtailment definition
# Z_1 expression
# Min X_1, X_2 expression
#  Take the min of min(X_1, X_2) and X_3
#  Take the overall min
#  Take the min of min(X_1, X_2) and X_3
#  Take the overall min
# Initialize Objective
# Optimize model
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 120
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1522 rows, 985 columns and 4720 nonzeros
# Model fingerprint: 0x7826ade2
# Model has 538 quadratic constraints
# Variable types: 740 continuous, 245 integer (245 binary)
# Coefficient statistics:
#   Matrix range     [9e-04, 1e+07]
#   QMatrix range    [1e+00, 2e+00]
#   QLMatrix range   [1e+00, 1e+07]
#   Objective range  [2e-03, 1e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [4e+02, 1e+07]
#   QRHS range       [1e+07, 1e+07]
# Presolve added 4 rows and 64 columns
# Presolve time: 0.01s
# Presolved: 2489 rows, 1194 columns, 7207 nonzeros
# Presolved model has 239 bilinear constraint(s)
# Variable types: 951 continuous, 243 integer (243 binary)
#
# Root relaxation: objective 1.286089e+06, 669 iterations, 0.00 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1286089.14    0  130          - 1286089.14      -     -    0s
#      0     0 1365854.41    0  131          - 1365854.41      -     -    0s
#      0     0 1441795.56    0  131          - 1441795.56      -     -    0s
#      0     0 1441795.56    0  128          - 1441795.56      -     -    0s
#      0     2 1441795.56    0  128          - 1441795.56      -     -    0s
# * 1285  1291             119    5.678888e+08 1441795.56   100%  17.2    0s
# * 1288  1291             120    5.662410e+08 1441795.56   100%  17.4    0s
# * 1299  1285             143    3.181781e+08 1441795.56   100%  17.6    0s
# * 1303  1285             145    3.166793e+08 1441795.56   100%  17.7    0s
# * 1367   839             113    1.340805e+07 1441795.56  89.2%  18.3    0s
# * 1414   787             115    1.339729e+07 1532100.28  88.6%  18.6    0s
#   1797  1040 2476463.63   28   57 1.3397e+07 2354035.16  82.4%  22.4    5s
# * 2183  1206              80    4256855.4147 2354035.16  44.7%  22.0    5s
# * 2569  1003              96    4098181.3643 2354035.16  42.6%  21.5    5s
# * 2642   922             100    4095275.2450 2354035.16  42.5%  21.4    5s
# * 2645   881             102    4093851.7122 2354035.16  42.5%  21.4    5s
# * 2648   843             103    4093783.1589 2354035.16  42.5%  21.4    5s
# * 2705   825              84    3442832.9317 2354035.16  31.6%  21.3    5s
# * 2817   699              89    3442109.2724 2354035.16  31.6%  21.0    5s
# * 2818   667              90    3442073.1130 2354035.16  31.6%  21.0    5s
# * 2851   625             129    3313182.3971 2354035.16  28.9%  20.8    5s
# * 2852   596             128    3313182.2798 2354035.16  28.9%  20.7    5s
# * 2853   568             127    3313182.1564 2354035.16  28.9%  20.7    5s
# * 2854   542             126    3313182.0264 2354035.16  28.9%  20.7    5s
# * 2879   472             105    2778361.3495 2354035.16  15.3%  20.7    5s
# * 2880   447             105    2772979.5450 2354035.16  15.1%  20.7    5s
# * 3150   445              46    2772790.9557 2392131.74  13.7%  20.9    5s
# * 3455   445             141    2772790.6972 2438652.78  12.1%  20.7    5s
# * 4613   716              65    2766109.3421 2471315.72  10.7%  21.4    6s
# * 5824  1093              98    2739261.1188 2487170.82  9.20%  21.7    7s
# * 6606  1257             103    2737940.5753 2492940.12  8.95%  21.6    7s
# * 6939  1313              50    2733420.6307 2492940.12  8.80%  21.7    7s
# * 6943  1304              51    2728039.1367 2492940.12  8.62%  21.7    7s
# * 6948  1294              53    2726765.0490 2492940.12  8.58%  21.7    7s
# * 6952  1292              54    2726248.7622 2492940.12  8.56%  21.7    7s
# * 6956  1292              55    2726038.8634 2492940.12  8.55%  21.7    7s
# * 6962  1292              58    2726008.8563 2492940.12  8.55%  21.7    7s
# * 6967  1292              60    2726001.6124 2492940.12  8.55%  21.6    7s

#
# Cutting planes:
#   Learned: 1
#   Gomory: 16
#   Implied bound: 14
#   Projected implied bound: 4
#   Clique: 3
#   MIR: 56
#   Flow cover: 104
#   RLT: 344
#   Relax-and-lift: 6
#
# Explored 129141 nodes (1167426 simplex iterations) in 54.58 seconds (41.19 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 2.70251e+06 2.70251e+06 2.70251e+06 ... 2.70298e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Warning: max constraint violation (1.9777e-06) exceeds tolerance
# Best objective 2.702507686357e+06, best bound 2.702242713092e+06, gap 0.0098%
#
# User-callback calls 262792, time in user-callback 0.02 sec
# CSV file exported to: Results/Low_cost/profiles_demand_flex0_vre0.csv
# INSTALLED POWER RESULTS
# [1219.2394639798686, 1566.853449187215, 302.5564252755744, 0.0, 2854.1838292079474]
# CSV file exported to: Results/Low_cost/power_demand_flex0_vre0.csv
# demand_flex50_vre0
# Reading scenario data/demand_flex50_vre0.csv
# Loaded demand with size (8759, 1)
# Cost
# Demand
# (8759,)
# (8807,)
# Availability
# Try reverse
# (8808, 5)
# Number of technologies: 5
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-09-07
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 120
# Model: initialized!
#
# Demand constraint
# Renewable maximum installed capacity constraint
# Storage variable
# Availability & installed power constraint
# Availability & installed power constraint
# Curtailment definition
# Z_1 expression
# Min X_1, X_2 expression
#  Take the min of min(X_1, X_2) and X_3
#  Take the overall min
#  Take the min of min(X_1, X_2) and X_3
#  Take the overall min
# Initialize Objective
# Optimize model
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 120
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1522 rows, 985 columns and 4720 nonzeros
# Model fingerprint: 0x94d810c9
# Model has 538 quadratic constraints
# Variable types: 740 continuous, 245 integer (245 binary)
# Coefficient statistics:
#   Matrix range     [9e-04, 1e+07]
#   QMatrix range    [1e+00, 2e+00]
#   QLMatrix range   [1e+00, 1e+07]
#   Objective range  [2e-03, 1e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+02, 1e+07]
#   QRHS range       [1e+07, 1e+07]
# Presolve added 4 rows and 64 columns
# Presolve time: 0.01s
# Presolved: 2489 rows, 1194 columns, 7207 nonzeros
# Presolved model has 239 bilinear constraint(s)
# Variable types: 951 continuous, 243 integer (243 binary)
#
# Root relaxation: objective 1.125890e+06, 682 iterations, 0.00 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1125889.53    0  134          - 1125889.53      -     -    0s
#      0     0 1216617.76    0  137          - 1216617.76      -     -    0s
#      0     0 1302737.98    0  135          - 1302737.98      -     -    0s
# H    0     0                    9.437147e+08 1302737.98   100%     -    0s
# H    0     0                    4.434259e+08 1302737.98   100%     -    0s
# H    0     2                    4.434152e+08 1302737.98   100%     -    0s
#      0     2 1302737.98    0  131 4.4342e+08 1302737.98   100%     -    0s
# H   32    40                    4.433343e+08 1302765.27   100%  84.4    0s
# *  363   380              42    3701410.3754 1443941.41  61.0%  15.3    0s
#   2802  1234 2196385.39   18   79 3701410.38 2161529.36  41.6%  28.0    5s
# H 3004  1252                    2708794.4977 2161529.36  20.2%  28.7    5s
# H 3005  1193                    2637321.0626 2161529.36  18.0%  28.7    5s
# * 3092  1136              43    2620295.4289 2161529.36  17.5%  28.8    5s
# * 3129  1084              45    2619184.5645 2161529.36  17.5%  28.7    5s
# * 3134  1033              49    2619065.1971 2161529.36  17.5%  28.7    5s
# * 3173   996              53    2619061.0719 2161529.36  17.5%  28.5    5s
# * 3234   946              68    2619060.9879 2161529.36  17.5%  28.3    5s
# * 3236   902              67    2619060.9835 2161529.36  17.5%  28.3    5s
# * 3269   853              66    2619060.9789 2228609.39  14.9%  28.3    5s
# * 3750   828              43    2615938.9118 2230161.95  14.7%  28.2    6s
# * 3754   790              44    2614724.9366 2230161.95  14.7%  28.2    6s
# * 3800   750              43    2613949.4684 2250380.23  13.9%  28.3    6s
# * 4037   700              58    2613027.8710 2250380.23  13.9%  28.2    6s
# * 4038   665              58    2611927.7559 2250380.23  13.8%  28.2    6s
# H 5125   967                    2611608.4995 2321720.63  11.1%  27.6    7s
# H 5156   967                    2611608.4986 2321720.63  11.1%  27.6    7s
# H 5158   957                    2606071.2308 2321720.63  10.9%  27.6    7s

#
# Cutting planes:
#   Gomory: 1
#   Cover: 15
#   Implied bound: 7
#   Projected implied bound: 4
#   Clique: 10
#   MIR: 60
#   Flow cover: 54
#   RLT: 265
#   Relax-and-lift: 37
#
# Explored 252228 nodes (4728261 simplex iterations) in 120.00 seconds (115.71 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 2.5773e+06 2.5773e+06 2.5773e+06 ... 2.57742e+06
#
# Time limit reached
# Warning: max constraint violation (1.6715e-06) exceeds tolerance
# Best objective 2.577301372122e+06, best bound 2.576392840658e+06, gap 0.0353%
#
# User-callback calls 511624, time in user-callback 0.04 sec
# CSV file exported to: Results/Low_cost/profiles_demand_flex50_vre0.csv
# INSTALLED POWER RESULTS
# [816.7931452566518, 1750.6593948330276, 265.630555846542, 0.0, 2629.9087508708453]
# CSV file exported to: Results/Low_cost/power_demand_flex50_vre0.csv
# demand_flex50_vre50
# Reading scenario data/demand_flex50_vre50.csv
# Loaded demand with size (8759, 1)
# Cost
# Demand
# (8759,)
# (8807,)
# Availability
# Try reverse
# (8808, 5)
# Number of technologies: 5
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-09-07
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 120
# Model: initialized!
#
# Demand constraint
# Renewable maximum installed capacity constraint
# Storage variable
# Availability & installed power constraint
# Availability & installed power constraint
# Curtailment definition
# Z_1 expression
# Min X_1, X_2 expression
#  Take the min of min(X_1, X_2) and X_3
#  Take the overall min
#  Take the min of min(X_1, X_2) and X_3
#  Take the overall min
# Initialize Objective
# Optimize model
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 120
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1522 rows, 985 columns and 4720 nonzeros
# Model fingerprint: 0xd4febdc3
# Model has 538 quadratic constraints
# Variable types: 740 continuous, 245 integer (245 binary)
# Coefficient statistics:
#   Matrix range     [9e-04, 1e+07]
#   QMatrix range    [1e+00, 2e+00]
#   QLMatrix range   [1e+00, 1e+07]
#   Objective range  [2e-03, 1e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+02, 1e+07]
#   QRHS range       [1e+07, 1e+07]
# Presolve added 4 rows and 64 columns
# Presolve time: 0.02s
# Presolved: 2489 rows, 1194 columns, 7207 nonzeros
# Presolved model has 239 bilinear constraint(s)
# Variable types: 951 continuous, 243 integer (243 binary)
#
# Root relaxation: objective 1.135579e+06, 679 iterations, 0.00 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1135579.22    0  131          - 1135579.22      -     -    0s
# H    0     0                    3.800606e+08 1135579.22   100%     -    0s
#      0     0 1440729.94    0  135 3.8006e+08 1440729.94   100%     -    0s
#      0     0 1440729.94    0  135 3.8006e+08 1440729.94   100%     -    0s
#      0     0 1440729.94    0  134 3.8006e+08 1440729.94   100%     -    0s
#      0     0 1474931.55    0  127 3.8006e+08 1474931.55   100%     -    0s
#      0     0 1474931.55    0  129 3.8006e+08 1474931.55   100%     -    0s
#      0     0 1474931.55    0  129 3.8006e+08 1474931.55   100%     -    0s
#      0     0 1474931.55    0  129 3.8006e+08 1474931.55   100%     -    0s
#      0     0 1474931.55    0  130 3.8006e+08 1474931.55   100%     -    0s
#      0     0 1474931.55    0  129 3.8006e+08 1474931.55   100%     -    0s
#      0     2 1474931.55    0  127 3.8006e+08 1474931.55   100%     -    0s
# H  317   362                    3.798975e+08 1491608.58   100%  13.7    0s
# H  359   362                    9.756455e+07 1491608.58  98.5%  13.3    0s
# *  360   362              43    1.071845e+07 1491608.58  86.1%  13.3    0s
# *  419   395              48    1.015501e+07 1491608.58  85.3%  16.6    0s
# *  425   395              53    1.015480e+07 1491608.58  85.3%  16.6    0s
# *  461   419              55    1.015480e+07 1491608.58  85.3%  16.9    0s
# H 1470   904                    3340437.6155 2046689.39  38.7%  21.5    3s
#   1510   931 2313957.04   14   71 3340437.62 2196635.93  34.2%  23.4    5s
# * 1930  1080              49    2740931.3532 2239632.59  18.3%  25.9    5s
# * 1967  1039              50    2740874.7255 2239632.59  18.3%  25.9    5s
# * 1968   997              50    2740849.0426 2239632.59  18.3%  25.9    5s
# * 1969   957              48    2740626.0345 2239632.59  18.3%  25.9    5s
# * 1970   920              47    2740278.6010 2239632.59  18.3%  25.9    5s

#
# Cutting planes:
#   Gomory: 1
#   Cover: 3
#   Implied bound: 7
#   Projected implied bound: 6
#   Clique: 3
#   MIR: 75
#   Flow cover: 29
#   RLT: 270
#   Relax-and-lift: 27
#
# Explored 264450 nodes (5571834 simplex iterations) in 120.01 seconds (108.23 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 2.46399e+06 2.46451e+06 2.46544e+06 ... 2.47081e+06
#
# Time limit reached
# Best objective 2.463994049731e+06, best bound 2.407409812636e+06, gap 2.2964%
#
# User-callback calls 537371, time in user-callback 0.04 sec
# CSV file exported to: Results/Low_cost/profiles_demand_flex100_vre0.csv
# INSTALLED POWER RESULTS
# [614.9291653545764, 1796.6311187529313, 257.2385280851294, 0.0, 2340.3086789117824]
# CSV file exported to: Results/Low_cost/power_demand_flex100_vre0.csv
# demand_flex100_vre50
# Reading scenario data/demand_flex100_vre50.csv
# Loaded demand with size (8760, 1)
# Cost
# Demand
# (8760,)
# (8808,)
# Availability
# Try reverse
# (8808, 5)
# Number of technologies: 5
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-09-07
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 120
# Model: initialized!
#
# Demand constraint
# Renewable maximum installed capacity constraint
# Storage variable
# Availability & installed power constraint
# Availability & installed power constraint
# Curtailment definition
# Z_1 expression
# Min X_1, X_2 expression
#  Take the min of min(X_1, X_2) and X_3
#  Take the overall min
#  Take the min of min(X_1, X_2) and X_3
#  Take the overall min
# Initialize Objective
# Optimize model
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 120
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1522 rows, 985 columns and 4720 nonzeros
# Model fingerprint: 0x06f6ff8e
# Model has 538 quadratic constraints
# Variable types: 740 continuous, 245 integer (245 binary)
# Coefficient statistics:
#   Matrix range     [9e-04, 1e+07]
#   QMatrix range    [1e+00, 2e+00]
#   QLMatrix range   [1e+00, 1e+07]
#   Objective range  [2e-03, 1e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+02, 1e+07]
#   QRHS range       [1e+07, 1e+07]
# Presolve added 4 rows and 64 columns
# Presolve time: 0.01s
# Presolved: 2489 rows, 1194 columns, 7207 nonzeros
# Presolved model has 239 bilinear constraint(s)
# Variable types: 951 continuous, 243 integer (243 binary)
#
# Root relaxation: objective 1.027940e+06, 675 iterations, 0.00 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1027940.41    0  154          - 1027940.41      -     -    0s
#      0     0 1114499.52    0  152          - 1114499.52      -     -    0s
#      0     0 1196908.64    0  152          - 1196908.64      -     -    0s
# H    0     0                    6.542312e+08 1196908.64   100%     -    0s
# H    0     0                    3.072463e+08 1196908.64   100%     -    0s
# H    0     2                    3.072224e+08 1196908.64   100%     -    0s
#      0     2 1196908.64    0  143 3.0722e+08 1196908.64   100%     -    0s
# H   31    40                    3.071773e+08 1196908.64   100%  91.3    0s
# H   35    40                    2.982638e+08 1196908.64   100%  83.1    0s
# H   87    96                    2.975589e+08 1246196.92   100%  40.9    0s
# *  267   318              37    2.715686e+08 1297197.35   100%  18.4    0s
# H  522   556                    1.227003e+08 1297197.35  98.9%  13.7    0s
# *  632   526              67    3959086.9821 1297197.35  67.2%  13.4    0s
# H 1476   735                    2622281.0821 2075914.22  20.8%  18.5    4s
#   1478   737 2091723.04   14   70 2622281.08 2091723.04  20.2%  19.9    5s
# * 2288   921             132    2573527.0507 2217191.42  13.8%  20.1    5s
# * 2289   886             132    2573526.9775 2217191.42  13.8%  20.1    5s
# * 2290   852             131    2573526.9005 2217191.42  13.8%  20.1    5s
# * 2291   820             130    2573526.8705 2217191.42  13.8%  20.1    5s
# * 2298   784              57    2473008.0270 2217191.42  10.3%  20.1    5s
# * 3200   773             116    2456199.5803 2242661.16  8.69%  18.5    6s
# * 3202   762             117    2453402.6183 2242661.16  8.59%  18.5    6s
#   9009  3042 2291148.13   43   75 2453402.62 2286112.94  6.82%  19.6   10s
# * 9267  2943             110    2453314.4870 2286112.94  6.82%  19.3   10s
# H13900  3654                    2439007.6329 2294854.83  5.91%  20.0   13s
# H13914  3653                    2438853.2997 2294854.83  5.90%  20.0   13s
# H15333  4010                    2438527.1663 2297338.46  5.79%  20.2   14s
