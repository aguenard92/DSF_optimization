# %%
# Introduction of the packages
using Pkg
Pkg.add("CSV")
Pkg.add("DataFrames")
Pkg.add("JuMP")
Pkg.add("Gurobi")
#Pkg.add("NLopt")

using CSV, DataFrames, JuMP, Gurobi
# Out:
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.9/Project.toml`
#   No Changes to `~/.julia/environments/v1.9/Manifest.toml`
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.9/Project.toml`
#   No Changes to `~/.julia/environments/v1.9/Manifest.toml`
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.9/Project.toml`
#   No Changes to `~/.julia/environments/v1.9/Manifest.toml`
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.9/Project.toml`
#   No Changes to `~/.julia/environments/v1.9/Manifest.toml`

# %%
# Read the CSVs
SCALE_MWH = 1000
SCALE_DOLLAR = 1000

# CHANGE THIS FOR HIGH COST SCENARIO
scenario = "max" # "max" or "mean"

fixed_cost = CSV.read("data/fixed_cost_"*scenario*".csv",DataFrame) ./ SCALE_DOLLAR
variable_cost = CSV.read("data/variable_cost_"*scenario*".csv",DataFrame) ./ SCALE_DOLLAR
co2_intensity = CSV.read("data/co2_intensity.csv",DataFrame)
curtailment_costs = [0, 2, 0, 0, 0, 0] ./ SCALE_DOLLAR
ramp_limits = CSV.read("data/ramp_limits.csv", DataFrame)

# AVAILABILITY
P_max_s = 95897829.43 / SCALE_MWH
P_max_w = 11158008 / SCALE_MWH;

Availability_matrix = CSV.read("data/Availability.csv", DataFrame);
println(size(Availability_matrix))

############### Constants of the model 

eta = 0.8; # Efficiency of the battery
CO2_price = 100; # price of the CO2 per ton
H = 2;

################ Time to consider

# T = 50
# T_start = 987
# println("Timespan: ", T)
# println("Starting at hour: ", T_start)
# time_ls_opt = 1:T
# time_ls_clipped = 2:T-1 # For rate of change calculations

T = 50
T_start = 4960
time_ls_opt = T_start-24:T_start+24


hrs = 4000
hre = 5000
sel_hrs = hrs:hre
println(sel_hrs)
techs = 5
n_eu = 4
# pad year by 1 day
add_h = 24


println("Timespan: ", T)
#time_ls = 1+add_h:T-add_h
time_ls = T_start-24+1:T_start+24-add_h
vre_ls = 1:2
fossil_ls = 3:4
batt_ind = 5;
# Out:
# (8760, 5)
# 4000:5000
# Timespan: 50

# %%
######## Need to create a loop on that ========

#name_demand_flex_input = [
#    "demand_flex0_vre0", 
 #   "demand_flex50_vre0", 
  #  "demand_flex50_vre50", 
   # "demand_flex50_vre100", 
    #"demand_flex100_vre0", 
    #"demand_flex100_vre50",
    #"demand_flex100_vre100"
    #]
name_demand_flex_input = [
    "demand_flex25_vre0", 
    "demand_flex25_vre50", 
    "demand_flex25_vre100", 
    "demand_flex75_vre0", 
    "demand_flex75_vre50", 
    "demand_flex75_vre100"
    ]
println("Starting Loop")
for name in name_demand_flex_input
    println(name)
    file_to_read = "data/"*name*".csv"
    println("Reading scenario $file_to_read")

    demand = Matrix(CSV.read(file_to_read, DataFrame)) ./ SCALE_MWH;
    println("Loaded demand with size ", size(demand))

    #######################################

    println("Cost")
    C_FC = fixed_cost[1:techs,1]
    C_FOM = fixed_cost[1:techs,2]
    C_VOM = variable_cost[1:techs,1]
    E_CO2 = co2_intensity[1:techs,1]
    C_ramp = variable_cost[1:techs,2]
    C_start = variable_cost[1:techs,3]
    C_curt = curtailment_costs[1:techs]

    println("Demand")
    D_b = demand[:] # Baseline demand with no flex
    println(size(D_b))
    D_b = vcat(reverse(reverse(demand)[1:add_h]), D_b, D_b[1:24])
    println(size(D_b))
    total_demand = D_b
    X_D = D_b

    A_r = ramp_limits[1:techs, 1]
    println("Availability")
    A_s = Availability_matrix[:,1:techs]
    println("Try reverse")
    A_s = vcat(reverse(reverse(Availability_matrix)[1:add_h, 1:techs]), A_s, A_s[1:24, 1:techs])
    println(size(A_s))
    # over time, opt each year with worst day for availability and highest demand?

    n = size(C_FC, 1) # number of technologies
    println("Number of technologies: ", n)

    ###### MODEL ######

    model = Model(Gurobi.Optimizer) # TODO: options? other optimizers?
    set_optimizer_attribute(model, "NonConvex", 2)
    #set_optimizer_attribute(model, "IterationLimit", 10000000)
    set_optimizer_attribute(model, "TimeLimit", 120)
    println("Model: initialized!\n")

    ###### MAIN VARIABLES ######
    # Non-negativity constraints
    # The installed power capacity of the mix
    @variable(model, P[1:n] >= 0)

    # The hourly power generation of each technology
    @variable(model, X_gen[time_ls_opt, 1:n] >= 0); # hourly production/use for each technology

    # Curtailment (only renewables?)
    @variable(model, X_cur[time_ls_opt, 1:n] >= 0); # hourly production/use for each technology

    ###### CONSTRAINTS ######

    # Demand constraint - meet demand per hour
    println("Demand constraint")
    @constraint(model, Con_dh[t = time_ls_opt], sum(X_gen[t, i] for i in 1:n) >= X_D[t]); # TODO: add curtailment
    # Meet total demand
    # @constraint(model, Con_d, sum(X_gen[t, i] for i in 1:n for t in time_ls_opt) >= sum(total_demand));

    # Installed capacity renewables < max capacity
    println("Renewable maximum installed capacity constraint")
    @constraint(model, Con_sgen, P[1] <= P_max_s);
    @constraint(model, Con_wgen, P[2] <= P_max_w);

    # println("Renewable minimum installed capacity constraint")
    #@constraint(model, Con_solar_lb, P[1] >= 50);
    #@constraint(model, Con_wind_lb, P[2] >= 600);

    # Storage variable
    println("Storage variable")
    @variable(model, 0<= X_soc[time_ls_opt] <=1)
    @variable(model, X_ch[time_ls_opt]>=0)

    # Cannot produce more than the installed power
    # println("Installed power constraint")
    # @constraint(model, Con_p[i = 1:n, t = time_ls_opt], X_gen[t, i] <= P[i])

    # For each tech, at each hour, usage cannot exceed available capacity
    println("Availability & installed power constraint")
    @constraint(model, [i = 1:n, t = time_ls_opt], X_gen[t, i] <= P[i]*A_s[t, i])
    # Renewables produce maximum possible capacity
    @constraint(model, [i = vre_ls, t = time_ls_opt], X_gen[t, i] >= 0.7*P[i]*A_s[t, i]) 


    println("Availability & installed power constraint")
    @constraint(model, [i = 1:n, t = time_ls_opt], X_gen[t, i] <= P[i]*A_s[t, i])

    println("Curtailment definition")
    @constraint(model, [t = time_ls_opt], sum(X_cur[t, i] for i in 1:n) == sum(X_gen[t, i] for i in 1:n) - X_D[t]) 
    @constraint(model, [i = 1:n, t = time_ls_opt], X_cur[t, i] <= X_gen[t, i])

    # Cannot produce less than the minimum stable generation: X_gen must be zero or min to max
    # min_usage = [0, 0.1, 0, 0] #TODO - cant be more than ramp
    # @constraint(model, [i = 1:n, t = time_ls_opt], X_gen[t, i] >= P[i]*min_usage[i])

    # For each tech, at each hour, change in production cannot exceed ramp rate (TODO might need to convert this to time)
    # println("Ramp constraint")
    # Auxiliary variables to linearize the rate of change constraint
    # @constraint(model, Con_rdwn[i = 1:n, t = time_ls_clipped], (X_gen[t+1, i] - X_gen[t, i]) >= -A_r[i]*X_gen[t, i]) 
    # @constraint(model, Con_rup[i = 1:n, t = time_ls_clipped], (X_gen[t+1, i] - X_gen[t, i]) <= A_r[i]*X_gen[t, i]);

    M = 10000000
    
    # println("Cold Start")
    # @variable(model, Cold_start[time_ls_opt, i = 1:4], Bin)
    # @constraint(model, [i = 1:4, t in time_ls_clipped], (X_gen[t, i] - X_gen[t-1, i])*X_gen[t, i] <= M*Cold_start[t, i])
    # @constraint(model, [i = 1:4, t in time_ls_clipped], -(X_gen[t, i] - X_gen[t-1, i])*X_gen[t, i] <= M*Cold_start[t, i])

    # Storage model

    # Need to put this conditions above
    @variable(model, Z_X_gen_greater_X_D[time_ls_opt], Bin)

    @constraint(model, Z_X_gen_greater_X_D_1[t in time_ls_opt], sum(X_gen[t,i] for i in 1:4) - X_D[t] <= M*Z_X_gen_greater_X_D[t])
    @constraint(model, Z_X_gen_greater_X_D_2[t in time_ls_opt], -sum(X_gen[t,i] for i in 1:4) + X_D[t] <= M*(1-Z_X_gen_greater_X_D[t]))


    # X_1, X_2, X_3 = [eta*(sum(X_gen[t,i] for i in Power_generation_ls)- X_D[t]) , eta*P3], (1- X_soc[t])*P[5]* H]
    @variable(model, z1[t in time_ls_opt], Bin)
    @variable(model, z2[t in time_ls_opt], Bin)

    # z_1 equal 1 if eta*(x_g_t -x_d) is is greatter than eta*E_max*delta t
    println("Z_1 expression")
    @constraint(model, z_1_1[t in time_ls_opt], eta*P[5] - eta*(sum(X_gen[t,i] for i in 1:4)- X_D[t])   <=  M*z1[t])
    @constraint(model, z_1_2[t in time_ls_opt], -eta*P[5] + eta*(sum(X_gen[t,i] for i in 1:4)- X_D[t]) <= M*(1-z1[t]))


    #Minimum between X_1 and X_2
    @variable(model, min_X_1_X_2[time_ls_opt])

    println("Min X_1, X_2 expression")
    @constraint(model, X_1_X_2_lower_1[t in time_ls_opt], min_X_1_X_2[t] <= eta*(sum(X_gen[t,i] for i in 1:4)- X_D[t]))
    @constraint(model, X_1_X_2_lower_2[t in time_ls_opt], min_X_1_X_2[t] <= eta*P[5])
    @constraint(model, X_1_X_2_higher_1[t in time_ls_opt], min_X_1_X_2[t] >= eta*(sum(X_gen[t,i] for i in 1:4)- X_D[t]) - M*(1-z1[t]))
    @constraint(model, X_1_X_2_higher_2[t in time_ls_opt], min_X_1_X_2[t] >= eta*P[5] - M*z1[t])


    # z_2 equal 1 if min(X_1, X_2) is is greater than (1- x_soc[t])*h*E_max
    println(" Take the min of min(X_1, X_2) and X_3")
    @constraint(model, z_2_1[t in time_ls_opt], (1- X_soc[t])* P[5] * H - min_X_1_X_2[t] <=  M*z2[t])
    @constraint(model, z_2_2[t in time_ls_opt], - (1- X_soc[t]) * P[5] * H + min_X_1_X_2[t] <= M*(1-z2[t]))


    # Constraint for the variable X_ch
    println(" Take the overall min")
    @variable(model, min_X_1_X_2_X_3[time_ls_opt])

    @constraint(model, X_1_X_2_X_3_lower_1[t in time_ls_opt], min_X_1_X_2_X_3[t] <= min_X_1_X_2[t])
    @constraint(model, X_1_X_2_X_3_lower_2[t in time_ls_opt], min_X_1_X_2_X_3[t] <= (1- X_soc[t])*P[3]* H)
    @constraint(model, X_1_X_2_X_3_higher_1[t in time_ls_opt], min_X_1_X_2_X_3[t] >= min_X_1_X_2[t] - M*(1-z2[t]))
    @constraint(model, X_1_X_2_X_3_higher_2[t in time_ls_opt], min_X_1_X_2_X_3[t] >= (1- X_soc[t])*P[3]* H - M*z2[t]);

    #Expression of X_ch
    @constraint(model, X_ch_expression[t in time_ls_opt], X_ch[t]  == Z_X_gen_greater_X_D[t]*min_X_1_X_2_X_3[t]);
    @variable(model, y2[time_ls_opt], Bin)

    # z_2 equal 1 if min(X_1, X_2) is is greater than (1- x_soc[t])*h*E_max
    println(" Take the min of min(X_1, X_2) and X_3")
    @constraint(model, y_2_1[t in time_ls_opt], X_soc[t]* P[5] * H - P[5] <=  M*y2[t])
    @constraint(model, y_2_2[t in time_ls_opt], - X_soc[t] * P[5] * H + P[5] <= M*(1-y2[t]))

    # Constraint for the variable X_ch
    println(" Take the overall min")
    @variable(model, min_extra_prod_P5_soc[time_ls_opt])

    @constraint(model, min_extra_prod_P5_soc_lower_1[t in time_ls_opt], min_extra_prod_P5_soc[t] <= P[5])
    @constraint(model, min_extra_prod_P5_soc_lower_2[t in time_ls_opt], min_extra_prod_P5_soc[t] <= X_soc[t]*P[5]* H)
    @constraint(model, min_extra_prod_P5_soc_higher_1[t in time_ls_opt], min_extra_prod_P5_soc[t] >= P[5] - M*(1-y2[t]))
    @constraint(model, min_extra_prod_P5_soc_higher_2[t in time_ls_opt], min_extra_prod_P5_soc[t] >= X_soc[t]*P[5]* H - M*y2[t]);

    @variable(model, batt_dispatch[time_ls_opt], Bin)

    #Expression of X_dch
    @constraint(model, X_dch_expression[t in time_ls_opt], X_gen[t,5]  <= batt_dispatch[t]*min_extra_prod_P5_soc[t]);


    # First hour need to be equal to one
    # Start with a charged battery
    @constraint(model, SOC_t_1, X_soc[time_ls_opt[1]] == 0)

    #
    @constraint(model, SOC_t[t in time_ls_opt[2]:time_ls_opt[end]], (X_soc[t]-X_soc[t-1])*H*P[5] == (X_ch[t-1]- X_gen[t-1,5]));

    # MODEL OBJECTIVE FUNCTION
    #TODO RAMP AND STARTUP COSTS

    println("Initialize Objective")

    @objective(model, Min, 
        (
            sum((C_FC[i] + C_FOM[i])*P[i] for i in 1:n) + # FIXED COSTS
            sum(sum((C_VOM[i] + CO2_price* E_CO2[i])* X_gen[t, i] for i in 1:n) for t in time_ls_opt) + # VARIABLE COSTS
            sum(sum(C_curt[i] * X_cur[t, i] for i in 1:n) for t in time_ls) # CURTAILMENT COSTS
    ));

    #Optimize
    println("Optimize model")
    optimize!(model)

    # Save the results for the generation
    # Assuming your matrix is named `my_matrix`
    my_matrix = [value.(X_gen) value.(X_soc) X_D[time_ls_opt]]  # Replace this with your actual matrix
    # Column names

    column_names = ["Solar", "Wind", "CCGT", "Coal", "Battery", "State_of_Charge", "Demand"]

    # Create a DataFrame with vectors for each column
    df = DataFrame([Symbol(name) => my_matrix[:, i] for (i, name) in enumerate(column_names)])

    # Specify the file path for your CSV file
    csv_file_path = "Results/Max_cost/profiles_" * name * ".csv"

    # Export the DataFrame to CSV
    CSV.write(csv_file_path, df)

    println("CSV file exported to: $csv_file_path")

    # Save the results for the power installed power
    # Assuming your matrix is named `my_matrix`
    Power = value.(P)   # Replace this with your actual matrix
    # Column names
    println("INSTALLED POWER RESULTS")
    println(Power)
    column_names_power = "Installed Power"

    # Create a DataFrame with vectors for each column
    df_Power = DataFrame(Symbol(column_names_power) => Power)

    # Specify the file path for your CSV file
    csv_file_path_power = "Results/Max_cost/power_" * name * ".csv"

    # Export the DataFrame to CSV
    CSV.write(csv_file_path_power, df_Power)

    println("CSV file exported to: $csv_file_path_power")
end
# Out:
# Starting Loop
# demand_flex25_vre0
# Reading scenario data/demand_flex25_vre0.csv
# Loaded demand with size (8759, 1)
# Cost
# Demand
# (8759,)
# (8807,)
# Availability
# Try reverse
# (8808, 5)
# Number of technologies: 5
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-09-07
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 120
# Model: initialized!
#
# Demand constraint
# Renewable maximum installed capacity constraint
# Storage variable
# Availability & installed power constraint
# Availability & installed power constraint
# Curtailment definition
# Z_1 expression
# Min X_1, X_2 expression
#  Take the min of min(X_1, X_2) and X_3
#  Take the overall min
#  Take the min of min(X_1, X_2) and X_3
#  Take the overall min
# Initialize Objective
# Optimize model
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 120
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1522 rows, 985 columns and 4720 nonzeros
# Model fingerprint: 0x45285afb
# Model has 538 quadratic constraints
# Variable types: 740 continuous, 245 integer (245 binary)
# Coefficient statistics:
#   Matrix range     [9e-04, 1e+07]
#   QMatrix range    [1e+00, 2e+00]
#   QLMatrix range   [1e+00, 1e+07]
#   Objective range  [2e-03, 1e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+02, 1e+07]
#   QRHS range       [1e+07, 1e+07]
# Presolve added 4 rows and 64 columns
# Presolve time: 0.01s
# Presolved: 2489 rows, 1194 columns, 7207 nonzeros
# Presolved model has 239 bilinear constraint(s)
# Variable types: 951 continuous, 243 integer (243 binary)
#
# Root relaxation: objective 1.582743e+06, 711 iterations, 0.00 seconds (0.02 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1582743.12    0  133          - 1582743.12      -     -    0s
# H    0     0                    5.516675e+08 1582743.12   100%     -    0s
#      0     0 2324534.42    0  132 5.5167e+08 2324534.42   100%     -    0s
# H    0     0                    5.154427e+08 2324534.42   100%     -    0s
# H    0     0                    5.154427e+08 2324534.42   100%     -    0s
#      0     0 2324534.42    0  133 5.1544e+08 2324534.42   100%     -    0s
#      0     0 2324534.42    0  128 5.1544e+08 2324534.42   100%     -    0s
#      0     0 2324534.42    0  128 5.1544e+08 2324534.42   100%     -    0s
#      0     0 2324534.42    0  130 5.1544e+08 2324534.42   100%     -    0s
#      0     0 2422876.78    0  128 5.1544e+08 2422876.78   100%     -    0s
#      0     2 2422876.78    0  127 5.1544e+08 2422876.78   100%     -    0s
# H  507   536                    1.059738e+08 2422876.78  97.7%  12.3    0s
# H  772   754                    8.344305e+07 2422876.78  97.1%  15.5    0s
# H  816   784                    8.198836e+07 2422876.78  97.0%  15.6    0s
# H  817   780                    7.234838e+07 2422876.78  96.7%  15.6    0s
# * 1001   670             128    1.518342e+07 2422876.78  84.0%  15.7    0s
# * 1002   670             129    1.499411e+07 2422876.78  83.8%  15.7    0s
# * 1007   670             131    1.498770e+07 2422876.78  83.8%  15.8    0s
# * 1099   695             134    1.498669e+07 2422876.78  83.8%  16.2    0s
# * 1102   695             135    1.498664e+07 2422876.78  83.8%  16.2    0s
# * 1212   745             140    1.498664e+07 2422876.78  83.8%  16.7    0s
# * 2122  1096              72    1.032906e+07 3198369.33  69.0%  21.5    4s
# * 2190  1097              58    7589148.0973 3198369.33  57.9%  21.5    4s
# * 2192  1054              59    5232359.0214 3198369.33  38.9%  21.5    4s
#   2276  1018     cutoff   62      5232359.02 3198369.33  38.9%  21.4    5s
# * 2292   973              59    4088784.1762 3198369.33  21.8%  21.4    5s
# * 2566   854              96    3976940.9312 3198369.33  19.6%  20.7    5s
# * 2614   756              96    3976271.7125 3198369.33  19.6%  20.7    5s
# * 2636   715              97    3976271.7116 3198369.33  19.6%  20.7    5s
# * 3010   622              63    3976271.6972 3198369.33  19.6%  21.3    5s
# * 3015   590              63    3976271.5761 3198369.33  19.6%  21.3    5s
# * 3464   750              68    3973617.3576 3198369.33  19.5%  21.4    5s
# * 3613   896              82    3973481.2507 3277865.27  17.5%  21.3    5s
# * 4104  1149              43    3941033.3088 3277865.27  16.8%  20.1    6s
# * 4107  1145              45    3936037.8940 3277865.27  16.7%  20.1    6s
# * 4109  1136              46    3932464.4059 3277865.27  16.6%  20.1    6s
# * 4112  1136              48    3932294.8537 3277865.27  16.6%  20.1    6s
# * 4521  1292              87    3932294.2605 3330984.25  15.3%  19.0    6s
# * 4659  1116              98    3913041.4119 3345671.36  14.5%  18.9    6s
# * 5662  1131              36    3896269.6092 3385855.57  13.1%  19.9    6s
# * 5666  1098              39    3884817.9373 3385855.57  12.8%  19.9    6s
# * 5668  1096              40    3883191.9064 3385855.57  12.8%  19.9    6s
# * 5674  1096              45    3882508.0124 3385855.57  12.8%  19.9    6s
# * 5819  1173              49    3882496.2371 3397188.40  12.5%  19.9    6s
# * 5822  1173              51    3882479.5233 3397188.40  12.5%  19.9    6s
# * 5911  1169              42    3881538.9723 3397188.40  12.5%  19.8    6s
# * 5914  1168              44    3881109.6218 3397188.40  12.5%  19.8    6s
# * 5917  1168              46    3880788.5373 3397188.40  12.5%  19.8    6s
# * 5920  1168              48    3880773.4667 3397188.40  12.5%  19.8    6s
# * 5923  1168              50    3880772.7721 3397188.40  12.5%  19.8    6s
# * 5926  1168              52    3880772.7437 3397188.40  12.5%  19.8    6s
# H 7191  1613                    3868422.5210 3436583.51  11.2%  20.9    7s
# * 8113  2072             119    3862901.8167 3444847.10  10.8%  20.5    8s
# * 8114  1980             119    3862065.5667 3444847.10  10.8%  20.5    8s
# H 9364  2302                    3852589.9712 3464668.64  10.1%  21.0    9s
#  10577  2862 3617879.86   32   20 3852589.97 3483905.12  9.57%  21.6   10s
# H10723  2862                    3852515.5400 3484142.37  9.56%  21.6   10s
# *10836  2968             106    3847027.1842 3485207.06  9.41%  21.6   10s
# *10838  2966             107    3846657.7644 3485207.06  9.40%  21.6   10s
# *10840  2964             108    3846505.0534 3485207.06  9.39%  21.6   10s
# *10846  2961             112    3846362.3590 3485207.06  9.39%  21.6   10s
# H14471  4104                    3845978.7029 3513157.62  8.65%  23.5   12s
# H15443  4204                    3845832.9338 3519212.44  8.49%  24.0   14s
#  16121  4590     cutoff   36      3845832.93 3522605.96  8.40%  24.1   15s
#  26833  7555 3692004.97   34   65 3845832.93 3543792.77  7.85%  26.6   20s
#  37619  9749 3598966.74   38   69 3845832.93 3551709.68  7.65%  27.7   25s
#  48002 11542     cutoff   48      3845832.93 3558162.32  7.48%  28.4   30s
#  60080 13636 3817175.08   40   13 3845832.93 3565323.60  7.29%  28.7   35s
#  70085 15026 3843051.74   45   59 3845832.93 3571107.38  7.14%  28.8   40s
#  81013 16417 3820838.76   44   62 3845832.93 3577413.16  6.98%  28.9   45s
#  91213 17597 3762984.37   41   13 3845832.93 3582037.07  6.86%  29.0   50s
#  100774 18647     cutoff   40      3845832.93 3586221.37  6.75%  29.0   55s
#  111111 19701 3729435.48   36   67 3845832.93 3590789.10  6.63%  29.0   60s
#  121355 20496 3606218.46   31   60 3845832.93 3595340.95  6.51%  29.1   65s
#  131756 21129     cutoff   39      3845832.93 3599973.20  6.39%  29.1   70s
#  141321 21431     cutoff   39      3845832.93 3604253.43  6.28%  29.2   75s
#  150087 21666     cutoff   39      3845832.93 3608457.03  6.17%  29.2   80s
#  159199 21634     cutoff   36      3845832.93 3612998.00  6.05%  29.2   85s
#  168869 21437     cutoff   35      3845832.93 3617662.47  5.93%  29.2   90s
#  179581 21237     cutoff   34      3845832.93 3622872.64  5.80%  29.2   95s
#  191108 20829 3822548.83   37   65 3845832.93 3628533.34  5.65%  29.2  100s
#  201486 20221     cutoff   29      3845832.93 3634941.60  5.48%  29.2  105s
#  212604 19327     cutoff   31      3845832.93 3642818.12  5.28%  29.2  110s
#  223910 18434     cutoff   40      3845832.93 3651867.16  5.04%  29.2  115s
#  235067 17663 3809179.94   41   13 3845832.93 3663067.51  4.75%  29.1  120s
#
# Cutting planes:
#   Gomory: 17
#   Cover: 3
#   Implied bound: 13
#   Projected implied bound: 2
#   Clique: 2
#   MIR: 65
#   Flow cover: 49
#   Inf proof: 1
#   RLT: 106
#   Relax-and-lift: 14
#   PSD: 1
#
# Explored 235125 nodes (6850558 simplex iterations) in 120.00 seconds (112.25 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 3.84583e+06 3.84598e+06 3.84636e+06 ... 3.8629e+06
#
# Time limit reached
# Best objective 3.845832933839e+06, best bound 3.663067505992e+06, gap 4.7523%
#
# User-callback calls 476435, time in user-callback 0.05 sec
# CSV file exported to: Results/Max_cost/profiles_demand_flex25_vre0.csv
# INSTALLED POWER RESULTS
# [1047.446575159946, 1598.9411541134145, 354.9999840562697, 0.0, 2496.618545796602]
# CSV file exported to: Results/Max_cost/power_demand_flex25_vre0.csv
# demand_flex25_vre50
# Reading scenario data/demand_flex25_vre50.csv
# Loaded demand with size (8759, 1)
# Cost
# Demand
# (8759,)
# (8807,)
# Availability
# Try reverse
# (8808, 5)
# Number of technologies: 5
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-09-07
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 120
# Model: initialized!
#
# Demand constraint
# Renewable maximum installed capacity constraint
# Storage variable
# Availability & installed power constraint
# Availability & installed power constraint
# Curtailment definition
# Z_1 expression
# Min X_1, X_2 expression
#  Take the min of min(X_1, X_2) and X_3
#  Take the overall min
#  Take the min of min(X_1, X_2) and X_3
#  Take the overall min
# Initialize Objective
# Optimize model
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 120
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1522 rows, 985 columns and 4720 nonzeros
# Model fingerprint: 0x28de5499
# Model has 538 quadratic constraints
# Variable types: 740 continuous, 245 integer (245 binary)
# Coefficient statistics:
#   Matrix range     [9e-04, 1e+07]
#   QMatrix range    [1e+00, 2e+00]
#   QLMatrix range   [1e+00, 1e+07]
#   Objective range  [2e-03, 1e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+02, 1e+07]
#   QRHS range       [1e+07, 1e+07]
# Presolve added 4 rows and 64 columns
# Presolve time: 0.01s
# Presolved: 2489 rows, 1194 columns, 7207 nonzeros
# Presolved model has 239 bilinear constraint(s)
# Variable types: 951 continuous, 243 integer (243 binary)
#
# Root relaxation: objective 1.596012e+06, 684 iterations, 0.00 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1596011.62    0  133          - 1596011.62      -     -    0s
#      0     0 1790629.94    0  132          - 1790629.94      -     -    0s
# H    0     0                    5.865955e+08 1790629.94   100%     -    0s
# H    0     0                    4.008931e+08 1980593.35   100%     -    0s
#      0     0 1980593.35    0  131 4.0089e+08 1980593.35   100%     -    0s
#      0     2 1980593.35    0  131 4.0089e+08 1980593.35   100%     -    0s
# H   82    96                    3.715830e+08 2253512.41  99.4%  33.9    0s
# H  646   618                    7.750714e+07 2253512.41  97.1%  18.7    0s
# H 1066   974                    7.750714e+07 2253512.41  97.1%  18.7    0s
# * 1436  1088             127    3.454397e+07 2253512.41  93.5%  17.6    0s
# * 1548  1110             129    3.437352e+07 2253512.41  93.4%  18.3    0s
# H 2273  1507                    1.048686e+07 3263393.88  68.9%  22.9    3s
# * 2341  1457              78    9838674.5933 3263393.88  66.8%  23.2    3s
# * 2343  1399              79    9606619.8361 3263393.88  66.0%  23.2    3s
# * 2346  1343              81    9531404.6647 3263393.88  65.8%  23.2    3s
# * 2417  1244              82    9499331.2512 3263393.88  65.6%  23.0    3s
# * 2418  1194              82    9475468.3078 3263393.88  65.6%  23.0    3s
# * 2420  1148              81    9419533.6450 3263393.88  65.4%  23.0    3s
# * 2421  1102              81    9377885.2062 3263393.88  65.2%  23.0    3s
# * 2458  1038              67    4234044.3535 3263393.88  22.9%  22.9    4s
# * 2465   996              70    4175195.1647 3263393.88  21.8%  22.9    4s
# * 2509   929              73    4159245.0510 3263393.88  21.5%  23.1    4s
# * 2528   887              83    3968486.1138 3263393.88  17.8%  23.0    4s
# * 2534   851              88    3967873.6220 3263393.88  17.8%  22.9    4s
# * 2536   817              89    3967842.9975 3263393.88  17.8%  22.9    4s
# * 2757   719             140    3967842.7120 3263393.88  17.8%  22.2    4s
# * 2762   689             138    3967842.6980 3263393.88  17.8%  22.2    4s
# * 3082   534             122    3921158.1476 3263393.88  16.8%  21.6    4s
# * 3437   570             107    3847386.1648 3263393.88  15.2%  21.7    4s
#   4241   863     cutoff   29      3847386.16 3426186.48  10.9%  21.9    5s
# H 4487   900                    3836566.8689 3434100.69  10.5%  22.9    5s
# H 8694  2693                    3836562.9826 3493635.09  8.94%  24.0    8s
#  11027  3626 3584284.89   41   64 3836562.98 3503998.57  8.67%  24.4   10s
# *14184  4432             113    3833866.2320 3511263.64  8.41%  24.4   11s
# *16406  5394             121    3833630.2474 3516617.87  8.27%  24.4   12s
# *16407  5394             120    3833630.1448 3516617.87  8.27%  24.4   12s
# *16412  5394             120    3833630.0975 3516617.87  8.27%  24.4   12s
# *16413  5394             118    3833630.0409 3516617.87  8.27%  24.4   12s
# H18193  5796                    3824411.4720 3520216.41  7.95%  25.0   13s
# H18408  5795                    3824398.3590 3520216.41  7.95%  25.0   13s
# H18659  5676                    3816987.4506 3520216.41  7.78%  25.3   14s
#  18774  5908     cutoff   42      3816987.45 3521217.06  7.75%  25.6   15s
# H24954  7421                    3814331.5499 3530865.59  7.43%  26.0   18s
#  28540  8491 3605236.11   36   16 3814331.55 3535323.95  7.31%  26.1   20s
#  40511 11036 3795983.36   40   63 3814331.55 3546564.89  7.02%  26.7   25s
#  51855 13043     cutoff   39      3814331.55 3554972.77  6.80%  26.9   30s
#  63643 14613 infeasible   38      3814331.55 3563069.33  6.59%  27.1   35s
#  75480 15788 3692381.49   37   65 3814331.55 3569992.40  6.41%  27.4   40s
#  86730 16616     cutoff   36      3814331.55 3576710.06  6.23%  27.7   45s
#  98837 17104     cutoff   45      3814331.55 3584420.26  6.03%  27.8   50s
#  110029 17263 3597045.92   36   62 3814331.55 3591363.47  5.85%  27.9   55s
#  121918 16968     cutoff   42      3814331.55 3599847.80  5.62%  28.0   60s
#  130824 16592     cutoff   36      3814331.55 3605923.17  5.46%  28.1   65s
#  143084 15608     cutoff   44      3814331.55 3616785.06  5.18%  28.2   70s
#  154098 14306 3632052.73   45   64 3814331.55 3630151.05  4.83%  28.2   75s
#  164959 12442 3673448.00   34   64 3814331.55 3648735.80  4.34%  28.2   80s
#  177178 11514     cutoff   52      3814331.55 3675224.05  3.65%  27.8   85s
#  190695  9602 3737058.38   51   65 3814331.55 3721017.41  2.45%  27.4   90s
#  202972  7617 3788584.13   40   59 3814331.55 3758213.64  1.47%  26.8   95s
#  216657  5590 3784896.11   51   63 3814331.55 3777712.77  0.96%  26.0  100s
#  230041  2747 3813551.22   67   62 3814331.55 3797730.77  0.44%  25.1  105s
# *238404  1665             127    3814324.8090 3809693.99  0.12%  24.5  108s
#  242842  2140     cutoff   67      3814324.81 3811860.97  0.06%  24.0  110s
# *243119  2118             117    3814324.3830 3811882.83  0.06%  24.0  110s
# *244426  2370             118    3814323.4159 3812251.85  0.05%  23.9  110s
# *253904  3526             127    3814319.7269 3813132.29  0.03%  23.0  112s
# *260395  4499             115    3814318.4393 3813489.47  0.02%  22.4  114s
#  261581  4670     cutoff   85      3814318.44 3813557.14  0.02%  22.3  115s
# *273003  5784             128    3814318.2478 3813816.19  0.01%  21.4  118s
#  277776  6258 3814277.73   77   61 3814318.25 3813893.06  0.01%  21.1  120s
#
# Cutting planes:
#   Gomory: 26
#   Cover: 1
#   Implied bound: 3
#   Projected implied bound: 2
#   MIR: 71
#   Flow cover: 51
#   Inf proof: 1
#   RLT: 245
#   Relax-and-lift: 1
#
# Explored 278677 nodes (5849712 simplex iterations) in 120.01 seconds (114.48 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 3.81432e+06 3.81432e+06 3.81432e+06 ... 3.82441e+06
#
# Time limit reached
# Warning: max constraint violation (3.7077e-06) exceeds tolerance
# Best objective 3.814318247773e+06, best bound 3.813900888507e+06, gap 0.0109%
#
# User-callback calls 565613, time in user-callback 0.06 sec
# CSV file exported to: Results/Max_cost/profiles_demand_flex25_vre50.csv
# INSTALLED POWER RESULTS
# [1090.703388738714, 1572.5358781207995, 350.91336420634957, 0.0, 2424.6003123680725]
# CSV file exported to: Results/Max_cost/power_demand_flex25_vre50.csv
# demand_flex25_vre100
# Reading scenario data/demand_flex25_vre100.csv
# Loaded demand with size (8759, 1)
# Cost
# Demand
# (8759,)
# (8807,)
# Availability
# Try reverse
# (8808, 5)
# Number of technologies: 5
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-09-07
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 120
# Model: initialized!
#
# Demand constraint
# Renewable maximum installed capacity constraint
# Storage variable
# Availability & installed power constraint
# Availability & installed power constraint
# Curtailment definition
# Z_1 expression
# Min X_1, X_2 expression
#  Take the min of min(X_1, X_2) and X_3
#  Take the overall min
#  Take the min of min(X_1, X_2) and X_3
#  Take the overall min
# Initialize Objective
# Optimize model
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 120
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1522 rows, 985 columns and 4720 nonzeros
# Model fingerprint: 0xb96343a1
# Model has 538 quadratic constraints
# Variable types: 740 continuous, 245 integer (245 binary)
# Coefficient statistics:
#   Matrix range     [9e-04, 1e+07]
#   QMatrix range    [1e+00, 2e+00]
#   QLMatrix range   [1e+00, 1e+07]
#   Objective range  [2e-03, 1e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+02, 1e+07]
#   QRHS range       [1e+07, 1e+07]
# Presolve added 4 rows and 64 columns
# Presolve time: 0.01s
# Presolved: 2489 rows, 1194 columns, 7207 nonzeros
# Presolved model has 239 bilinear constraint(s)
# Variable types: 951 continuous, 243 integer (243 binary)
#
# Root relaxation: objective 1.611037e+06, 678 iterations, 0.00 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1611036.95    0  134          - 1611036.95      -     -    0s
# H    0     0                    5.672237e+08 1611036.95   100%     -    0s
#      0     0 2155092.18    0  134 5.6722e+08 2155092.18   100%     -    0s
# H    0     0                    4.941529e+08 2155092.18   100%     -    0s
#      0     0 2155092.18    0  134 4.9415e+08 2155092.18   100%     -    0s
# H    0     0                    3.944304e+08 2155092.18  99.5%     -    0s
#      0     0 2525288.53    0  133 3.9443e+08 2525288.53  99.4%     -    0s
#      0     2 2525288.53    0  132 3.9443e+08 2525288.53  99.4%     -    0s
# H   64    80                    3.894762e+08 2525288.53  99.4%  30.4    0s
# H 1009   870                    7.242203e+07 2525288.53  96.5%  13.4    0s
# H 1768  1345                    5.959054e+07 3146427.18  94.7%  13.2    2s
# H 1768  1277                    2.263162e+07 3146427.18  86.1%  13.2    3s
# H 1768  1213                    2.263162e+07 3146427.18  86.1%  13.2    3s
# H 1801  1165                    2.263162e+07 3146427.18  86.1%  15.4    3s
# H 1889  1141                    2.263162e+07 3146427.18  86.1%  16.1    3s
# H 1970  1136                    2.263162e+07 3146427.18  86.1%  16.6    3s
# H 1973  1083                    2.263162e+07 3146427.18  86.1%  16.6    3s
# H 2351  1201                    6326873.7415 3146427.18  50.3%  19.0    3s
# * 2512  1152              87    6271179.6371 3146427.18  49.8%  19.4    4s
# * 2574  1051              89    5987763.5211 3146427.18  47.5%  19.4    4s
# * 2628  1011              92    5982397.7835 3146427.18  47.4%  19.5    4s
# * 2980   964              81    5855812.6040 3146427.18  46.3%  19.0    4s
# * 3039   816              80    5324886.1647 3146427.18  40.9%  19.1    4s
# * 3042   738              81    4889715.3292 3146427.18  35.7%  19.2    4s
# * 3045   698              83    4791592.0112 3146427.18  34.3%  19.1    4s
# * 3048   664              85    4772695.0890 3146427.18  34.1%  19.1    4s
# * 3078   640              86    4767457.4983 3146427.18  34.0%  19.3    4s
# * 3085   609              92    4767456.9494 3146427.18  34.0%  19.2    4s
# * 3092   577              97    4767455.9124 3146427.18  34.0%  19.2    4s
# * 3187   606             118    4426387.2385 3146427.18  28.9%  18.9    4s
# * 3431   494             115    3897245.4738 3146427.18  19.3%  18.8    4s
#   3510   449     cutoff  116      3897245.47 3225596.34  17.2%  19.1    5s
# * 3597   470              68    3888265.3077 3225596.34  17.0%  19.3    5s
# * 3604   470              74    3887937.6808 3225596.34  17.0%  19.3    5s
# * 3684   491              77    3887871.6498 3225596.34  17.0%  19.6    5s
# * 3692   491              84    3887869.6591 3225596.34  17.0%  19.5    5s
# * 3698   491              89    3887869.4610 3225596.34  17.0%  19.5    5s
# * 3701   491              89    3887869.3642 3225596.34  17.0%  19.5    5s
# * 3760   462              88    3887869.2201 3225596.34  17.0%  19.8    5s
# * 3763   462              87    3887869.0055 3225596.34  17.0%  19.8    5s
# * 3783   474              59    3883321.8757 3225596.34  16.9%  20.0    5s
# * 3786   470              59    3878207.3788 3225596.34  16.8%  20.1    5s
# * 3796   469              63    3876850.3477 3225596.34  16.8%  20.0    5s
# * 3862   500              68    3876771.0427 3225596.34  16.8%  20.2    5s
# * 3868   500              73    3876767.8194 3225596.34  16.8%  20.2    5s
# * 3871   500              75    3876767.0209 3225596.34  16.8%  20.2    5s
# * 3876   500              79    3876766.9126 3225596.34  16.8%  20.1    5s
# * 3884   500              83    3876766.8992 3225596.34  16.8%  20.1    5s
# * 3889   500              83    3876766.8858 3225596.34  16.8%  20.1    5s
# * 4522   858             127    3864842.7768 3355841.01  13.2%  20.6    5s
# * 4854  1027              82    3864842.7748 3355841.01  13.2%  20.7    6s
# * 7993  2562              76    3864842.7739 3418636.58  11.5%  23.9    9s
# * 8938  2822             116    3864723.0357 3428496.80  11.3%  24.7    9s
#   9149  3153 3843248.33   67   20 3864723.04 3430289.99  11.2%  24.7   10s
# *10031  3521             122    3858504.6594 3433576.22  11.0%  24.5   10s
# *10032  3472             122    3857624.1705 3433576.22  11.0%  24.5   10s
# *10421  3539             103    3852564.7434 3436783.19  10.8%  24.4   10s
# *10422  3536             103    3851896.5119 3436783.19  10.8%  24.4   10s
# *10589  3451             102    3834015.6910 3436989.99  10.4%  24.4   10s
# *11533  3780              64    3823223.2717 3441770.45  10.0%  24.8   11s
# *11535  3762              65    3820392.6333 3441770.45  9.91%  24.8   11s
# *11543  3756              72    3819528.5100 3441770.45  9.89%  24.8   11s
# *11547  3756              75    3819491.0449 3441770.45  9.89%  24.8   11s
# *11557  3756              80    3819489.6623 3441770.45  9.89%  24.8   11s
# *12184  3950              83    3819489.6602 3445457.18  9.79%  24.8   11s
# *12187  3950              82    3819489.6569 3445457.18  9.79%  24.8   11s
# H15016  4814                    3796137.6209 3456676.22  8.94%  26.3   14s
#  15077  5039 3519680.46   38   66 3796137.62 3456758.63  8.94%  26.4   15s
#  22659  8241 infeasible   54      3796137.62 3478910.92  8.36%  29.5   20s
# H28495 10225                    3796098.9747 3488323.55  8.11%  31.0   24s
#  29276 10847     cutoff   66      3796098.97 3489154.29  8.09%  31.2   25s
#  36516 13665 3561928.09   49   65 3796098.97 3496949.18  7.88%  32.3   30s
#  44098 16449 3536479.97   35   71 3796098.97 3503510.50  7.71%  33.6   35s
#  52144 19143 infeasible   65      3796098.97 3508369.80  7.58%  35.2   40s
#  59527 21372     cutoff   41      3796098.97 3512297.11  7.48%  36.2   45s
#  66947 23464 3678764.99   46   53 3796098.97 3515692.68  7.39%  37.3   50s
#  74118 25442 3635200.69   32   81 3796098.97 3518488.98  7.31%  39.0   55s
#  80314 27064 3525998.46   39   70 3796098.97 3520591.75  7.26%  40.7   60s
#  85500 28255 3578458.43   36   66 3796098.97 3522781.43  7.20%  41.3   65s
# H85610 28255                    3796064.6461 3522781.43  7.20%  41.3   65s
#  92187 30162     cutoff   47      3796064.65 3524978.99  7.14%  41.6   70s
#  98868 31806 3527983.44   45   68 3796064.65 3526910.74  7.09%  41.9   75s
#  107006 33629 3571348.36   49   62 3796064.65 3529315.79  7.03%  42.3   80s
#  114145 35290 3547879.12   39   71 3796064.65 3531245.59  6.98%  42.7   85s
#  121472 36937 3592064.74   46   64 3796064.65 3533166.74  6.93%  43.0   90s
#  128868 38321  postponed   43      3796064.65 3534163.48  6.90%  44.0   95s
#  129909 38568  postponed   62      3796064.65 3534163.48  6.90%  51.2  100s
#  130392 38654 infeasible   67      3796064.65 3534163.48  6.90%  59.2  105s
#  130862 38751  postponed   63      3796064.65 3534163.48  6.90%  66.9  110s
# H130867 38670                    3794712.4540 3534163.48  6.87%  67.0  110s
#  131481 38757 infeasible   75      3794712.45 3534163.48  6.87%  76.0  115s
#  132054 38816     cutoff   45      3794712.45 3534163.48  6.87%  84.9  120s
#
# Cutting planes:
#   Gomory: 30
#   Cover: 1
#   Implied bound: 2
#   Projected implied bound: 1
#   MIR: 19
#   Flow cover: 37
#   RLT: 266
#
# Explored 132063 nodes (11237674 simplex iterations) in 120.00 seconds (146.80 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 3.79471e+06 3.79606e+06 3.7961e+06 ... 3.82322e+06
#
# Time limit reached
# Warning: max constraint violation (1.9124e-06) exceeds tolerance
# Best objective 3.794712453982e+06, best bound 3.534163481733e+06, gap 6.8661%
#
# User-callback calls 274342, time in user-callback 0.03 sec
# CSV file exported to: Results/Max_cost/profiles_demand_flex25_vre100.csv
# INSTALLED POWER RESULTS
# [1137.1439060857865, 1544.5744981272276, 355.69085458119304, 0.0, 2358.6565475012203]
# CSV file exported to: Results/Max_cost/power_demand_flex25_vre100.csv
# demand_flex75_vre0
# Reading scenario data/demand_flex75_vre0.csv
# Loaded demand with size (8759, 1)
# Cost
# Demand
# (8759,)
# (8807,)
# Availability
# Try reverse
# (8808, 5)
# Number of technologies: 5
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-09-07
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 120
# Model: initialized!
#
# Demand constraint
# Renewable maximum installed capacity constraint
# Storage variable
# Availability & installed power constraint
# Availability & installed power constraint
# Curtailment definition
# Z_1 expression
# Min X_1, X_2 expression
#  Take the min of min(X_1, X_2) and X_3
#  Take the overall min
#  Take the min of min(X_1, X_2) and X_3
#  Take the overall min
# Initialize Objective
# Optimize model
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 120
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1522 rows, 985 columns and 4720 nonzeros
# Model fingerprint: 0x83eb1739
# Model has 538 quadratic constraints
# Variable types: 740 continuous, 245 integer (245 binary)
# Coefficient statistics:
#   Matrix range     [9e-04, 1e+07]
#   QMatrix range    [1e+00, 2e+00]
#   QLMatrix range   [1e+00, 1e+07]
#   Objective range  [2e-03, 1e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+02, 1e+07]
#   QRHS range       [1e+07, 1e+07]
# Presolve added 4 rows and 64 columns
# Presolve time: 0.01s
# Presolved: 2489 rows, 1194 columns, 7207 nonzeros
# Presolved model has 239 bilinear constraint(s)
# Variable types: 951 continuous, 243 integer (243 binary)
#
# Root relaxation: objective 1.418757e+06, 683 iterations, 0.00 seconds (0.02 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1418756.72    0  140          - 1418756.72      -     -    0s
# H    0     0                    3.737170e+08 1418756.72   100%     -    0s
#      0     0 2106854.23    0  139 3.7372e+08 2106854.23  99.4%     -    0s
#      0     0 2459063.54    0  139 3.7372e+08 2459063.54  99.3%     -    0s
#      0     2 2459063.54    0  138 3.7372e+08 2459063.54  99.3%     -    0s
# H   54    64                    3.512009e+08 2459063.54  99.3%  60.2    0s
# H   60    64                    3.416297e+08 2459063.54  99.3%  57.3    0s
# H  132   138                    3.415564e+08 2459063.54  99.3%  29.1    0s
# *  874   841             116    2.808008e+08 2459063.54  99.1%  17.7    0s
# *  963   898             118    2.805498e+08 2459063.54  99.1%  17.3    0s
# * 1457  1111             123    3.595005e+07 2459063.54  93.2%  18.2    1s
# H 1757   149                    4106951.0578 2459063.54  40.1%  19.0    1s
# H 1766   119                    3870673.3037 3193445.31  17.5%  18.9    3s
# * 2014   198              45    3870389.9590 3222326.22  16.7%  21.5    4s
# * 2075   209              56    3870370.7231 3222326.22  16.7%  21.9    4s
# * 2106   223              62    3870367.9302 3222326.22  16.7%  22.0    4s
# * 2181   266              71    3870367.8452 3222326.22  16.7%  22.2    4s
# * 2190   266              54    3845812.3001 3222326.22  16.2%  22.2    4s
# * 2195   266              58    3839112.6614 3222326.22  16.1%  22.1    4s
# * 2199   266              61    3838371.0153 3222326.22  16.0%  22.1    4s
# * 2226   269              62    3837976.1786 3222326.22  16.0%  22.4    4s
# * 2229   269              64    3837879.3094 3222326.22  16.0%  22.4    4s
# * 2231   269              65    3837824.2650 3222326.22  16.0%  22.4    4s
# * 2258   289              69    3837810.7601 3222326.22  16.0%  22.3    4s
# * 2320   328              76    3837809.3294 3222326.22  16.0%  22.0    4s
# * 2360   390              62    3812556.8247 3222326.22  15.5%  21.7    4s
#   2438   453 3779118.24   53   61 3812556.82 3222326.22  15.5%  21.4    5s
# * 2632   544              92    3807425.6631 3222326.22  15.4%  20.5    5s
# * 2743   511             119    3792516.1713 3222326.22  15.0%  19.9    5s
# * 2744   511             119    3792330.7437 3222326.22  15.0%  19.9    5s
# * 2745   511             118    3792281.2443 3222326.22  15.0%  19.9    5s
# H 2908   555                    3780077.7002 3222326.22  14.8%  19.7    5s
# * 3229   708             100    3779811.5818 3222326.22  14.7%  19.5    5s
# * 3238   708              97    3779811.5812 3222326.22  14.7%  19.4    5s
# * 3274   678              97    3779797.1100 3222326.22  14.7%  19.4    5s
# H 4334   804                    3779009.1539 3379842.57  10.6%  23.1    7s
# H 5028  1063                    3778679.8254 3400143.41  10.0%  25.2    8s
# * 5179  1131              98    3776532.7515 3403531.04  9.88%  25.3    8s
# * 5184  1119             100    3773060.8239 3403531.04  9.79%  25.3    8s
#   7101  1921 3455186.60   33   70 3773060.82 3424882.97  9.23%  28.2   10s
# * 8733  2715              96    3771608.4596 3435881.41  8.90%  28.9   11s
# * 8737  2681              96    3767883.8243 3435881.41  8.81%  28.9   11s
# * 9804  2969              99    3759791.9936 3438043.70  8.56%  28.4   11s
# *10485  3038              91    3756932.4043 3440737.49  8.42%  28.8   12s
# *10487  3035              92    3756581.4203 3440737.49  8.41%  28.7   12s
# *10492  3034              93    3756286.1392 3440737.49  8.40%  28.7   12s
# *10495  3034              93    3756140.2655 3440737.49  8.40%  28.7   12s
# H11799  3376                    3755672.6656 3444782.25  8.28%  29.9   13s
# H12398  3663                    3752168.5134 3447194.65  8.13%  30.2   14s
# H12695  3612                    3746898.8468 3447194.65  8.00%  30.5   14s
#  13265  4012 3676599.21   40   63 3746898.85 3450137.21  7.92%  30.7   15s
# *13845  4292              97    3745343.2283 3450716.11  7.87%  31.2   15s
# *13847  4272              98    3742601.7984 3450716.11  7.80%  31.2   15s
# H17596  5321                    3741326.6067 3458902.16  7.55%  33.1   18s
#  19696  6164 infeasible   37      3741326.61 3463178.64  7.43%  34.5   20s
# *20566  6578             100    3741264.9939 3464357.17  7.40%  35.0   20s
# *20571  6527             103    3738717.8951 3464357.17  7.34%  35.0   20s
# *20572  6527             102    3738701.0512 3464357.17  7.34%  35.0   20s
#  27180  8538 3738271.79   44   13 3738701.05 3474384.50  7.07%  37.0   25s
# H33923 10015                    3738527.8680 3480535.90  6.90%  38.6   30s
# H35679 10607                    3738334.0031 3481713.86  6.86%  39.0   32s
# *36496 10852             104    3736438.2192 3482027.25  6.81%  39.0   32s
# H37093 11000                    3735520.7882 3482893.60  6.76%  39.1   33s
# H38809 11212                    3734882.5230 3483940.79  6.72%  39.3   34s
#  38820 11405 3714573.02   40   15 3734882.52 3484069.01  6.72%  39.3   35s
#  44362 12669     cutoff   36      3734882.52 3487000.70  6.64%  40.2   40s
#  50942 14368 3494171.26   38   62 3734882.52 3490604.81  6.54%  41.1   45s
# H57741 15470                    3734844.8739 3493507.05  6.46%  41.8   49s
#  58317 15659 3497070.60   30   68 3734844.87 3493538.46  6.46%  41.9   50s
#  65357 16904 3514862.50   36   66 3734844.87 3496933.03  6.37%  42.7   55s
#  73225 18204 3522119.82   33   65 3734844.87 3499561.35  6.30%  43.5   60s
#  81096 19383 3533549.89   40   17 3734844.87 3502076.74  6.23%  44.0   65s
#  88790 20588     cutoff   44      3734844.87 3504241.14  6.17%  44.7   70s
#  96535 21643 3522077.54   39   19 3734844.87 3506494.22  6.11%  45.2   75s
#  104632 22751     cutoff   43      3734844.87 3508435.34  6.06%  45.6   80s
# H106591 22604                    3730005.6237 3508757.02  5.93%  45.7   82s
# H108549 22840                    3729888.4688 3509226.42  5.92%  45.7   84s
#  108656 22946 3600444.55   35   64 3729888.47 3509296.95  5.91%  45.7   85s
#  115782 23919 infeasible   40      3729888.47 3510992.86  5.87%  46.1   90s
#  123300 24801 3544542.43   44   62 3729888.47 3512838.92  5.82%  46.4   95s
#  130831 25653 3575544.69   37   17 3729888.47 3514432.79  5.78%  46.7  100s
#  138042 26531 3576547.31   40   17 3729888.47 3516112.10  5.73%  46.9  105s
#  145466 27272     cutoff   32      3729888.47 3517534.43  5.69%  47.2  110s
#  152988 28135 3717755.45   39   60 3729888.47 3519069.48  5.65%  47.4  115s
#  157970 28633 3572814.72   42   62 3729888.47 3519989.21  5.63%  47.5  120s
#
# Cutting planes:
#   Gomory: 18
#   Cover: 10
#   Implied bound: 9
#   Projected implied bound: 5
#   MIR: 44
#   Flow cover: 35
#   RLT: 228
#   Relax-and-lift: 22
#
# Explored 159014 nodes (7568266 simplex iterations) in 120.01 seconds (128.12 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 3.72989e+06 3.73001e+06 3.73484e+06 ... 3.73872e+06
#
# Time limit reached
# Warning: max constraint violation (1.7514e-06) exceeds tolerance
# Best objective 3.729888468793e+06, best bound 3.520096080372e+06, gap 5.6246%
#
# User-callback calls 328428, time in user-callback 0.03 sec
# CSV file exported to: Results/Max_cost/profiles_demand_flex75_vre0.csv
# INSTALLED POWER RESULTS
# [807.5142891335029, 1676.3740302156345, 333.00004413925575, 0.0, 2378.9407372681153]
# CSV file exported to: Results/Max_cost/power_demand_flex75_vre0.csv
# demand_flex75_vre50
# Reading scenario data/demand_flex75_vre50.csv
# Loaded demand with size (8759, 1)
# Cost
# Demand
# (8759,)
# (8807,)
# Availability
# Try reverse
# (8808, 5)
# Number of technologies: 5
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-09-07
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 120
# Model: initialized!
#
# Demand constraint
# Renewable maximum installed capacity constraint
# Storage variable
# Availability & installed power constraint
# Availability & installed power constraint
# Curtailment definition
# Z_1 expression
# Min X_1, X_2 expression
#  Take the min of min(X_1, X_2) and X_3
#  Take the overall min
#  Take the min of min(X_1, X_2) and X_3
#  Take the overall min
# Initialize Objective
# Optimize model
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 120
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1522 rows, 985 columns and 4720 nonzeros
# Model fingerprint: 0x7b59b40b
# Model has 538 quadratic constraints
# Variable types: 740 continuous, 245 integer (245 binary)
# Coefficient statistics:
#   Matrix range     [9e-04, 1e+07]
#   QMatrix range    [1e+00, 2e+00]
#   QLMatrix range   [1e+00, 1e+07]
#   Objective range  [2e-03, 1e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+02, 1e+07]
#   QRHS range       [1e+07, 1e+07]
# Presolve added 4 rows and 64 columns
# Presolve time: 0.01s
# Presolved: 2489 rows, 1194 columns, 7207 nonzeros
# Presolved model has 239 bilinear constraint(s)
# Variable types: 951 continuous, 243 integer (243 binary)
#
# Root relaxation: objective 1.438463e+06, 661 iterations, 0.00 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1438463.14    0  139          - 1438463.14      -     -    0s
# H    0     0                    7.207628e+08 1438463.14   100%     -    0s
#      0     0 2043064.02    0  139 7.2076e+08 2043064.02   100%     -    0s
# H    0     0                    3.483911e+08 2043064.02  99.4%     -    0s
#      0     0 2043064.02    0  139 3.4839e+08 2043064.02  99.4%     -    0s
#      0     0 2043064.02    0  138 3.4839e+08 2043064.02  99.4%     -    0s
#      0     0 2043064.02    0  129 3.4839e+08 2043064.02  99.4%     -    0s
#      0     0 2248810.78    0  126 3.4839e+08 2248810.78  99.4%     -    0s
#      0     0 2248810.78    0  126 3.4839e+08 2248810.78  99.4%     -    0s
#      0     0 2248810.78    0  126 3.4839e+08 2248810.78  99.4%     -    0s
#      0     2 2248810.78    0  126 3.4839e+08 2248810.78  99.4%     -    0s
# H   52    64                    2.969043e+08 2248810.78  99.2%  33.3    0s
# H  151   171                    2.961577e+08 2248810.78  99.2%  14.2    0s
# *  487   509              50    5692799.3137 2248810.78  60.5%  13.1    0s
# *  551   459              55    5692593.3664 2248810.78  60.5%  14.4    0s
# H 1601   918                    5174789.9979 2976468.61  42.5%  17.2    4s
#   1606   921 5050483.84   55   35 5174790.00 3144441.69  39.2%  17.1    5s
# H 1606   875                    3931716.3621 3144441.69  20.0%  17.1    5s
# * 2106   985              56    3907423.4519 3269775.04  16.3%  20.7    6s
# * 2159   976              60    3859481.8188 3269775.04  15.3%  20.6    6s
# * 2161   935              61    3812010.5110 3269775.04  14.2%  20.6    6s
# * 2163   896              62    3809631.8199 3269775.04  14.2%  20.6    6s
# * 2336   875              92    3809337.9165 3270108.65  14.2%  20.2    6s
# * 2382   826              72    3766544.1881 3275022.29  13.0%  20.3    6s
# * 2799   757             109    3734627.7209 3305570.88  11.5%  20.0    7s
# H 3879   888                    3723101.2993 3360764.85  9.73%  20.9    8s
# H 3895   888                    3723101.2811 3360764.85  9.73%  21.0    8s
# * 4337  1149              47    3718972.9478 3381322.91  9.08%  21.6    8s
# * 4344  1149              51    3718838.7478 3381322.91  9.08%  21.6    8s
# * 4355  1149              54    3718797.4603 3381322.91  9.07%  21.5    8s
# * 4466  1192              53    3718797.4585 3381322.91  9.07%  21.5    8s
# * 5992  2226             115    3705575.4804 3395732.61  8.36%  19.6    9s
# * 5994  2213             116    3702492.5065 3395732.61  8.29%  19.6    9s
#   6048  2294 3435841.05   32   66 3702492.51 3395732.61  8.29%  19.6   10s
# * 6180  1842             102    3689836.0036 3395732.61  7.97%  19.5   10s
# * 8296  2532             134    3657763.0270 3407447.14  6.84%  18.8   11s
#  14282  4128 3421424.26   36   67 3657763.03 3420634.27  6.48%  21.8   15s
#  21371  5688     cutoff   42      3657763.03 3426108.68  6.33%  29.7   20s
# H21373  5396                    3657644.4990 3426108.68  6.33%  29.7   20s
# H23101  5860                    3657562.4585 3427582.09  6.29%  32.3   21s
#  27206  6822 3432415.11   35   66 3657562.46 3429732.53  6.23%  34.9   25s
#  34236  8280 3447932.46   39   70 3657562.46 3434104.03  6.11%  36.3   30s
#  45064  9988 infeasible   39      3657562.46 3438573.38  5.99%  34.4   35s
#  54706 11388 3567576.61   37   65 3657562.46 3441682.59  5.90%  33.9   40s
#  58274 11829 infeasible   59      3657562.46 3441682.59  5.90%  45.2   45s
#  58808 12005 infeasible   72      3657562.46 3441682.59  5.90%  66.6   50s
#  59295 12091 infeasible   64      3657562.46 3441682.59  5.90%  87.3   55s
#  59809 12287  postponed   70      3657562.46 3441682.59  5.90%   105   60s
#  60398 12440 3472144.54   97   94 3657562.46 3441682.59  5.90%   120   65s
#  60946 12622  postponed   71      3657562.46 3441682.59  5.90%   137   70s
#  61427 12806  postponed   65      3657562.46 3441682.59  5.90%   154   75s
#  61910 12972 infeasible   74      3657562.46 3441682.59  5.90%   168   80s
#  62477 13142  postponed   84      3657562.46 3441682.59  5.90%   183   85s
#  63159 13279  postponed   67      3657562.46 3441682.59  5.90%   200   91s
#  63739 13391 infeasible   84      3657562.46 3441682.59  5.90%   213   96s
#  64433 13559  postponed   84      3657562.46 3441682.59  5.90%   227  101s
#  65003 13741  postponed   72      3657562.46 3441682.59  5.90%   245  106s
#  65615 13876 infeasible   79      3657562.46 3441682.59  5.90%   255  112s
#  66294 14008 infeasible   80      3657562.46 3441682.59  5.90%   267  116s
#  66914 14133  postponed   75      3657562.46 3441682.59  5.90%   280  120s
#
# Cutting planes:
#   Gomory: 12
#   Cover: 3
#   Implied bound: 4
#   Projected implied bound: 7
#   Clique: 4
#   MIR: 86
#   Flow cover: 30
#   RLT: 206
#   Relax-and-lift: 16
#
# Explored 66982 nodes (18888879 simplex iterations) in 120.00 seconds (223.37 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 3.65756e+06 3.65764e+06 3.65776e+06 ... 3.71897e+06
#
# Time limit reached
# Warning: max constraint violation (1.6858e-06) exceeds tolerance
# Best objective 3.657562458495e+06, best bound 3.441682593792e+06, gap 5.9023%
#
# User-callback calls 142089, time in user-callback 0.02 sec
# CSV file exported to: Results/Max_cost/profiles_demand_flex75_vre50.csv
# INSTALLED POWER RESULTS
# [822.0523643594433, 1672.0724007517736, 312.6399821554625, 0.0, 2198.529768717251]
# CSV file exported to: Results/Max_cost/power_demand_flex75_vre50.csv
# demand_flex75_vre100
# Reading scenario data/demand_flex75_vre100.csv
# Loaded demand with size (8759, 1)
# Cost
# Demand
# (8759,)
# (8807,)
# Availability
# Try reverse
# (8808, 5)
# Number of technologies: 5
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-09-07
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 120
# Model: initialized!
#
# Demand constraint
# Renewable maximum installed capacity constraint
# Storage variable
# Availability & installed power constraint
# Availability & installed power constraint
# Curtailment definition
# Z_1 expression
# Min X_1, X_2 expression
#  Take the min of min(X_1, X_2) and X_3
#  Take the overall min
#  Take the min of min(X_1, X_2) and X_3
#  Take the overall min
# Initialize Objective
# Optimize model
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 120
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1522 rows, 985 columns and 4720 nonzeros
# Model fingerprint: 0x57a02e1b
# Model has 538 quadratic constraints
# Variable types: 740 continuous, 245 integer (245 binary)
# Coefficient statistics:
#   Matrix range     [9e-04, 1e+07]
#   QMatrix range    [1e+00, 2e+00]
#   QLMatrix range   [1e+00, 1e+07]
#   Objective range  [2e-03, 1e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+02, 1e+07]
#   QRHS range       [1e+07, 1e+07]
# Presolve added 4 rows and 64 columns
# Presolve time: 0.01s
# Presolved: 2489 rows, 1194 columns, 7207 nonzeros
# Presolved model has 239 bilinear constraint(s)
# Variable types: 951 continuous, 243 integer (243 binary)
#
# Root relaxation: objective 1.487175e+06, 663 iterations, 0.00 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1487175.47    0  139          - 1487175.47      -     -    0s
# H    0     0                    6.642092e+08 1487175.47   100%     -    0s
#      0     0 2074844.43    0  140 6.6421e+08 2074844.43   100%     -    0s
# H    0     0                    3.304635e+08 2074844.43  99.4%     -    0s
#      0     0 2191154.88    0  140 3.3046e+08 2191154.88  99.3%     -    0s
#      0     0 2191154.88    0  141 3.3046e+08 2191154.88  99.3%     -    0s
# H    0     0                    3.304635e+08 2372924.65  99.3%     -    0s
#      0     0 2372924.65    0  127 3.3046e+08 2372924.65  99.3%     -    0s
#      0     0 2372924.65    0  127 3.3046e+08 2372924.65  99.3%     -    0s
#      0     0 2372924.65    0  124 3.3046e+08 2372924.65  99.3%     -    0s
#      0     0 2372924.65    0  124 3.3046e+08 2372924.65  99.3%     -    0s
#      0     0 2372924.65    0  125 3.3046e+08 2372924.65  99.3%     -    0s
#      0     0 2372924.65    0  121 3.3046e+08 2372924.65  99.3%     -    0s
# H    0     0                    2.950359e+08 2372924.65  99.2%     -    0s
#      0     0 2372924.65    0  120 2.9504e+08 2372924.65  99.2%     -    0s
#      0     0 2372924.65    0  120 2.9504e+08 2372924.65  99.2%     -    0s
#      0     2 2372924.65    0  120 2.9504e+08 2372924.65  99.2%     -    0s
# H    5     8                    2.617730e+08 2372924.65  99.1%  73.8    0s
# *  835   801             120    1.186483e+08 2372924.65  98.0%  15.1    0s
# *  910   852             123    1.163249e+08 2372924.65  98.0%  16.1    0s
# H  994   879                    7.529943e+07 2372924.65  96.8%  17.0    0s
# H 1006   893                    6.014277e+07 2372924.65  96.1%  17.2    0s
# H 1008   881                    4.491556e+07 2372924.65  94.7%  17.4    0s
# * 1095   570             114    4527117.4861 2372924.65  47.6%  17.7    1s
# * 1247   511             115    4522772.5749 2372924.65  47.5%  17.2    1s
# * 1249   511             116    4514505.5834 2372924.65  47.4%  17.2    1s
# * 1257   511             120    4514468.8362 2372924.65  47.4%  17.1    1s
# * 1401   599             132    4514468.6869 2372924.65  47.4%  16.8    1s
# H 1502   551                    4267050.3776 2911216.00  31.8%  16.4    3s
# H 1510   529                    3673145.0523 3095189.44  15.7%  16.3    4s
# * 1697   584              35    3668390.2403 3165208.22  13.7%  17.9    4s
# * 1722   562              38    3665327.1158 3165208.22  13.6%  18.1    4s
# * 1750   561              41    3647311.2307 3165208.22  13.2%  18.4    4s
#   1762   588 3508247.28   29   73 3647311.23 3165208.22  13.2%  18.4    5s
# * 1819   559              52    3632771.4501 3165208.22  12.9%  18.4    5s
# * 1851   563              53    3630906.5929 3165208.22  12.8%  18.4    5s
# * 1905   554              66    3630473.1829 3165208.22  12.8%  18.2    5s
# * 2003   550              86    3630459.4706 3165208.22  12.8%  18.0    5s
# * 2301   685              91    3630459.4679 3196648.73  11.9%  16.9    5s
# * 2390   631              96    3629923.5459 3196648.73  11.9%  16.6    5s
# * 2440   502              95    3612547.4470 3196648.73  11.5%  16.5    5s
# * 2447   495             100    3611524.4824 3196648.73  11.5%  16.5    5s
# * 2448   493              99    3610256.9337 3196648.73  11.5%  16.5    5s
# * 2449   492              98    3609145.3429 3196648.73  11.4%  16.5    5s
# * 2450   487              97    3608075.1059 3196648.73  11.4%  16.5    5s
# * 2756   734             100    3607346.1688 3224091.69  10.6%  15.9    5s
# * 2759   726             102    3606172.3317 3224091.69  10.6%  15.9    5s
# * 3047   892              98    3606083.5166 3229069.79  10.5%  15.3    6s
# * 3232   836              88    3605836.1655 3248972.30  9.90%  15.3    6s
# H 4305  1137                    3605819.0555 3274162.29  9.20%  17.6    7s
# H 4306  1114                    3605740.3639 3274162.29  9.20%  17.6    7s
#   7542  2485 3410532.55   27   68 3605740.36 3321898.83  7.87%  20.3   10s
# *14677  5020              95    3605501.0864 3350130.50  7.08%  22.4   13s
# *14792  4946              95    3603857.6960 3350189.05  7.04%  22.3   13s
#  14918  5055 3557701.32   35   19 3603857.70 3350636.04  7.03%  22.3   15s
# H15083  4855                    3590365.3971 3350956.60  6.67%  22.3   15s
#  24545  7824     cutoff   38      3590365.40 3364970.45  6.28%  22.9   20s
# H29131  8778                    3590024.6469 3368290.16  6.18%  23.0   22s
#  32287  9769 3423592.58   31   65 3590024.65 3370917.32  6.10%  23.2   25s
#  42717 12155 3589270.03   31   62 3590024.65 3376785.64  5.94%  23.5   30s
#  53209 14281 3506245.18   33   19 3590024.65 3381220.26  5.82%  23.6   35s
#  64229 16191 3537524.38   32   62 3590024.65 3385625.63  5.69%  23.8   40s
#  73918 17817     cutoff   37      3590024.65 3388671.59  5.61%  24.0   45s
#  84237 19395 3574843.71   38   62 3590024.65 3391701.12  5.52%  24.1   50s
#  94096 20667     cutoff   38      3590024.65 3394255.54  5.45%  24.3   55s
#  104052 21867     cutoff   34      3590024.65 3396647.57  5.39%  24.4   60s
#  114188 22954 3533945.43   33   71 3590024.65 3399035.15  5.32%  24.4   65s
#  124443 23988     cutoff   36      3590024.65 3401371.09  5.25%  24.5   70s
#  132179 24730     cutoff   33      3590024.65 3403226.04  5.20%  24.6   75s
#  142799 25720     cutoff   35      3590024.65 3405583.67  5.14%  24.6   80s
#  152267 26467 3579198.99   32   68 3590024.65 3407610.38  5.08%  24.7   85s
#  163832 27439     cutoff   30      3590024.65 3409939.81  5.02%  24.8   90s
#  171034 27931     cutoff   37      3590024.65 3411305.70  4.98%  24.8   95s
#  182908 28730     cutoff   36      3590024.65 3413720.55  4.91%  24.9  100s
#  191663 29228     cutoff   30      3590024.65 3415411.63  4.86%  24.9  105s
#  202207 29720     cutoff   34      3590024.65 3417495.76  4.81%  24.9  110s
#  213131 30209 3501561.69   31   19 3590024.65 3419495.87  4.75%  25.0  115s
#  222849 30493 3435756.18   32   61 3590024.65 3421539.08  4.69%  25.0  120s
#
# Cutting planes:
#   Gomory: 5
#   Cover: 11
#   Implied bound: 7
#   Projected implied bound: 11
#   Clique: 11
#   MIR: 53
#   Flow cover: 41
#   Inf proof: 1
#   RLT: 269
#   Relax-and-lift: 26
#   BQP: 5
#
# Explored 223480 nodes (5589069 simplex iterations) in 120.01 seconds (122.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 3.59002e+06 3.59037e+06 3.60386e+06 ... 3.60735e+06
#
# Time limit reached
# Warning: max constraint violation (1.6638e-06) exceeds tolerance
# Best objective 3.590024646914e+06, best bound 3.421626906804e+06, gap 4.6907%
#
# User-callback calls 455299, time in user-callback 0.13 sec
# CSV file exported to: Results/Max_cost/profiles_demand_flex75_vre100.csv
# INSTALLED POWER RESULTS
# [941.2122357386428, 1607.7495072163276, 290.49268891766735, 0.0, 2071.1200179152597]
# CSV file exported to: Results/Max_cost/power_demand_flex75_vre100.csv
