# %%
# Introduction of the packages
using Pkg
Pkg.add("CSV")
Pkg.add("DataFrames")
Pkg.add("JuMP")
Pkg.add("Gurobi")
#Pkg.add("NLopt")

using CSV, DataFrames, JuMP, Gurobi
# Out:
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.9/Project.toml`
#   No Changes to `~/.julia/environments/v1.9/Manifest.toml`
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.9/Project.toml`
#   No Changes to `~/.julia/environments/v1.9/Manifest.toml`
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.9/Project.toml`
#   No Changes to `~/.julia/environments/v1.9/Manifest.toml`
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.9/Project.toml`
#   No Changes to `~/.julia/environments/v1.9/Manifest.toml`

# %%
# Read the CSVs
SCALE_MWH = 1000
SCALE_DOLLAR = 1000

# CHANGE THIS FOR HIGH COST SCENARIO
scenario = "max" # "max" or "mean"

fixed_cost = CSV.read("data/fixed_cost_"*scenario*".csv",DataFrame) ./ SCALE_DOLLAR
variable_cost = CSV.read("data/variable_cost_"*scenario*".csv",DataFrame) ./ SCALE_DOLLAR
co2_intensity = CSV.read("data/co2_intensity.csv",DataFrame)
curtailment_costs = [0, 2, 0, 0, 0, 0] ./ SCALE_DOLLAR
ramp_limits = CSV.read("data/ramp_limits.csv", DataFrame)

# AVAILABILITY
P_max_s = 95897829.43 / SCALE_MWH
P_max_w = 11158008 / SCALE_MWH;

Availability_matrix = CSV.read("data/Availability.csv", DataFrame);
println(size(Availability_matrix))

############### Constants of the model 

eta = 0.8; # Efficiency of the battery
CO2_price = 100; # price of the CO2 per ton
H = 2;

################ Time to consider

# T = 50
# T_start = 987
# println("Timespan: ", T)
# println("Starting at hour: ", T_start)
# time_ls_opt = 1:T
# time_ls_clipped = 2:T-1 # For rate of change calculations

T = 50
T_start = 4960
time_ls_opt = T_start-24:T_start+24


hrs = 4000
hre = 5000
sel_hrs = hrs:hre
println(sel_hrs)
techs = 5
n_eu = 4
# pad year by 1 day
add_h = 24


println("Timespan: ", T)
#time_ls = 1+add_h:T-add_h
time_ls = T_start-24+1:T_start+24-add_h
vre_ls = 1:2
fossil_ls = 3:4
batt_ind = 5;
# Out:
# (8760, 5)
# 4000:5000
# Timespan: 50

# %%
######## Need to create a loop on that ========

name_demand_flex_input = [
    "demand_flex0_vre0", 
    "demand_flex50_vre0", 
    "demand_flex50_vre50", 
    "demand_flex50_vre100", 
    "demand_flex100_vre0", 
    "demand_flex100_vre50",
    "demand_flex100_vre100"
    ]
println("Starting Loop")
for name in name_demand_flex_input
    println(name)
    file_to_read = "data/"*name*".csv"
    println("Reading scenario $file_to_read")

    demand = Matrix(CSV.read(file_to_read, DataFrame)) ./ SCALE_MWH;
    println("Loaded demand with size ", size(demand))

    #######################################

    println("Cost")
    C_FC = fixed_cost[1:techs,1]
    C_FOM = fixed_cost[1:techs,2]
    C_VOM = variable_cost[1:techs,1]
    E_CO2 = co2_intensity[1:techs,1]
    C_ramp = variable_cost[1:techs,2]
    C_start = variable_cost[1:techs,3]
    C_curt = curtailment_costs[1:techs]

    println("Demand")
    D_b = demand[:] # Baseline demand with no flex
    println(size(D_b))
    D_b = vcat(reverse(reverse(demand)[1:add_h]), D_b, D_b[1:24])
    println(size(D_b))
    total_demand = D_b
    X_D = D_b

    A_r = ramp_limits[1:techs, 1]
    println("Availability")
    A_s = Availability_matrix[:,1:techs]
    println("Try reverse")
    A_s = vcat(reverse(reverse(Availability_matrix)[1:add_h, 1:techs]), A_s, A_s[1:24, 1:techs])
    println(size(A_s))
    # over time, opt each year with worst day for availability and highest demand?

    n = size(C_FC, 1) # number of technologies
    println("Number of technologies: ", n)

    ###### MODEL ######

    model = Model(Gurobi.Optimizer) # TODO: options? other optimizers?
    set_optimizer_attribute(model, "NonConvex", 2)
    #set_optimizer_attribute(model, "IterationLimit", 10000000)
    set_optimizer_attribute(model, "TimeLimit", 120)
    println("Model: initialized!\n")

    ###### MAIN VARIABLES ######
    # Non-negativity constraints
    # The installed power capacity of the mix
    @variable(model, P[1:n] >= 0)

    # The hourly power generation of each technology
    @variable(model, X_gen[time_ls_opt, 1:n] >= 0); # hourly production/use for each technology

    # Curtailment (only renewables?)
    @variable(model, X_cur[time_ls_opt, 1:n] >= 0); # hourly production/use for each technology

    ###### CONSTRAINTS ######

    # Demand constraint - meet demand per hour
    println("Demand constraint")
    @constraint(model, Con_dh[t = time_ls_opt], sum(X_gen[t, i] for i in 1:n) >= X_D[t]); # TODO: add curtailment
    # Meet total demand
    # @constraint(model, Con_d, sum(X_gen[t, i] for i in 1:n for t in time_ls_opt) >= sum(total_demand));

    # Installed capacity renewables < max capacity
    println("Renewable maximum installed capacity constraint")
    @constraint(model, Con_sgen, P[1] <= P_max_s);
    @constraint(model, Con_wgen, P[2] <= P_max_w);

    # println("Renewable minimum installed capacity constraint")
    #@constraint(model, Con_solar_lb, P[1] >= 50);
    #@constraint(model, Con_wind_lb, P[2] >= 600);

    # Storage variable
    println("Storage variable")
    @variable(model, 0<= X_soc[time_ls_opt] <=1)
    @variable(model, X_ch[time_ls_opt]>=0)

    # Cannot produce more than the installed power
    # println("Installed power constraint")
    # @constraint(model, Con_p[i = 1:n, t = time_ls_opt], X_gen[t, i] <= P[i])

    # For each tech, at each hour, usage cannot exceed available capacity
    println("Availability & installed power constraint")
    @constraint(model, [i = 1:n, t = time_ls_opt], X_gen[t, i] <= P[i]*A_s[t, i])
    # Renewables produce maximum possible capacity
    @constraint(model, [i = vre_ls, t = time_ls_opt], X_gen[t, i] >= 0.7*P[i]*A_s[t, i]) 


    println("Availability & installed power constraint")
    @constraint(model, [i = 1:n, t = time_ls_opt], X_gen[t, i] <= P[i]*A_s[t, i])

    println("Curtailment definition")
    @constraint(model, [t = time_ls_opt], sum(X_cur[t, i] for i in 1:n) == sum(X_gen[t, i] for i in 1:n) - X_D[t]) 
    @constraint(model, [i = 1:n, t = time_ls_opt], X_cur[t, i] <= X_gen[t, i])

    # Cannot produce less than the minimum stable generation: X_gen must be zero or min to max
    # min_usage = [0, 0.1, 0, 0] #TODO - cant be more than ramp
    # @constraint(model, [i = 1:n, t = time_ls_opt], X_gen[t, i] >= P[i]*min_usage[i])

    # For each tech, at each hour, change in production cannot exceed ramp rate (TODO might need to convert this to time)
    # println("Ramp constraint")
    # Auxiliary variables to linearize the rate of change constraint
    # @constraint(model, Con_rdwn[i = 1:n, t = time_ls_clipped], (X_gen[t+1, i] - X_gen[t, i]) >= -A_r[i]*X_gen[t, i]) 
    # @constraint(model, Con_rup[i = 1:n, t = time_ls_clipped], (X_gen[t+1, i] - X_gen[t, i]) <= A_r[i]*X_gen[t, i]);

    M = 10000000
    
    # println("Cold Start")
    # @variable(model, Cold_start[time_ls_opt, i = 1:4], Bin)
    # @constraint(model, [i = 1:4, t in time_ls_clipped], (X_gen[t, i] - X_gen[t-1, i])*X_gen[t, i] <= M*Cold_start[t, i])
    # @constraint(model, [i = 1:4, t in time_ls_clipped], -(X_gen[t, i] - X_gen[t-1, i])*X_gen[t, i] <= M*Cold_start[t, i])

    # Storage model

    # Need to put this conditions above
    @variable(model, Z_X_gen_greater_X_D[time_ls_opt], Bin)

    @constraint(model, Z_X_gen_greater_X_D_1[t in time_ls_opt], sum(X_gen[t,i] for i in 1:4) - X_D[t] <= M*Z_X_gen_greater_X_D[t])
    @constraint(model, Z_X_gen_greater_X_D_2[t in time_ls_opt], -sum(X_gen[t,i] for i in 1:4) + X_D[t] <= M*(1-Z_X_gen_greater_X_D[t]))


    # X_1, X_2, X_3 = [eta*(sum(X_gen[t,i] for i in Power_generation_ls)- X_D[t]) , eta*P3], (1- X_soc[t])*P[5]* H]
    @variable(model, z1[t in time_ls_opt], Bin)
    @variable(model, z2[t in time_ls_opt], Bin)

    # z_1 equal 1 if eta*(x_g_t -x_d) is is greatter than eta*E_max*delta t
    println("Z_1 expression")
    @constraint(model, z_1_1[t in time_ls_opt], eta*P[5] - eta*(sum(X_gen[t,i] for i in 1:4)- X_D[t])   <=  M*z1[t])
    @constraint(model, z_1_2[t in time_ls_opt], -eta*P[5] + eta*(sum(X_gen[t,i] for i in 1:4)- X_D[t]) <= M*(1-z1[t]))


    #Minimum between X_1 and X_2
    @variable(model, min_X_1_X_2[time_ls_opt])

    println("Min X_1, X_2 expression")
    @constraint(model, X_1_X_2_lower_1[t in time_ls_opt], min_X_1_X_2[t] <= eta*(sum(X_gen[t,i] for i in 1:4)- X_D[t]))
    @constraint(model, X_1_X_2_lower_2[t in time_ls_opt], min_X_1_X_2[t] <= eta*P[5])
    @constraint(model, X_1_X_2_higher_1[t in time_ls_opt], min_X_1_X_2[t] >= eta*(sum(X_gen[t,i] for i in 1:4)- X_D[t]) - M*(1-z1[t]))
    @constraint(model, X_1_X_2_higher_2[t in time_ls_opt], min_X_1_X_2[t] >= eta*P[5] - M*z1[t])


    # z_2 equal 1 if min(X_1, X_2) is is greater than (1- x_soc[t])*h*E_max
    println(" Take the min of min(X_1, X_2) and X_3")
    @constraint(model, z_2_1[t in time_ls_opt], (1- X_soc[t])* P[5] * H - min_X_1_X_2[t] <=  M*z2[t])
    @constraint(model, z_2_2[t in time_ls_opt], - (1- X_soc[t]) * P[5] * H + min_X_1_X_2[t] <= M*(1-z2[t]))


    # Constraint for the variable X_ch
    println(" Take the overall min")
    @variable(model, min_X_1_X_2_X_3[time_ls_opt])

    @constraint(model, X_1_X_2_X_3_lower_1[t in time_ls_opt], min_X_1_X_2_X_3[t] <= min_X_1_X_2[t])
    @constraint(model, X_1_X_2_X_3_lower_2[t in time_ls_opt], min_X_1_X_2_X_3[t] <= (1- X_soc[t])*P[3]* H)
    @constraint(model, X_1_X_2_X_3_higher_1[t in time_ls_opt], min_X_1_X_2_X_3[t] >= min_X_1_X_2[t] - M*(1-z2[t]))
    @constraint(model, X_1_X_2_X_3_higher_2[t in time_ls_opt], min_X_1_X_2_X_3[t] >= (1- X_soc[t])*P[3]* H - M*z2[t]);

    #Expression of X_ch
    @constraint(model, X_ch_expression[t in time_ls_opt], X_ch[t]  == Z_X_gen_greater_X_D[t]*min_X_1_X_2_X_3[t]);
    @variable(model, y2[time_ls_opt], Bin)

    # z_2 equal 1 if min(X_1, X_2) is is greater than (1- x_soc[t])*h*E_max
    println(" Take the min of min(X_1, X_2) and X_3")
    @constraint(model, y_2_1[t in time_ls_opt], X_soc[t]* P[5] * H - P[5] <=  M*y2[t])
    @constraint(model, y_2_2[t in time_ls_opt], - X_soc[t] * P[5] * H + P[5] <= M*(1-y2[t]))

    # Constraint for the variable X_ch
    println(" Take the overall min")
    @variable(model, min_extra_prod_P5_soc[time_ls_opt])

    @constraint(model, min_extra_prod_P5_soc_lower_1[t in time_ls_opt], min_extra_prod_P5_soc[t] <= P[5])
    @constraint(model, min_extra_prod_P5_soc_lower_2[t in time_ls_opt], min_extra_prod_P5_soc[t] <= X_soc[t]*P[5]* H)
    @constraint(model, min_extra_prod_P5_soc_higher_1[t in time_ls_opt], min_extra_prod_P5_soc[t] >= P[5] - M*(1-y2[t]))
    @constraint(model, min_extra_prod_P5_soc_higher_2[t in time_ls_opt], min_extra_prod_P5_soc[t] >= X_soc[t]*P[5]* H - M*y2[t]);

    @variable(model, batt_dispatch[time_ls_opt], Bin)

    #Expression of X_dch
    @constraint(model, X_dch_expression[t in time_ls_opt], X_gen[t,5]  <= batt_dispatch[t]*min_extra_prod_P5_soc[t]);


    # First hour need to be equal to one
    # Start with a charged battery
    @constraint(model, SOC_t_1, X_soc[time_ls_opt[1]] == 0)

    #
    @constraint(model, SOC_t[t in time_ls_opt[2]:time_ls_opt[end]], (X_soc[t]-X_soc[t-1])*H*P[5] == (X_ch[t-1]- X_gen[t-1,5]));

    # MODEL OBJECTIVE FUNCTION
    #TODO RAMP AND STARTUP COSTS

    println("Initialize Objective")

    @objective(model, Min, 
        (
            sum((C_FC[i] + C_FOM[i])*P[i] for i in 1:n) + # FIXED COSTS
            sum(sum((C_VOM[i] + CO2_price* E_CO2[i])* X_gen[t, i] for i in 1:n) for t in time_ls_opt) + # VARIABLE COSTS
            sum(sum(C_curt[i] * X_cur[t, i] for i in 1:n) for t in time_ls) # CURTAILMENT COSTS
    ));

    #Optimize
    println("Optimize model")
    optimize!(model)

    # Save the results for the generation
    # Assuming your matrix is named `my_matrix`
    my_matrix = [value.(X_gen) value.(X_soc) X_D[time_ls_opt]]  # Replace this with your actual matrix
    # Column names

    column_names = ["Solar", "Wind", "CCGT", "Coal", "Battery", "State_of_Charge", "Demand"]

    # Create a DataFrame with vectors for each column
    df = DataFrame([Symbol(name) => my_matrix[:, i] for (i, name) in enumerate(column_names)])

    # Specify the file path for your CSV file
    csv_file_path = "Results/Max_cost/profiles_" * name * ".csv"

    # Export the DataFrame to CSV
    CSV.write(csv_file_path, df)

    println("CSV file exported to: $csv_file_path")

    # Save the results for the power installed power
    # Assuming your matrix is named `my_matrix`
    Power = value.(P)   # Replace this with your actual matrix
    # Column names
    println("INSTALLED POWER RESULTS")
    println(Power)
    column_names_power = "Installed Power"

    # Create a DataFrame with vectors for each column
    df_Power = DataFrame(Symbol(column_names_power) => Power)

    # Specify the file path for your CSV file
    csv_file_path_power = "Results/Max_cost/power_" * name * ".csv"

    # Export the DataFrame to CSV
    CSV.write(csv_file_path_power, df_Power)

    println("CSV file exported to: $csv_file_path_power")
end
# Out:
# Starting Loop
# demand_flex0_vre0
# Reading scenario data/demand_flex0_vre0.csv
# Loaded demand with size (8759, 1)
# Cost
# Demand
# (8759,)
# (8807,)
# Availability
# Try reverse
# (8808, 5)
# Number of technologies: 5
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-09-07
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 120
# Model: initialized!
#
# Demand constraint
# Renewable maximum installed capacity constraint
# Storage variable
# Availability & installed power constraint
# Availability & installed power constraint
# Curtailment definition
# Z_1 expression
# Min X_1, X_2 expression
#  Take the min of min(X_1, X_2) and X_3
#  Take the overall min
#  Take the min of min(X_1, X_2) and X_3
#  Take the overall min
# Initialize Objective
# Optimize model
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 120
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1522 rows, 985 columns and 4720 nonzeros
# Model fingerprint: 0x0689849b
# Model has 538 quadratic constraints
# Variable types: 740 continuous, 245 integer (245 binary)
# Coefficient statistics:
#   Matrix range     [9e-04, 1e+07]
#   QMatrix range    [1e+00, 2e+00]
#   QLMatrix range   [1e+00, 1e+07]
#   Objective range  [2e-03, 1e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [4e+02, 1e+07]
#   QRHS range       [1e+07, 1e+07]
# Presolve added 4 rows and 64 columns
# Presolve time: 0.01s
# Presolved: 2489 rows, 1194 columns, 7207 nonzeros
# Presolved model has 239 bilinear constraint(s)
# Variable types: 951 continuous, 243 integer (243 binary)
#
# Root relaxation: objective 1.689844e+06, 669 iterations, 0.00 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1689843.52    0  130          - 1689843.52      -     -    0s
#      0     0 1879165.09    0  131          - 1879165.09      -     -    0s
#      0     0 1973050.69    0  131          - 1973050.69      -     -    0s
#      0     0 2059336.53    0  128          - 2059336.53      -     -    0s
#      0     2 2059336.53    0  128          - 2059336.53      -     -    0s
# H  846   867                    5.536010e+08 2059336.53   100%  17.3    0s
# H  852   862                    2.162528e+08 2059336.53  99.0%  17.5    0s
# H  875   864                    1.082283e+08 2059336.53  98.1%  18.4    0s
# * 1165   919             111    1.632473e+07 2059336.53  87.4%  16.2    0s
# H 2118  1522                    1.632473e+07 3372371.42  79.3%  19.1    4s
# H 2218  1512                    1.072214e+07 3372371.42  68.5%  19.2    4s
# * 2620  1573              84    1.072214e+07 3372371.42  68.5%  19.6    4s
# * 2623  1506              84    1.072214e+07 3372371.42  68.5%  19.6    4s
# * 2626  1443              83    1.072214e+07 3372371.42  68.5%  19.6    4s
# * 2631  1362             101    6621176.2464 3372371.42  49.1%  19.6    4s
#   2807  1330 4263741.24   80   70 6621176.25 3372371.42  49.1%  19.8    5s
# * 3358  1133             124    4149174.2470 3372371.42  18.7%  18.4    5s
# * 3451   964              70    4118822.0452 3408794.01  17.2%  18.3    5s
# * 3452   913              70    4117691.6554 3408794.01  17.2%  18.3    5s
# * 3662   838             133    4023164.3345 3408794.01  15.3%  18.3    5s
# * 3723   723             138    4016010.2595 3408794.01  15.1%  18.3    5s
# * 3986   636              71    3990546.2255 3408794.01  14.6%  18.4    5s
# * 3987   593              71    3977502.8772 3408794.01  14.3%  18.4    5s
# * 4517   480              50    3974337.1304 3512605.54  11.6%  19.6    5s
# * 4531   475              63    3970516.3805 3512605.54  11.5%  19.6    5s
# * 4534   473              65    3969834.6694 3512605.54  11.5%  19.5    5s
# * 4539   473              69    3969763.0147 3512605.54  11.5%  19.5    5s
# * 4627   512              77    3969755.6886 3512605.54  11.5%  19.7    6s
# * 5170   700              98    3953706.2375 3538929.03  10.5%  20.3    6s
# * 5797   841              98    3945704.1208 3573578.71  9.43%  21.2    6s
# H 9818  1679                    3930417.9739 3615897.50  8.00%  25.0    8s
# *10642  1929             101    3930016.6201 3620547.37  7.87%  24.4    9s
#  11847  2118 3742546.24   42   67 3930016.62 3630536.15  7.62%  24.7   10s
# H17666  2093                    3929446.3607 3678127.70  6.40%  25.3   14s
# H17670  1978                    3922815.7446 3678127.70  6.24%  25.3   14s
#  18335  1905 3731748.30   45   63 3922815.74 3688797.77  5.97%  25.4   15s
# H19073  1891                    3921771.4505 3698092.02  5.70%  25.5   15s
# H19075  1891                    3921575.2465 3698092.02  5.70%  25.5   15s
#  27437  1928 3863826.33   49   19 3921575.25 3793161.79  3.27%  24.8   20s
# *33110  1748             116    3921549.5514 3837745.92  2.14%  23.9   23s
# *33114  1747             117    3921462.8755 3837745.92  2.13%  23.9   23s
#  38065  1629     cutoff   39      3921462.88 3868357.40  1.35%  22.7   25s
# *40315  1489             102    3921060.9888 3880973.57  1.02%  22.1   26s
# *49150   898             106    3920964.3692 3911882.75  0.23%  19.6   29s
#  51147  1245     cutoff   58      3920964.37 3914933.47  0.15%  18.9   30s
# *55530  2036             104    3920939.7066 3918075.34  0.07%  17.5   31s
# H58823  2566                    3920904.8119 3918075.34  0.07%  16.6   32s
#  67858  3398     cutoff   61      3920904.81 3920096.23  0.02%  14.4   35s
#
# Cutting planes:
#   Gomory: 19
#   Cover: 3
#   Implied bound: 8
#   Projected implied bound: 7
#   Clique: 3
#   MIR: 72
#   Flow cover: 130
#   RLT: 234
#   Relax-and-lift: 6
#   PSD: 2
#
# Explored 80799 nodes (982334 simplex iterations) in 39.00 seconds (29.55 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 3.9209e+06 3.92094e+06 3.92096e+06 ... 3.92945e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.920904811892e+06, best bound 3.920534523083e+06, gap 0.0094%
#
# User-callback calls 165334, time in user-callback 0.02 sec
# CSV file exported to: Results/Max_cost/profiles_demand_flex0_vre0.csv
# INSTALLED POWER RESULTS
# [1268.2621840629638, 1488.3209811061258, 387.1954663348789, 0.0, 2621.377514891572]
# CSV file exported to: Results/Max_cost/power_demand_flex0_vre0.csv
# demand_flex50_vre0
# Reading scenario data/demand_flex50_vre0.csv
# Loaded demand with size (8759, 1)
# Cost
# Demand
# (8759,)
# (8807,)
# Availability
# Try reverse
# (8808, 5)
# Number of technologies: 5
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-09-07
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 120
# Model: initialized!
#
# Demand constraint
# Renewable maximum installed capacity constraint
# Storage variable
# Availability & installed power constraint
# Availability & installed power constraint
# Curtailment definition
# Z_1 expression
# Min X_1, X_2 expression
#  Take the min of min(X_1, X_2) and X_3
#  Take the overall min
#  Take the min of min(X_1, X_2) and X_3
#  Take the overall min
# Initialize Objective
# Optimize model
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 120
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1522 rows, 985 columns and 4720 nonzeros
# Model fingerprint: 0x508173d3
# Model has 538 quadratic constraints
# Variable types: 740 continuous, 245 integer (245 binary)
# Coefficient statistics:
#   Matrix range     [9e-04, 1e+07]
#   QMatrix range    [1e+00, 2e+00]
#   QLMatrix range   [1e+00, 1e+07]
#   Objective range  [2e-03, 1e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+02, 1e+07]
#   QRHS range       [1e+07, 1e+07]
# Presolve added 4 rows and 64 columns
# Presolve time: 0.02s
# Presolved: 2489 rows, 1194 columns, 7207 nonzeros
# Presolved model has 239 bilinear constraint(s)
# Variable types: 951 continuous, 243 integer (243 binary)
#
# Root relaxation: objective 1.488005e+06, 682 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1488004.69    0  134          - 1488004.69      -     -    0s
#      0     0 1703348.83    0  137          - 1703348.83      -     -    0s
#      0     0 1907714.03    0  135          - 1907714.03      -     -    0s
# H    0     0                    9.445715e+08 1907714.03   100%     -    0s
# H    0     0                    4.442827e+08 1907714.03   100%     -    0s
# H    0     2                    4.442720e+08 1907714.03   100%     -    0s
#      0     2 1907714.03    0  131 4.4427e+08 1907714.03   100%     -    0s
# H   32    40                    4.440429e+08 1907714.03   100%  83.3    0s
# H  375   377                    4.308249e+08 2242687.39  99.5%  14.3    0s
# * 1107  1059             118    4.308249e+08 2242687.39  99.5%  17.4    0s
# * 1110  1059             118    4.308249e+08 2242687.39  99.5%  17.4    0s
# * 1149  1086             107    4.151030e+08 2242687.39  99.5%  17.8    0s
# * 1153  1086             109    4.146410e+08 2242687.39  99.5%  17.8    0s
# * 1168   967             101    2.046231e+08 2242687.39  98.9%  17.8    0s
# H 2059  1540                    2.046231e+08 3075689.43  98.5%  15.3    2s
# H 2065  1467                    5.500597e+07 3215752.61  94.2%  15.2    2s
# H 2065  1393                    3.123936e+07 3215752.61  89.7%  15.2    2s
# H 2065  1324                    3.123936e+07 3215752.61  89.7%  15.2    2s
# H 2088  1269                    5479816.5784 3215752.61  41.3%  17.1    3s
# * 3119  1421              85    5441914.2716 3236959.57  40.5%  17.4    3s
# * 3121  1361              86    5238245.8963 3236959.57  38.2%  17.4    3s
# * 3123  1303              87    5196404.3786 3236959.57  37.7%  17.3    3s
# * 3127  1248              90    5187495.0216 3236959.57  37.6%  17.3    3s
# * 3129  1196              91    5185728.5330 3236959.57  37.6%  17.3    3s
# * 3216   970              92    5184730.8224 3236959.57  37.6%  16.9    3s
# H 3217   924                    5183539.6846 3236959.57  37.6%  16.9    3s
# * 3260   890              96    5183398.3398 3236959.57  37.6%  16.9    3s
# * 3262   848              97    5183382.5578 3236959.57  37.6%  16.9    3s
# * 3264   807              98    5183372.0086 3236959.57  37.6%  16.8    3s
# * 3360   792             146    5183371.5315 3236959.57  37.6%  16.9    3s
# * 3361   756             146    5183371.5291 3236959.57  37.6%  16.9    3s
# * 3362   721             145    5183371.5263 3236959.57  37.6%  16.9    3s
# * 3363   689             144    5183371.5233 3236959.57  37.6%  16.9    3s
# * 3364   658             143    5183371.5201 3236959.57  37.6%  16.9    3s
# * 3732   529              94    5095281.7351 3278398.89  35.7%  17.5    3s
# * 3736   528              97    5093720.3952 3278398.89  35.6%  17.5    3s
# * 3740   528              99    5093648.2165 3278398.89  35.6%  17.5    3s
# * 3773   528              71    5085120.7367 3278398.89  35.5%  17.6    3s
# * 3774   514              71    4979644.1459 3278398.89  34.2%  17.6    3s
# * 3778   511              72    4920502.5051 3278398.89  33.4%  17.6    3s
# * 3779   492              72    4860921.8263 3278398.89  32.6%  17.6    3s
# * 3781   486              72    4789969.0279 3278398.89  31.6%  17.6    3s
# * 3783   486              73    4735160.4925 3278398.89  30.8%  17.6    3s
# * 3838   474              74    4712330.2779 3278398.89  30.4%  17.6    4s
# * 3839   474              74    4679216.2394 3278398.89  29.9%  17.6    4s
# * 3949   554              67    4537808.7610 3278398.89  27.8%  17.7    4s
# * 3951   543              68    4463000.2017 3278398.89  26.5%  17.7    4s
# * 3953   539              69    4436114.5832 3278398.89  26.1%  17.7    4s
# * 3958   539              73    4430571.0209 3278398.89  26.0%  17.6    4s
# * 3964   539              78    4430185.8578 3278398.89  26.0%  17.6    4s
# * 4036   599              95    4430185.5671 3290695.82  25.7%  17.6    4s
# * 4037   599              95    4430185.4340 3290695.82  25.7%  17.6    4s
# * 4038   599              94    4430185.2400 3290695.82  25.7%  17.6    4s
# * 4039   599              93    4430184.9572 3290695.82  25.7%  17.6    4s
# * 4040   599              92    4430184.5449 3290695.82  25.7%  17.6    4s
# * 4703  1104              70    4351486.4398 3293800.61  24.3%  17.2    4s
# * 4704  1104              70    4345538.9951 3293800.61  24.2%  17.2    4s
# H 4707  1100                    4339550.0669 3293800.61  24.1%  17.2    4s
# * 4709  1100              70    4338224.1099 3293800.61  24.1%  17.2    4s
# * 4714  1100              71    4337676.5733 3293800.61  24.1%  17.2    4s
# * 4880  1258              74    4337660.2876 3293800.61  24.1%  16.9    4s
# * 5303  1333             106    3886436.4317 3293800.61  15.2%  15.9    4s
# * 5472  1160             122    3866537.9592 3323997.98  14.0%  15.7    4s
# * 5473   586             122    3847631.9276 3323997.98  13.6%  15.7    4s
#   5938   842     cutoff   55      3847631.93 3348696.94  13.0%  16.0    5s
# H 6508   906                    3816458.3364 3364812.14  11.8%  16.5    5s
# H 6513   900                    3812067.1685 3364812.14  11.7%  16.6    5s
#  12055  3578 3576083.95   41   67 3812067.17 3439791.13  9.77%  19.8   10s
# H12878  3587                    3791038.1752 3444923.34  9.13%  20.0   11s
#  19505  6555 3570684.13   46   62 3791038.18 3472829.64  8.39%  21.8   15s
# H26273  8623                    3790307.2346 3487391.68  7.99%  22.5   18s
#  27979  9404 3717764.76   53   19 3790307.23 3490579.32  7.91%  22.6   20s
# H28187  9403                    3790182.4837 3490703.56  7.90%  22.6   20s
#  38269 12973 3672020.41   53   19 3790182.48 3505703.85  7.51%  22.8   25s
#  49089 16442     cutoff   48      3790182.48 3515750.63  7.24%  22.7   30s
#  60007 19394 3528191.70   44   70 3790182.48 3522283.81  7.07%  22.8   35s
#  70977 22068     cutoff   57      3790182.48 3527851.87  6.92%  22.9   40s
#  82013 24600 3615270.87   59   65 3790182.48 3532014.94  6.81%  23.1   45s
#  92685 26669 3583802.85   47   65 3790182.48 3535359.89  6.72%  23.2   50s
#  103291 28772 3687256.28   54   65 3790182.48 3538270.41  6.65%  23.3   55s
#  114125 30757 3774552.90   55   63 3790182.48 3540976.93  6.58%  23.4   60s
#  123897 32388     cutoff   53      3790182.48 3543265.54  6.51%  23.5   65s
#  135402 34304     cutoff   51      3790182.48 3545643.99  6.45%  23.6   70s
#  145717 36029     cutoff   51      3790182.48 3547977.28  6.39%  23.7   75s
#  155796 37410 3602871.66   51   19 3790182.48 3549894.12  6.34%  23.9   80s
#  166663 39031     cutoff   49      3790182.48 3551982.73  6.28%  24.0   85s
# H170749 39418                    3790060.4372 3552684.11  6.26%  24.0   87s
# H170936 39412                    3789888.7911 3552684.11  6.26%  24.0   87s
#  175722 40102 3751168.17   51   62 3789888.79 3553549.69  6.24%  24.0   90s
#  182997 40974 infeasible   68      3789888.79 3554145.57  6.22%  25.5   95s
#  183346 41198  postponed   99      3789888.79 3554145.57  6.22%  30.1  100s
#  183781 41391  postponed   73      3789888.79 3554145.57  6.22%  35.3  105s
#  184425 41589  postponed  108      3789888.79 3554145.57  6.22%  40.3  110s
#  184831 41778  postponed   72      3789888.79 3554145.57  6.22%  44.9  115s
#  185312 41965     cutoff  108      3789888.79 3554145.57  6.22%  50.4  120s
#
# Cutting planes:
#   Gomory: 12
#   Cover: 2
#   Implied bound: 3
#   Projected implied bound: 1
#   MIR: 36
#   Flow cover: 30
#   RLT: 296
#
# Explored 185371 nodes (9438975 simplex iterations) in 120.00 seconds (159.93 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 3.78989e+06 3.79006e+06 3.79018e+06 ... 3.88644e+06
#
# Time limit reached
# Warning: max constraint violation (1.6832e-06) exceeds tolerance
# Best objective 3.789888791065e+06, best bound 3.554145574567e+06, gap 6.2203%
#
# User-callback calls 378928, time in user-callback 0.04 sec
# CSV file exported to: Results/Max_cost/profiles_demand_flex50_vre0.csv
# INSTALLED POWER RESULTS
# [867.6771340658341, 1669.1452475116293, 351.20330166571176, 0.0, 2412.0546595590886]
# CSV file exported to: Results/Max_cost/power_demand_flex50_vre0.csv
# demand_flex50_vre50
# Reading scenario data/demand_flex50_vre50.csv
# Loaded demand with size (8759, 1)
# Cost
# Demand
# (8759,)
# (8807,)
# Availability
# Try reverse
# (8808, 5)
# Number of technologies: 5
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-09-07
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 120
# Model: initialized!
#
# Demand constraint
# Renewable maximum installed capacity constraint
# Storage variable
# Availability & installed power constraint
# Availability & installed power constraint
# Curtailment definition
# Z_1 expression
# Min X_1, X_2 expression
#  Take the min of min(X_1, X_2) and X_3
#  Take the overall min
#  Take the min of min(X_1, X_2) and X_3
#  Take the overall min
# Initialize Objective
# Optimize model
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 120
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1522 rows, 985 columns and 4720 nonzeros
# Model fingerprint: 0xb5308395
# Model has 538 quadratic constraints
# Variable types: 740 continuous, 245 integer (245 binary)
# Coefficient statistics:
#   Matrix range     [9e-04, 1e+07]
#   QMatrix range    [1e+00, 2e+00]
#   QLMatrix range   [1e+00, 1e+07]
#   Objective range  [2e-03, 1e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+02, 1e+07]
#   QRHS range       [1e+07, 1e+07]
# Presolve added 4 rows and 64 columns
# Presolve time: 0.02s
# Presolved: 2489 rows, 1194 columns, 7207 nonzeros
# Presolved model has 239 bilinear constraint(s)
# Variable types: 951 continuous, 243 integer (243 binary)
#
# Root relaxation: objective 1.497502e+06, 679 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1497501.87    0  131          - 1497501.87      -     -    0s
# H    0     0                    3.817119e+08 1497501.87   100%     -    0s
#      0     0 2221571.96    0  135 3.8171e+08 2221571.96  99.4%     -    0s
#      0     0 2381873.10    0  135 3.8171e+08 2381873.10  99.4%     -    0s
#      0     0 2381873.10    0  134 3.8171e+08 2381873.10  99.4%     -    0s
#      0     0 2381873.10    0  122 3.8171e+08 2381873.10  99.4%     -    0s
#      0     0 2381873.10    0  123 3.8171e+08 2381873.10  99.4%     -    0s
#      0     0 2381873.10    0  128 3.8171e+08 2381873.10  99.4%     -    0s
#      0     0 2381873.10    0  128 3.8171e+08 2381873.10  99.4%     -    0s
#      0     2 2381873.10    0  126 3.8171e+08 2381873.10  99.4%     -    0s
# H  135   144                    3.815487e+08 2381873.10  99.4%  17.3    0s
# H  270   277                    9.901537e+07 2381873.10  97.6%  13.6    0s
# H  275   277                    9.901537e+07 2381873.10  97.6%  13.4    0s
# *  313   331              36    5133365.7313 2381873.10  53.6%  13.9    0s
# H 1455   927                    4204834.4089 3097842.45  26.3%  21.5    4s
#   1536   941 3854166.51   25  100 4204834.41 3272312.50  22.2%  25.7    5s
# * 1652   915              33    4173331.0037 3272312.50  21.6%  27.5    5s
# * 1683   873              35    4157005.7869 3272312.50  21.3%  28.0    5s
# * 1714   831              38    4156025.7150 3272312.50  21.3%  28.4    5s
# * 1750   797              40    4155986.8097 3272312.50  21.3%  28.8    5s
# H 1760   786                    3985548.9613 3272312.50  17.9%  28.9    5s
# * 1817   735              47    3959208.3048 3272312.50  17.3%  28.9    5s
# * 1912   741              67    3958542.3941 3288725.81  16.9%  28.5    5s
# * 2045   747              74    3958519.1735 3288725.81  16.9%  28.1    5s
# * 2461   703              42    3941027.9097 3302087.77  16.2%  29.2    6s
# * 2532   658              48    3931615.9641 3302087.77  16.0%  29.0    6s
# * 2616   672              63    3931561.4784 3302087.77  16.0%  28.4    6s
# * 2699   693              67    3931523.2887 3302087.77  16.0%  28.2    6s
# * 2775   639             120    3888489.7872 3320587.13  14.6%  27.8    6s
# * 2776   615             120    3886213.0590 3320587.13  14.6%  27.8    6s
# * 2777   605             119    3883811.3642 3320587.13  14.5%  27.8    6s
# * 2778   599             118    3881528.2453 3320587.13  14.5%  27.8    6s
# * 2779   599             117    3878866.8165 3320587.13  14.4%  27.8    6s
# * 3144   684             103    3801423.4129 3346846.53  12.0%  27.9    6s
# H 4192   801                    3798766.7061 3419235.72  10.0%  32.9    7s
# H 4195   801                    3798766.5003 3419235.72  10.0%  32.8    7s
#   5850  1545 3502906.07   31   64 3798766.50 3461533.30  8.88%  37.1   10s
# * 7731  2419             110    3797784.3399 3472895.00  8.55%  37.0   11s
# * 9287  2644              70    3785078.2599 3481475.30  8.02%  37.5   12s
# H10490  2952                    3780725.3426 3484606.92  7.83%  37.7   14s
# H10491  2946                    3780633.8898 3484606.92  7.83%  37.7   14s
# H10496  2946                    3780399.7387 3484606.92  7.82%  37.7   14s
#  11306  3299 3751727.71   38   28 3780399.74 3488701.11  7.72%  38.1   15s
# *12150  3455             105    3774505.7271 3490607.95  7.52%  38.2   15s
# *12154  3444             106    3773395.8888 3490607.95  7.49%  38.2   15s
# *12158  3429             107    3771336.3613 3490607.95  7.44%  38.2   15s
# *12160  3411             106    3770167.3333 3490607.95  7.42%  38.2   15s
# H13142  3721                    3763612.9250 3492943.27  7.19%  38.4   16s
# H14498  3960                    3763295.4192 3494491.23  7.14%  39.8   18s
# H14504  3921                    3760203.3667 3494491.23  7.07%  40.1   18s
#  16156  4446  postponed   39      3760203.37 3496852.29  7.00%  42.2   20s
# H18469  4758                    3760058.1933 3500122.58  6.91%  44.6   22s
# H18475  4754                    3759935.5684 3500122.58  6.91%  45.0   22s
#  21387  5682 3705738.63   40   17 3759935.57 3503441.18  6.82%  46.9   25s
#  28596  7113 infeasible   40      3759935.57 3512199.88  6.59%  47.3   30s
# H32714  7712                    3759932.9107 3515827.46  6.49%  47.4   33s
#  34554  8148     cutoff   43      3759932.91 3517487.99  6.45%  47.4   35s
#  41099  9070 3527987.21   35   66 3759932.91 3523194.00  6.30%  47.9   40s
# H45274  9497                    3759843.4155 3526479.51  6.21%  48.8   43s
#  46575  9675 3555944.76   39   64 3759843.42 3527478.96  6.18%  48.8   45s
# H52940 10475                    3759831.3111 3531775.88  6.07%  48.7   49s
#  54122 10650     cutoff   39      3759831.31 3532621.72  6.04%  48.7   50s
#  60204 11179     cutoff   37      3759831.31 3536613.00  5.94%  48.8   55s
#  67832 11745 infeasible   50      3759831.31 3541520.84  5.81%  48.8   60s
#  74330 12071 3631707.11   41   66 3759831.31 3545737.29  5.69%  49.2   65s
#  80704 12364     cutoff   34      3759831.31 3550734.82  5.56%  50.1   70s
#  86351 12453     cutoff   43      3759831.31 3554705.18  5.46%  50.1   75s
#  94068 12599 3726970.83   38   17 3759831.31 3560066.78  5.31%  50.2   80s
#  100243 12654 3623588.98   35   61 3759831.31 3564644.00  5.19%  51.0   85s
#  106633 12582 3645211.61   33   60 3759831.31 3569568.55  5.06%  51.8   90s
#  112826 12522 3758883.88   45   57 3759831.31 3574929.19  4.92%  52.0   95s
# H114487 12479                    3759826.8361 3576301.35  4.88%  52.1   96s
#  118093 12266     cutoff   40      3759826.84 3580096.27  4.78%  52.1  100s
#  124711 11986 3724941.38   36   63 3759826.84 3586142.54  4.62%  52.7  105s
#  130853 11642     cutoff   41      3759826.84 3593383.88  4.43%  53.3  110s
#  137106 11418 3656563.40   35   14 3759826.84 3601390.28  4.21%  53.5  115s
#  143457 11119 3666810.84   35   65 3759826.84 3610064.95  3.98%  53.5  120s
#
# Cutting planes:
#   Learned: 1
#   Gomory: 5
#   Cover: 13
#   Implied bound: 8
#   Projected implied bound: 13
#   Clique: 6
#   MIR: 50
#   Flow cover: 70
#   Inf proof: 2
#   RLT: 349
#   Relax-and-lift: 49
#
# Explored 144258 nodes (7723510 simplex iterations) in 120.01 seconds (120.96 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 3.75983e+06 3.75983e+06 3.75984e+06 ... 3.77017e+06
#
# Time limit reached
# Warning: max constraint violation (1.5372e-06) exceeds tolerance
# Best objective 3.759826836135e+06, best bound 3.611440726921e+06, gap 3.9466%
#
# User-callback calls 297108, time in user-callback 0.03 sec
# CSV file exported to: Results/Max_cost/profiles_demand_flex50_vre50.csv
# INSTALLED POWER RESULTS
# [899.4027648440075, 1653.2172123461764, 344.0000028167819, 0.0, 2337.0000067751935]
# CSV file exported to: Results/Max_cost/power_demand_flex50_vre50.csv
# demand_flex50_vre100
# Reading scenario data/demand_flex50_vre100.csv
# Loaded demand with size (8759, 1)
# Cost
# Demand
# (8759,)
# (8807,)
# Availability
# Try reverse
# (8808, 5)
# Number of technologies: 5
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-09-07
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 120
# Model: initialized!
#
# Demand constraint
# Renewable maximum installed capacity constraint
# Storage variable
# Availability & installed power constraint
# Availability & installed power constraint
# Curtailment definition
# Z_1 expression
# Min X_1, X_2 expression
#  Take the min of min(X_1, X_2) and X_3
#  Take the overall min
#  Take the min of min(X_1, X_2) and X_3
#  Take the overall min
# Initialize Objective
# Optimize model
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 120
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1522 rows, 985 columns and 4720 nonzeros
# Model fingerprint: 0x6bcb4967
# Model has 538 quadratic constraints
# Variable types: 740 continuous, 245 integer (245 binary)
# Coefficient statistics:
#   Matrix range     [9e-04, 1e+07]
#   QMatrix range    [1e+00, 2e+00]
#   QLMatrix range   [1e+00, 1e+07]
#   Objective range  [2e-03, 1e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+02, 1e+07]
#   QRHS range       [1e+07, 1e+07]
# Presolve added 4 rows and 64 columns
# Presolve time: 0.01s
# Presolved: 2489 rows, 1194 columns, 7207 nonzeros
# Presolved model has 239 bilinear constraint(s)
# Variable types: 951 continuous, 243 integer (243 binary)
#
# Root relaxation: objective 1.533642e+06, 700 iterations, 0.00 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1533642.16    0  139          - 1533642.16      -     -    0s
# H    0     0                    5.005042e+08 1533642.16   100%     -    0s
#      0     0 2101086.13    0  139 5.0050e+08 2101086.13   100%     -    0s
# H    0     0                    4.017175e+08 2101086.13  99.5%     -    0s
#      0     0 2268615.12    0  138 4.0172e+08 2268615.12  99.4%     -    0s
#      0     2 2268615.12    0  137 4.0172e+08 2268615.12  99.4%     -    0s
# H  178   211                    3.836008e+08 2268615.12  99.4%  17.8    0s
# H  182   211                    3.836008e+08 2268615.12  99.4%  17.4    0s
# *  290   301              35    4986441.2260 2268615.12  54.5%  13.6    0s
# H 1451   922                    3740343.7105 3140593.67  16.0%  21.8    3s
# * 2007  1058             112    3740342.1940 3212525.44  14.1%  25.3    4s
# * 2009  1013             111    3740342.1742 3212525.44  14.1%  25.3    4s
# * 2010   972             110    3740342.1532 3212525.44  14.1%  25.3    4s
# * 2011   932             109    3740342.1309 3212525.44  14.1%  25.3    4s
# * 2193   921              80    3739538.5829 3243312.44  13.3%  24.8    4s
#   2303   899 3739538.53   74   45 3739538.58 3243312.44  13.3%  25.3    5s
# * 2355   849              74    3739532.8777 3302375.83  11.7%  25.0    5s
# * 3243  1002              72    3739375.5913 3312629.18  11.4%  27.5    5s
# * 4635  1583             142    3727789.5823 3312629.18  11.1%  23.0    6s
# * 4637  1553             143    3724537.4839 3312629.18  11.1%  23.0    6s
# H 5774  1352                    3699246.7082 3342611.51  9.64%  25.6    7s
# H 5777  1352                    3699245.7149 3342611.51  9.64%  25.6    7s
# H 5779  1351                    3699149.8270 3342611.51  9.64%  25.6    7s
#   8168  2409 3571345.33   36   58 3699149.83 3375682.04  8.74%  29.9   10s
# *11526  3795             108    3697087.2867 3392816.48  8.23%  33.3   12s
# *11533  3793             110    3696790.1787 3392816.48  8.22%  33.3   12s
# *11544  3793             112    3696623.8058 3392816.48  8.22%  33.3   12s
# H12681  4231                    3693756.8818 3396886.49  8.04%  34.0   13s
# H14025  4659                    3693756.8671 3400906.10  7.93%  34.9   14s
#  14369  4704 3656444.58   39   64 3693756.87 3400906.10  7.93%  35.2   15s
# H14373  4691                    3693749.8265 3400906.10  7.93%  35.2   15s
# H14507  4599                    3687460.3903 3400906.10  7.77%  35.3   15s
# H18539  6057                    3679968.9155 3408863.13  7.37%  37.2   18s
# H18545  6057                    3679968.9147 3408863.13  7.37%  37.2   18s
#  19982  6785 3616650.46   42   61 3679968.91 3412167.60  7.28%  37.7   20s
#  27027  8636     cutoff   41      3679968.91 3420031.05  7.06%  40.6   25s
# H31759  9067                    3674370.1025 3423758.20  6.82%  42.4   28s
# H33455  9511                    3673787.5399 3425325.73  6.76%  42.8   29s
#  33957  9700     cutoff   44      3673787.54 3425538.03  6.76%  43.0   30s
#  40509 10946 3620303.58   41   13 3673787.54 3429737.04  6.64%  44.5   35s
#  48917 12484 3657594.01   41   21 3673787.54 3433988.85  6.53%  45.7   40s
#  55546 13615 3456157.92   36   18 3673787.54 3436852.76  6.45%  46.6   45s
#  62340 14718 3520792.64   34   55 3673787.54 3439785.59  6.37%  47.3   50s
#  69977 15876     cutoff   46      3673787.54 3442480.85  6.30%  48.1   55s
#  77746 16997 3671924.17   47   55 3673787.54 3445132.15  6.22%  48.6   60s
#  84187 17734 3470767.36   36   66 3673787.54 3447351.12  6.16%  49.1   65s
#  91294 18522 3481939.03   38   66 3673787.54 3449669.22  6.10%  49.5   70s
#  98376 19329     cutoff   41      3673787.54 3451887.98  6.04%  50.0   75s
#  104499 19920 infeasible   38      3673787.54 3453889.71  5.99%  50.4   80s
#  112529 20713     cutoff   41      3673787.54 3456098.65  5.93%  50.7   85s
#  119805 21384     cutoff   42      3673787.54 3458273.84  5.87%  51.0   90s
#  126118 21924 infeasible   41      3673787.54 3460079.58  5.82%  51.2   95s
# H128296 22046                    3673752.8538 3460542.52  5.80%  51.3   96s
#  131857 22423 3484512.69   40   17 3673752.85 3461646.95  5.77%  51.4  100s
#  139393 22830 3648644.88   40   62 3673752.85 3463603.65  5.72%  51.6  105s
#  145692 23271 3662241.80   38   64 3673752.85 3465517.28  5.67%  51.8  110s
#  152917 23647     cutoff   44      3673752.85 3467554.21  5.61%  52.1  115s
#  159268 23939 3609102.61   36   16 3673752.85 3469300.79  5.57%  52.2  120s
#
# Cutting planes:
#   Gomory: 2
#   Cover: 7
#   Implied bound: 14
#   Projected implied bound: 13
#   Clique: 6
#   MIR: 47
#   Flow cover: 27
#   RLT: 267
#   Relax-and-lift: 44
#
# Explored 160179 nodes (8371762 simplex iterations) in 120.01 seconds (127.49 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 3.67375e+06 3.67379e+06 3.67437e+06 ... 3.69662e+06
#
# Time limit reached
# Warning: max constraint violation (1.5138e-06) exceeds tolerance
# Best objective 3.673752853838e+06, best bound 3.469554176076e+06, gap 5.5583%
#
# User-callback calls 326734, time in user-callback 0.03 sec
# CSV file exported to: Results/Max_cost/profiles_demand_flex50_vre100.csv
# INSTALLED POWER RESULTS
# [1006.5718525599914, 1602.7994348333357, 312.99994458502454, 0.0, 2146.999992205715]
# CSV file exported to: Results/Max_cost/power_demand_flex50_vre100.csv
# demand_flex100_vre0
# Reading scenario data/demand_flex100_vre0.csv
# Loaded demand with size (8760, 1)
# Cost
# Demand
# (8760,)
# (8808,)
# Availability
# Try reverse
# (8808, 5)
# Number of technologies: 5
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-09-07
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 120
# Model: initialized!
#
# Demand constraint
# Renewable maximum installed capacity constraint
# Storage variable
# Availability & installed power constraint
# Availability & installed power constraint
# Curtailment definition
# Z_1 expression
# Min X_1, X_2 expression
#  Take the min of min(X_1, X_2) and X_3
#  Take the overall min
#  Take the min of min(X_1, X_2) and X_3
#  Take the overall min
# Initialize Objective
# Optimize model
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 120
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1522 rows, 985 columns and 4720 nonzeros
# Model fingerprint: 0xdd12cf6f
# Model has 538 quadratic constraints
# Variable types: 740 continuous, 245 integer (245 binary)
# Coefficient statistics:
#   Matrix range     [9e-04, 1e+07]
#   QMatrix range    [1e+00, 2e+00]
#   QLMatrix range   [1e+00, 1e+07]
#   Objective range  [2e-03, 1e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+02, 1e+07]
#   QRHS range       [1e+07, 1e+07]
# Presolve added 4 rows and 64 columns
# Presolve time: 0.01s
# Presolved: 2489 rows, 1194 columns, 7207 nonzeros
# Presolved model has 239 bilinear constraint(s)
# Variable types: 951 continuous, 243 integer (243 binary)
#
# Root relaxation: objective 1.372603e+06, 674 iterations, 0.00 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1372602.79    0  146          - 1372602.79      -     -    0s
#      0     0 1568711.91    0  141          - 1568711.91      -     -    0s
# H    0     0                    6.741244e+08 1568711.91   100%     -    0s
#      0     0 1668116.85    0  141 6.7412e+08 1668116.85   100%     -    0s
#      0     0 1768293.28    0  141 6.7412e+08 1768293.28   100%     -    0s
# H    0     0                    6.715920e+08 1768293.28   100%     -    0s
#      0     0 1768293.28    0  141 6.7159e+08 1768293.28   100%     -    0s
# H    0     0                    3.181379e+08 1768293.28  99.4%     -    0s
#      0     0 1768293.28    0  139 3.1814e+08 1768293.28  99.4%     -    0s
#      0     0 1768293.28    0  142 3.1814e+08 1768293.28  99.4%     -    0s
#      0     0 1768293.28    0  141 3.1814e+08 1768293.28  99.4%     -    0s
#      0     0 1768293.28    0  140 3.1814e+08 1768293.28  99.4%     -    0s
#      0     0 1768293.28    0  140 3.1814e+08 1768293.28  99.4%     -    0s
#      0     2 1768293.28    0  131 3.1814e+08 1768293.28  99.4%     -    0s
# H   38    40                    3.108748e+08 1793667.46  99.4%  53.4    0s
# H   60    64                    2.986276e+08 1793758.08  99.4%  37.1    0s
# H  484   491                    8.040496e+07 1793758.08  97.8%  15.7    0s
# H 1499  1230                    8339386.9497 3016554.82  63.8%  16.6    2s
# * 2427  1526              88    6010381.6803 3016554.82  49.8%  19.1    3s
# * 2501  1440              93    5970396.9745 3016554.82  49.5%  19.3    3s
# * 2504  1382              95    5968507.9410 3016554.82  49.5%  19.3    3s
# * 2507  1318              96    5967130.3101 3016554.82  49.4%  19.3    3s
# * 2557  1124              97    5440872.9593 3016554.82  44.6%  19.2    3s
# * 2718  1081              87    5426173.3358 3016554.82  44.4%  19.2    3s
# * 2720   974              88    5274536.8382 3016554.82  42.8%  19.2    3s
# * 3067   801              93    5108099.8888 3016554.82  40.9%  18.7    3s
# * 3068   760              70    3801464.1086 3016554.82  20.6%  18.7    3s
# * 3287   625              85    3779011.5570 3016554.82  20.2%  18.5    3s
# * 3289   587              86    3770357.1016 3016554.82  20.0%  18.5    3s
# * 3291   551              87    3767188.8169 3016554.82  19.9%  18.5    3s
# * 3294   517              89    3766453.5354 3016554.82  19.9%  18.5    3s
# * 3297   486              91    3766282.8857 3016554.82  19.9%  18.4    3s
# * 3300   486              93    3766243.2795 3016554.82  19.9%  18.4    3s
# * 3374   471             100    3766237.4421 3016554.82  19.9%  18.3    3s
# * 3867   649              78    3752114.9025 3100873.85  17.4%  18.8    4s
# * 4200   821              88    3715619.4055 3100873.85  16.5%  18.4    4s
#   5547  1814 3323762.35   27   67 3715619.41 3123971.91  15.9%  17.7    5s
# * 5589  1782              84    3709503.3937 3123971.91  15.8%  17.6    5s
# * 6071  1959             144    3701128.3550 3123971.91  15.6%  16.8    5s
# * 6531  1965             115    3668989.1874 3157349.69  13.9%  16.5    5s
# * 7206  1954             134    3668762.9856 3190702.01  13.0%  16.7    6s
# * 7207  1907             134    3667689.6936 3190702.01  13.0%  16.7    6s
# H 8589  2528                    3654831.9082 3219022.93  11.9%  17.4    6s
# H 9648  2865                    3653205.5882 3239778.14  11.3%  18.0    7s
#  13268  4718     cutoff   53      3653205.59 3302478.45  9.60%  18.9   10s
# *14032  4986             122    3652045.6244 3309472.20  9.38%  18.9   10s
#  22604  8900     cutoff   51      3652045.62 3353924.95  8.16%  19.3   15s
# H27378 10542                    3650903.5415 3367915.61  7.75%  19.4   17s
# H27380 10542                    3650903.5053 3367915.61  7.75%  19.4   17s
# H27387 10457                    3643625.4151 3367915.61  7.57%  19.4   18s
# H27388 10450                    3643160.8214 3367915.61  7.56%  19.4   18s
# H27425 10444                    3642495.7491 3367915.61  7.54%  19.4   18s
#  29633 11681 3528680.98   52   67 3642495.75 3372064.71  7.42%  19.4   20s
#  41661 16731     cutoff   50      3642495.75 3386178.35  7.04%  19.3   25s
#  53893 21350     cutoff   55      3642495.75 3396304.72  6.76%  19.2   30s
#  66624 26111 3422212.95   36   67 3642495.75 3403546.05  6.56%  19.2   35s
#  79226 30440 3607075.23   44   65 3642495.75 3408696.62  6.42%  19.4   40s
#  92722 34534     cutoff   43      3642495.75 3414245.46  6.27%  19.5   45s
#  104460 37743 3431447.39   39   68 3642495.75 3417975.36  6.16%  19.8   50s
#  117849 41342 3621071.99   49   71 3642495.75 3421716.45  6.06%  20.0   55s
#  129336 44237     cutoff   44      3642495.75 3424521.62  5.98%  20.1   60s
#  139198 46592     cutoff   54      3642495.75 3426517.37  5.93%  20.2   65s
#  152618 49457     cutoff   51      3642495.75 3429374.97  5.85%  20.3   70s
#  164431 51663 3548232.50   52   62 3642495.75 3431423.36  5.79%  20.7   75s
#  177242 54098 3554539.21   47   69 3642495.75 3433544.31  5.74%  20.9   80s
#  189179 56188 3591638.40   51   62 3642495.75 3435490.62  5.68%  21.0   85s
#  201043 58484 3519438.02   39   63 3642495.75 3437187.20  5.64%  21.1   90s
#  212724 60420 infeasible   52      3642495.75 3438641.47  5.60%  21.1   95s
#  225564 62474     cutoff   50      3642495.75 3440168.56  5.55%  21.2  100s
#  238090 64430 3442180.28   37   69 3642495.75 3441784.85  5.51%  21.3  105s
# H245609 65361                    3642494.5180 3442717.42  5.48%  21.3  109s
# H245900 65360                    3642483.6497 3442736.02  5.48%  21.3  109s
#  247483 65589 3450088.67   56   66 3642483.65 3442963.61  5.48%  21.3  110s
#  259859 67414     cutoff   56      3642483.65 3444393.74  5.44%  21.4  115s
#  269924 68501 3605669.89   49   60 3642483.65 3445599.36  5.41%  21.4  120s
#
# Cutting planes:
#   Gomory: 18
#   Cover: 1
#   Implied bound: 2
#   Projected implied bound: 1
#   MIR: 29
#   Flow cover: 29
#   Inf proof: 3
#   RLT: 281
#
# Explored 270245 nodes (5793352 simplex iterations) in 120.01 seconds (138.74 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 3.64248e+06 3.64249e+06 3.6425e+06 ... 3.65483e+06
#
# Time limit reached
# Warning: max constraint violation (1.5230e-06) exceeds tolerance
# Best objective 3.642483649700e+06, best bound 3.445692370185e+06, gap 5.4027%
#
# User-callback calls 554386, time in user-callback 0.04 sec
# CSV file exported to: Results/Max_cost/profiles_demand_flex100_vre0.csv
# INSTALLED POWER RESULTS
# [876.9696210742118, 1648.3327076581413, 302.39227679930366, 0.0, 2168.9548343712604]
# CSV file exported to: Results/Max_cost/power_demand_flex100_vre0.csv
# demand_flex100_vre50
# Reading scenario data/demand_flex100_vre50.csv
# Loaded demand with size (8760, 1)
# Cost
# Demand
# (8760,)
# (8808,)
# Availability
# Try reverse
# (8808, 5)
# Number of technologies: 5
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-09-07
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 120
# Model: initialized!
#
# Demand constraint
# Renewable maximum installed capacity constraint
# Storage variable
# Availability & installed power constraint
# Availability & installed power constraint
# Curtailment definition
# Z_1 expression
# Min X_1, X_2 expression
#  Take the min of min(X_1, X_2) and X_3
#  Take the overall min
#  Take the min of min(X_1, X_2) and X_3
#  Take the overall min
# Initialize Objective
# Optimize model
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 120
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1522 rows, 985 columns and 4720 nonzeros
# Model fingerprint: 0x49c7d81b
# Model has 538 quadratic constraints
# Variable types: 740 continuous, 245 integer (245 binary)
# Coefficient statistics:
#   Matrix range     [9e-04, 1e+07]
#   QMatrix range    [1e+00, 2e+00]
#   QLMatrix range   [1e+00, 1e+07]
#   Objective range  [2e-03, 1e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+02, 1e+07]
#   QRHS range       [1e+07, 1e+07]
# Presolve added 4 rows and 64 columns
# Presolve time: 0.01s
# Presolved: 2489 rows, 1194 columns, 7207 nonzeros
# Presolved model has 239 bilinear constraint(s)
# Variable types: 951 continuous, 243 integer (243 binary)
#
# Root relaxation: objective 1.362884e+06, 675 iterations, 0.00 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1362883.71    0  154          - 1362883.71      -     -    0s
#      0     0 1568328.25    0  152          - 1568328.25      -     -    0s
# H    0     0                    6.564676e+08 1568328.25   100%     -    0s
#      0     0 1763845.62    0  152 6.5647e+08 1763845.62   100%     -    0s
# H    0     0                    3.081444e+08 1763845.62  99.4%     -    0s
# H    0     2                    3.081424e+08 1763845.62  99.4%     -    0s
#      0     2 1763845.62    0  143 3.0814e+08 1763845.62  99.4%     -    0s
# H   31    40                    3.079568e+08 1763845.62  99.4%  88.5    0s
# H   35    40                    2.990643e+08 1885182.91  99.4%  80.6    0s
# H   38    40                    2.983630e+08 1885182.91  99.4%  80.1    0s
# H  266   319                    2.723862e+08 2001789.47  99.3%  16.6    0s
# H  479   504                    6.044504e+07 2001789.47  96.7%  14.8    0s
# *  899   520              77    6027953.0808 2001789.47  66.8%  16.7    0s
# * 1216   559              90    6019443.5018 2194163.01  63.5%  17.2    0s
# H 1627   711                    5251125.6365 3038035.33  42.1%  15.7    3s
# H 1630   677                    4165239.8017 3156232.60  24.2%  15.7    4s
#   1665   698 3418063.85   19   66 4165239.80 3333099.22  20.0%  18.2    5s
# * 1949   752              50    3902192.0028 3333099.22  14.6%  19.9    5s
# * 1953   719              53    3890919.6258 3333099.22  14.3%  19.9    5s
# * 1981   684              54    3889621.6372 3337183.55  14.2%  20.2    5s
# * 1984   654              56    3889523.8618 3337183.55  14.2%  20.2    5s
# * 1987   625              58    3889517.8384 3337183.55  14.2%  20.2    5s
# * 2139   641              77    3889517.4922 3338827.54  14.2%  20.5    5s
# * 2770   758             100    3679730.9197 3344592.74  9.11%  18.1    5s
# * 3231   913             114    3675099.8055 3351881.05  8.79%  16.7    5s
# * 3469  1099             119    3660711.7839 3358179.57  8.26%  15.9    5s
# * 3471  1098             120    3659376.6536 3358179.57  8.23%  15.9    5s
# * 3475  1085             122    3657660.9407 3358179.57  8.19%  15.9    5s
# * 3582  1164             123    3655163.1357 3358179.57  8.13%  15.8    5s
# * 3819   959             124    3644264.8767 3367558.29  7.59%  15.8    6s
# H 6007  2032                    3638380.8257 3379269.30  7.12%  15.5    7s
# H 6034  2021                    3635391.0901 3379269.30  7.05%  15.5    7s
# H 6037  2021                    3635391.0733 3379269.30  7.05%  15.5    7s
# *10692  3208             134    3632070.3361 3391729.53  6.62%  19.9    9s
#  10852  3323 3611537.05   41   75 3632070.34 3392429.03  6.60%  19.9   10s
# *13543  4043              78    3630798.1682 3396037.85  6.47%  21.6   11s
#  20536  6264     cutoff   35      3630798.17 3411949.00  6.03%  23.9   15s
# H27135  7370                    3627072.2571 3424175.08  5.59%  26.2   18s
#  29570  7686 infeasible   44      3627072.26 3424175.08  5.59%  28.7   20s
# H31904  7368                    3605611.0845 3424175.08  5.03%  31.3   21s
# H31907  7368                    3605610.9548 3424175.08  5.03%  31.3   21s
# *32087  7368             132    3605610.5930 3424175.08  5.03%  31.1   21s
#  36959  7346 3469412.00   31   66 3605610.59 3465606.10  3.88%  34.8   25s
# H39943  7206                    3603986.2978 3466790.38  3.81%  34.9   26s
#  45745  7236     cutoff   41      3603986.30 3482554.34  3.37%  34.3   30s
#  57823  6947     cutoff   35      3603986.30 3499822.54  2.89%  32.9   35s
#  68236  4764     cutoff   36      3603986.30 3534607.50  1.93%  31.9   40s
# *78996  2467             114    3603976.2256 3574514.16  0.82%  30.2   44s
# *79267  2416             101    3603759.5535 3574816.80  0.80%  30.2   44s
#  80635  2002     cutoff   38      3603759.55 3584392.10  0.54%  29.9   45s
# *82611  1903             110    3603698.7791 3588480.92  0.42%  29.4   46s
# *83026  1889             117    3603681.7851 3588480.92  0.42%  29.3   46s
# *84191  1840             130    3603672.0293 3589536.95  0.39%  28.9   46s
# *84192  1769             131    3603553.2793 3589536.95  0.39%  28.9   46s
# *84258  1568             116    3603509.4372 3589536.95  0.39%  28.9   46s
# *84260  1547             117    3603473.7049 3589536.95  0.39%  28.9   46s
# *84261  1513             117    3603430.4005 3589536.95  0.39%  28.9   46s
# *84618  1462             128    3603305.1776 3594787.12  0.24%  28.8   46s
# *87322  1717             125    3603295.6929 3597178.75  0.17%  28.0   47s
# *89794  1953             111    3603255.2143 3599952.94  0.09%  27.3   48s
#  95920  2714 3603194.73   65   61 3603255.21 3601676.34  0.04%  25.7   50s
#  115800  4861 3603130.30   69   61 3603255.21 3602638.74  0.02%  21.4   55s
#
# Cutting planes:
#   Gomory: 9
#   Cover: 3
#   Implied bound: 6
#   Projected implied bound: 3
#   Clique: 6
#   MIR: 97
#   Flow cover: 94
#   Inf proof: 3
#   RLT: 172
#   Relax-and-lift: 6
#
# Explored 133644 nodes (2484271 simplex iterations) in 59.22 seconds (57.18 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 3.60326e+06 3.6033e+06 3.60331e+06 ... 3.6037e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Warning: max constraint violation (1.5709e-06) exceeds tolerance
# Best objective 3.603255214273e+06, best bound 3.602896965844e+06, gap 0.0099%
#
# User-callback calls 272337, time in user-callback 0.02 sec
# CSV file exported to: Results/Max_cost/profiles_demand_flex100_vre50.csv
# INSTALLED POWER RESULTS
# [876.6011139701784, 1654.205083760958, 281.65495604475774, 0.0, 2091.048603447143]
# CSV file exported to: Results/Max_cost/power_demand_flex100_vre50.csv
# demand_flex100_vre100
# Reading scenario data/demand_flex100_vre100.csv
# Loaded demand with size (8760, 1)
# Cost
# Demand
# (8760,)
# (8808,)
# Availability
# Try reverse
# (8808, 5)
# Number of technologies: 5
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-09-07
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 120
# Model: initialized!
#
# Demand constraint
# Renewable maximum installed capacity constraint
# Storage variable
# Availability & installed power constraint
# Availability & installed power constraint
# Curtailment definition
# Z_1 expression
# Min X_1, X_2 expression
#  Take the min of min(X_1, X_2) and X_3
#  Take the overall min
#  Take the min of min(X_1, X_2) and X_3
#  Take the overall min
# Initialize Objective
# Optimize model
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 120
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1522 rows, 985 columns and 4720 nonzeros
# Model fingerprint: 0x13c26394
# Model has 538 quadratic constraints
# Variable types: 740 continuous, 245 integer (245 binary)
# Coefficient statistics:
#   Matrix range     [9e-04, 1e+07]
#   QMatrix range    [1e+00, 2e+00]
#   QLMatrix range   [1e+00, 1e+07]
#   Objective range  [2e-03, 1e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+02, 1e+07]
#   QRHS range       [1e+07, 1e+07]
# Presolve added 4 rows and 64 columns
# Presolve time: 0.01s
# Presolved: 2489 rows, 1194 columns, 7207 nonzeros
# Presolved model has 239 bilinear constraint(s)
# Variable types: 951 continuous, 243 integer (243 binary)
#
# Root relaxation: objective 1.409073e+06, 680 iterations, 0.00 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1409073.39    0  156          - 1409073.39      -     -    0s
#      0     0 1599728.86    0  155          - 1599728.86      -     -    0s
#      0     0 1789601.27    0  154          - 1789601.27      -     -    0s
# H    0     0                    5.645918e+08 1789601.27   100%     -    0s
# H    0     0                    5.621009e+08 1789601.27   100%     -    0s
#      0     2 1789601.27    0  154 5.6210e+08 1789601.27   100%     -    0s
# H   33    40                    2.641495e+08 1789601.27  99.3%  60.4    0s
# H   62    64                    2.619953e+08 1789601.27  99.3%  35.1    0s
# H  123   142                    2.613563e+08 1789601.27  99.3%  20.3    0s
# H  131   142                    2.613563e+08 1789601.27  99.3%  19.4    0s
# H  133   142                    2.506184e+08 1789601.27  99.3%  19.1    0s
# H  139   142                    2.310207e+08 1789601.27  99.2%  18.4    0s
# *  248   260              34    4999501.7698 1789601.27  64.2%  13.0    0s
# *  292   266              35    4829943.7426 1789601.27  62.9%  14.7    0s
# H 1489   959                    3590650.7926 3011567.31  16.1%  22.1    4s
#   1710  1055 3305277.26   32   18 3590650.79 3101894.98  13.6%  25.3    5s
# * 2046  1072              78    3588093.3004 3101894.98  13.6%  25.7    5s
# * 2116  1046              86    3587796.3493 3101894.98  13.5%  25.0    5s
# * 2122  1000              91    3587547.4208 3101894.98  13.5%  25.0    5s
# * 2191   990              99    3587485.3411 3101894.98  13.5%  24.4    5s
# * 2267   974             101    3587455.8576 3101894.98  13.5%  24.1    5s
# * 2280   933             105    3587448.5018 3101894.98  13.5%  24.0    5s
# * 2319   918             109    3582985.6850 3101894.98  13.4%  23.7    5s
# * 2320   846             109    3581063.0610 3101894.98  13.4%  23.7    5s
# * 2395   783             109    3581063.0506 3140849.97  12.3%  23.2    5s
# * 2454   718              99    3575298.5964 3144664.86  12.0%  23.2    5s
# * 3002   727              83    3573949.6849 3171703.04  11.3%  24.1    5s
# * 3003   699              83    3573732.2613 3171703.04  11.2%  24.1    5s
# * 3004   687              82    3573503.3942 3171703.04  11.2%  24.1    5s
# * 3005   687              81    3573262.4811 3171703.04  11.2%  24.0    5s
# * 3709  1069              98    3563187.3993 3174113.98  10.9%  24.2    6s
# * 3821   994             103    3540540.6073 3174113.98  10.3%  24.1    6s
# * 3822   993             103    3539682.1355 3174113.98  10.3%  24.1    6s
# * 3824   991             101    3538773.0615 3174113.98  10.3%  24.0    6s
# * 3825   990             100    3538266.4030 3174113.98  10.3%  24.0    6s
# H 4690  1521                    3537343.0124 3243640.72  8.30%  24.8    7s
# H 5806  1867                    3497931.7843 3256396.60  6.91%  26.1    8s
#   8715  3332 3317890.48   33   70 3497931.78 3274988.08  6.37%  28.5   10s
# H 8871  3361                    3497663.5059 3274988.08  6.37%  28.8   10s
# H13925  5560                    3487533.0930 3285290.59  5.80%  30.9   14s
#  14914  5977 3392666.74   34   30 3487533.09 3285917.55  5.78%  31.3   15s
# H15434  5981                    3487524.9033 3287182.79  5.74%  31.6   15s
# H15435  5979                    3487408.6338 3287182.79  5.74%  31.6   15s
#  22828  9046 3298939.41   30   63 3487408.63 3294175.51  5.54%  34.4   20s
#  32824 12367     cutoff   43      3487408.63 3300822.06  5.35%  36.0   25s
#  42059 15080 3315287.70   35   58 3487408.63 3306058.28  5.20%  37.1   30s
#  51151 17418 3422857.19   34   24 3487408.63 3309966.18  5.09%  38.3   35s
#  60193 19640 3440275.02   40   26 3487408.63 3313762.51  4.98%  39.3   40s
#  68275 21446 3437782.17   34   86 3487408.63 3316819.24  4.89%  40.5   45s
#  76729 23032 3455554.41   35   86 3487408.63 3319912.84  4.80%  41.3   50s
#  84664 24539     cutoff   43      3487408.63 3322275.26  4.74%  41.9   55s
#  93148 26073     cutoff   33      3487408.63 3325249.92  4.65%  42.5   60s
# H94953 26170                    3486726.1918 3325799.91  4.62%  42.6   62s
#  99842 26958 3403710.42   41   67 3486726.19 3327188.37  4.58%  43.4   65s
#  107983 27975     cutoff   34      3486726.19 3329444.23  4.51%  43.9   70s
# H108984 27947                    3486370.9480 3329615.61  4.50%  44.0   71s
# H111161 28174                    3486123.8557 3330146.21  4.47%  44.1   72s
# H112398 28316                    3486110.0448 3330499.47  4.46%  44.2   73s
# H113671 28456                    3486089.4123 3330953.17  4.45%  44.3   74s
#  114187 28563 3449474.61   33   70 3486089.41 3331159.47  4.44%  44.3   75s
#  122830 29688     cutoff   45      3486089.41 3333379.89  4.38%  44.8   80s
#  132037 30635 3414540.04   40   59 3486089.41 3335787.42  4.31%  45.3   85s
#  140903 31344 3418663.58   47   68 3486089.41 3338288.04  4.24%  45.8   90s
#  149046 31934 infeasible   42      3486089.41 3340627.14  4.17%  46.3   95s
#  157960 32542 3351535.67   35   65 3486089.41 3343317.02  4.10%  46.7  100s
#  165677 33081 infeasible   39      3486089.41 3345325.13  4.04%  47.3  105s
#  170588 33350 infeasible   42      3486089.41 3346584.80  4.00%  48.6  110s
#  178099 33792 3378956.83   36   64 3486089.41 3349220.17  3.93%  49.2  115s
#  185851 33952     cutoff   34      3486089.41 3351966.32  3.85%  49.4  120s
#
# Cutting planes:
#   Gomory: 9
#   Cover: 1
#   Implied bound: 8
#   Projected implied bound: 6
#   Clique: 2
#   MIR: 84
#   Flow cover: 18
#   RLT: 185
#   Relax-and-lift: 29
#
# Explored 186028 nodes (9188149 simplex iterations) in 120.00 seconds (134.92 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 3.48609e+06 3.48611e+06 3.48612e+06 ... 3.49793e+06
#
# Time limit reached
# Warning: max constraint violation (1.8868e-06) exceeds tolerance
# Best objective 3.486089412254e+06, best bound 3.351986530250e+06, gap 3.8468%
#
# User-callback calls 380698, time in user-callback 0.03 sec
# CSV file exported to: Results/Max_cost/profiles_demand_flex100_vre100.csv
# INSTALLED POWER RESULTS
# [908.5512249081479, 1626.3711921076444, 261.00000293995504, 0.0, 1822.9999957600498]
# CSV file exported to: Results/Max_cost/power_demand_flex100_vre100.csv
